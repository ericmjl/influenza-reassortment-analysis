# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import brewer2mpl
import colorsys
import math
import dendropy as dp
import json
import os

from datetime import datetime
from Bio import AlignIO, SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq
from Levenshtein import distance
from itertools import combinations, product, permutations
from time import time
from __future__ import division
from collections import Counter, defaultdict
from copy import deepcopy
from random import shuffle, choice, sample
from scipy.stats.mstats import mquantiles
from scipy.stats import norm, expon, poisson, binom
from scipy.misc import comb
from IPython.display import Math
from networkx.readwrite import json_graph 

# %matplotlib inline

# %%
dir_handle = 'mds_coordinates'
coordinate_files = {int(f.split('_')[0]):f for f in os.listdir(dir_handle) if 'avg' in f and 'csv' in f}

# %%
host_codes = {'Avian':0, 
              'Swine':1, 
              'Human':2, 
              'Environment':3,
              'Other':4}

code_hosts = {v:k for k, v in host_codes.items()}

def get_host_code(x, host_codes):
    if '/' in x:
        x = x.split('/')[1]
        
    if x in host_codes.keys():
        return host_codes[x]
    else:
        return host_codes['Other']
    
def get_state(x):
    if len(x.split('/')) == 5:
        return x.split('/')[2]
    if len(x.split('/')) == 4:
        return x.split('/')[1]

# %%
masterfile = pd.read_csv('20150112_All_IRD_HA_Sequences.csv', parse_dates=['Collection Date'])
masterfile['Sequence Accession'] = masterfile['Sequence Accession'].str.strip('*')
masterfile['Strain Name'] = masterfile['Strain Name'].apply(lambda x: x.split('(')[0] if '(' in x else x)
masterfile['Host Species'] = masterfile['Host Species'].str.split(':').str[1]
masterfile['Host Code'] = masterfile['Host Species'].apply(lambda x: get_host_code(x, host_codes))
masterfile['Year'] = masterfile['Collection Date'].apply(lambda x: x.year)
masterfile['State/Province'] = masterfile['Strain Name'].apply(lambda x: get_state(x))
masterfile.set_index('Sequence Accession', inplace=True)

# %%
masterfile
# Out:
#                    Name Complete Genome  Segment  Segment Length Subtype  \
# Sequence Accession
# K00429               HA              No        4            1730    H7N7
# CY083910             HA             Yes        4            1752    H1N1
# CY063606             HA             Yes        4            1734    H1N1
# CY083776             HA              No        4            1748    H1N1
# CY073725             HA             Yes        4            1734    H1N1
# CY062691             HA             Yes        4            1734    H1N1
# CY062699             HA             Yes        4            1734    H1N1
# CY066935             HA             Yes        4            1734    H1N1
# CY066943             HA             Yes        4            1734    H1N1
# CY066951             HA             Yes        4            1734    H1N1
# CY083761             HA              No        4            1750    H1N1
# CY066959             HA             Yes        4            1734    H1N1
# CY066967             HA             Yes        4            1734    H1N1
# CY066975             HA             Yes        4            1734    H1N1
# CY067031             HA             Yes        4            1734    H1N1
# CY067039             HA             Yes        4            1743    H1N1
# CY067047             HA             Yes        4            1734    H1N1
# CY067055             HA             Yes        4            1734    H1N1
# CY176570             HA             Yes        4            1730    H1N1
# CY176578             HA             Yes        4            1755    H1N1
# CY176586             HA             Yes        4            1752    H1N1
# CY129910             HA             Yes        4            1752    H1N1
# CY129918             HA             Yes        4            1752    H1N1
# CY129926             HA             Yes        4            1734    H1N1
# CY129934             HA             Yes        4            1752    H1N1
# CY129546             HA              No        4            1752    H1N1
# CY129942             HA             Yes        4            1752    H1N1
# CY056947             HA             Yes        4            1720    H1N1
# GU367315             HA              No        4            1752    H1N1
# HM628693             HA              No        4            1701    H3N2
# ...                 ...             ...      ...             ...     ...
# GQ457548                    2  2009
# U67783                      0  2009
# DQ659327                    4  2009
# DQ659326                    4  2009
#
# [38918 rows x 13 columns]

# %%
# Color MDS plots by host
host_code_colormap = {0:'r', 1:'b', 2:'g', 3:'orange', 4:'purple'}
for i, f in coordinate_files.items():
    print(i, f)
    coords = pd.read_csv('{0}/{1}'.format(dir_handle, f), index_col=0)
    coords_joined = coords.join(masterfile)
    fig = plt.figure(i)
    for group, data in coords_joined.groupby('Host Code'):
        plt.scatter(data['x'], data['y'], color=host_code_colormap[group], label=code_hosts[group])
    plt.legend()
    plt.title('Subgraph {0} MDS'.format(i))
    plt.savefig('mds_coordinates/{0}_mds_by_host.pdf'.format(i))
    plt.close()
# Out:
# (0, '0_mds_avg_coordinates.csv')
# (1, '1_mds_avg_coordinates.csv')
# (2, '2_mds_avg_coordinates.csv')
# (3, '3_mds_avg_coordinates.csv')
# (4, '4_mds_avg_coordinates.csv')
# (5, '5_mds_avg_coordinates.csv')
# (6, '6_mds_avg_coordinates.csv')
# (7, '7_mds_avg_coordinates.csv')
# (8, '8_mds_avg_coordinates.csv')
# (9, '9_mds_avg_coordinates.csv')
# (10, '10_mds_avg_coordinates.csv')
# (11, '11_mds_avg_coordinates.csv')
# (12, '12_mds_avg_coordinates.csv')
# (13, '13_mds_avg_coordinates.csv')
# (14, '14_mds_avg_coordinates.csv')
# (15, '15_mds_avg_coordinates.csv')
# (16, '16_mds_avg_coordinates.csv')
# (17, '17_mds_avg_coordinates.csv')
# (18, '18_mds_avg_coordinates.csv')
# (19, '19_mds_avg_coordinates.csv')
# (20, '20_mds_avg_coordinates.csv')
# (21, '21_mds_avg_coordinates.csv')
# (22, '22_mds_avg_coordinates.csv')
# (23, '23_mds_avg_coordinates.csv')
# (24, '24_mds_avg_coordinates.csv')
# (25, '25_mds_avg_coordinates.csv')
# (26, '26_mds_avg_coordinates.csv')
# (27, '27_mds_avg_coordinates.csv')
# (28, '28_mds_avg_coordinates.csv')
# (29, '29_mds_avg_coordinates.csv')
# (30, '30_mds_avg_coordinates.csv')
# (31, '31_mds_avg_coordinates.csv')
# (32, '32_mds_avg_coordinates.csv')
# (33, '33_mds_avg_coordinates.csv')
# (35, '35_mds_avg_coordinates.csv')
# (36, '36_mds_avg_coordinates.csv')
# (37, '37_mds_avg_coordinates.csv')
# (39, '39_mds_avg_coordinates.csv')
# (40, '40_mds_avg_coordinates.csv')
# (41, '41_mds_avg_coordinates.csv')
# (42, '42_mds_avg_coordinates.csv')
# (43, '43_mds_avg_coordinates.csv')
# (44, '44_mds_avg_coordinates.csv')
# (45, '45_mds_avg_coordinates.csv')
# (46, '46_mds_avg_coordinates.csv')
# (47, '47_mds_avg_coordinates.csv')
# (48, '48_mds_avg_coordinates.csv')
# (49, '49_mds_avg_coordinates.csv')
# (50, '50_mds_avg_coordinates.csv')
# (51, '51_mds_avg_coordinates.csv')
# (52, '52_mds_avg_coordinates.csv')
# (53, '53_mds_avg_coordinates.csv')
# (54, '54_mds_avg_coordinates.csv')
# (55, '55_mds_avg_coordinates.csv')
# (56, '56_mds_avg_coordinates.csv')
# (57, '57_mds_avg_coordinates.csv')
# (58, '58_mds_avg_coordinates.csv')
# (59, '59_mds_avg_coordinates.csv')
# (60, '60_mds_avg_coordinates.csv')
# (522, '522_mds_avg_coordinates.csv')
# (62, '62_mds_avg_coordinates.csv')
# (63, '63_mds_avg_coordinates.csv')
# (64, '64_mds_avg_coordinates.csv')
# (65, '65_mds_avg_coordinates.csv')
# (66, '66_mds_avg_coordinates.csv')
# (523, '523_mds_avg_coordinates.csv')
# (68, '68_mds_avg_coordinates.csv')
# (71, '71_mds_avg_coordinates.csv')
# (584, '584_mds_avg_coordinates.csv')
# (73, '73_mds_avg_coordinates.csv')
# (74, '74_mds_avg_coordinates.csv')
# (587, '587_mds_avg_coordinates.csv')
# (76, '76_mds_avg_coordinates.csv')
# (77, '77_mds_avg_coordinates.csv')
# (80, '80_mds_avg_coordinates.csv')
# (81, '81_mds_avg_coordinates.csv')
# (82, '82_mds_avg_coordinates.csv')
# (83, '83_mds_avg_coordinates.csv')
# (84, '84_mds_avg_coordinates.csv')
# (85, '85_mds_avg_coordinates.csv')
# (87, '87_mds_avg_coordinates.csv')
# (88, '88_mds_avg_coordinates.csv')
# (89, '89_mds_avg_coordinates.csv')
# (90, '90_mds_avg_coordinates.csv')
# (91, '91_mds_avg_coordinates.csv')
# (92, '92_mds_avg_coordinates.csv')
# (93, '93_mds_avg_coordinates.csv')
# (94, '94_mds_avg_coordinates.csv')
# (96, '96_mds_avg_coordinates.csv')
# (101, '101_mds_avg_coordinates.csv')
# (106, '106_mds_avg_coordinates.csv')
# (107, '107_mds_avg_coordinates.csv')
# (108, '108_mds_avg_coordinates.csv')
# (109, '109_mds_avg_coordinates.csv')
# (110, '110_mds_avg_coordinates.csv')
# (111, '111_mds_avg_coordinates.csv')
# (112, '112_mds_avg_coordinates.csv')
# (113, '113_mds_avg_coordinates.csv')
# (114, '114_mds_avg_coordinates.csv')
# (115, '115_mds_avg_coordinates.csv')
# (116, '116_mds_avg_coordinates.csv')
# (117, '117_mds_avg_coordinates.csv')
# (118, '118_mds_avg_coordinates.csv')
# (121, '121_mds_avg_coordinates.csv')
# (122, '122_mds_avg_coordinates.csv')
# (123, '123_mds_avg_coordinates.csv')
# (125, '125_mds_avg_coordinates.csv')
# (126, '126_mds_avg_coordinates.csv')
# (127, '127_mds_avg_coordinates.csv')
# (128, '128_mds_avg_coordinates.csv')
# (129, '129_mds_avg_coordinates.csv')
# (130, '130_mds_avg_coordinates.csv')
# (131, '131_mds_avg_coordinates.csv')
# (132, '132_mds_avg_coordinates.csv')
# (133, '133_mds_avg_coordinates.csv')
# (134, '134_mds_avg_coordinates.csv')
# (135, '135_mds_avg_coordinates.csv')
# (138, '138_mds_avg_coordinates.csv')
# (139, '139_mds_avg_coordinates.csv')
# (141, '141_mds_avg_coordinates.csv')
# (142, '142_mds_avg_coordinates.csv')
# (144, '144_mds_avg_coordinates.csv')
# (145, '145_mds_avg_coordinates.csv')
# (146, '146_mds_avg_coordinates.csv')
# (147, '147_mds_avg_coordinates.csv')
# (148, '148_mds_avg_coordinates.csv')
# (149, '149_mds_avg_coordinates.csv')
# (150, '150_mds_avg_coordinates.csv')
# (537, '537_mds_avg_coordinates.csv')
# (152, '152_mds_avg_coordinates.csv')
# (153, '153_mds_avg_coordinates.csv')
# (154, '154_mds_avg_coordinates.csv')
# (155, '155_mds_avg_coordinates.csv')
# (156, '156_mds_avg_coordinates.csv')
# (158, '158_mds_avg_coordinates.csv')
# (160, '160_mds_avg_coordinates.csv')
# (161, '161_mds_avg_coordinates.csv')
# (162, '162_mds_avg_coordinates.csv')
# (164, '164_mds_avg_coordinates.csv')
# (165, '165_mds_avg_coordinates.csv')
# (166, '166_mds_avg_coordinates.csv')
# (167, '167_mds_avg_coordinates.csv')
# (170, '170_mds_avg_coordinates.csv')
# (171, '171_mds_avg_coordinates.csv')
# (172, '172_mds_avg_coordinates.csv')
# (176, '176_mds_avg_coordinates.csv')
# (178, '178_mds_avg_coordinates.csv')
# (180, '180_mds_avg_coordinates.csv')
# (182, '182_mds_avg_coordinates.csv')
# (184, '184_mds_avg_coordinates.csv')
# (186, '186_mds_avg_coordinates.csv')
# (187, '187_mds_avg_coordinates.csv')
# (189, '189_mds_avg_coordinates.csv')
# (190, '190_mds_avg_coordinates.csv')
# (192, '192_mds_avg_coordinates.csv')
# (195, '195_mds_avg_coordinates.csv')
# (196, '196_mds_avg_coordinates.csv')
# (197, '197_mds_avg_coordinates.csv')
# (198, '198_mds_avg_coordinates.csv')
# (199, '199_mds_avg_coordinates.csv')
# (200, '200_mds_avg_coordinates.csv')
# (202, '202_mds_avg_coordinates.csv')
# (203, '203_mds_avg_coordinates.csv')
# (204, '204_mds_avg_coordinates.csv')
# (206, '206_mds_avg_coordinates.csv')
# (209, '209_mds_avg_coordinates.csv')
# (212, '212_mds_avg_coordinates.csv')
# (214, '214_mds_avg_coordinates.csv')
# (215, '215_mds_avg_coordinates.csv')
# (219, '219_mds_avg_coordinates.csv')
# (220, '220_mds_avg_coordinates.csv')
# (222, '222_mds_avg_coordinates.csv')
# (549, '549_mds_avg_coordinates.csv')
# (224, '224_mds_avg_coordinates.csv')
# (226, '226_mds_avg_coordinates.csv')
# (227, '227_mds_avg_coordinates.csv')
# (229, '229_mds_avg_coordinates.csv')
# (231, '231_mds_avg_coordinates.csv')
# (233, '233_mds_avg_coordinates.csv')
# (234, '234_mds_avg_coordinates.csv')
# (238, '238_mds_avg_coordinates.csv')
# (239, '239_mds_avg_coordinates.csv')
# (241, '241_mds_avg_coordinates.csv')
# (248, '248_mds_avg_coordinates.csv')
# (250, '250_mds_avg_coordinates.csv')
# (252, '252_mds_avg_coordinates.csv')
# (554, '554_mds_avg_coordinates.csv')
# (255, '255_mds_avg_coordinates.csv')
# (258, '258_mds_avg_coordinates.csv')
# (618, '618_mds_avg_coordinates.csv')
# (261, '261_mds_avg_coordinates.csv')
# (262, '262_mds_avg_coordinates.csv')
# (263, '263_mds_avg_coordinates.csv')
# (264, '264_mds_avg_coordinates.csv')
# (265, '265_mds_avg_coordinates.csv')
# (267, '267_mds_avg_coordinates.csv')
# (272, '272_mds_avg_coordinates.csv')
# (275, '275_mds_avg_coordinates.csv')
# (276, '276_mds_avg_coordinates.csv')
# (278, '278_mds_avg_coordinates.csv')
# (279, '279_mds_avg_coordinates.csv')
# (283, '283_mds_avg_coordinates.csv')
# (289, '289_mds_avg_coordinates.csv')
# (290, '290_mds_avg_coordinates.csv')
# (561, '561_mds_avg_coordinates.csv')
# (299, '299_mds_avg_coordinates.csv')
# (301, '301_mds_avg_coordinates.csv')
# (302, '302_mds_avg_coordinates.csv')
# (304, '304_mds_avg_coordinates.csv')
# (307, '307_mds_avg_coordinates.csv')
# (312, '312_mds_avg_coordinates.csv')
# (316, '316_mds_avg_coordinates.csv')
# (317, '317_mds_avg_coordinates.csv')
# (318, '318_mds_avg_coordinates.csv')
# (319, '319_mds_avg_coordinates.csv')
# (320, '320_mds_avg_coordinates.csv')
# (322, '322_mds_avg_coordinates.csv')
# (325, '325_mds_avg_coordinates.csv')
# (327, '327_mds_avg_coordinates.csv')
# (328, '328_mds_avg_coordinates.csv')
# (329, '329_mds_avg_coordinates.csv')
# (330, '330_mds_avg_coordinates.csv')
# (331, '331_mds_avg_coordinates.csv')
# (332, '332_mds_avg_coordinates.csv')
# (336, '336_mds_avg_coordinates.csv')
# (338, '338_mds_avg_coordinates.csv')
# (339, '339_mds_avg_coordinates.csv')
# (340, '340_mds_avg_coordinates.csv')
# (342, '342_mds_avg_coordinates.csv')
# (350, '350_mds_avg_coordinates.csv')
# (351, '351_mds_avg_coordinates.csv')
# (656, '656_mds_avg_coordinates.csv')
# (354, '354_mds_avg_coordinates.csv')
# (359, '359_mds_avg_coordinates.csv')
# (360, '360_mds_avg_coordinates.csv')
# (364, '364_mds_avg_coordinates.csv')
# (61, '61_mds_avg_coordinates.csv')
# (370, '370_mds_avg_coordinates.csv')
# (373, '373_mds_avg_coordinates.csv')
# (376, '376_mds_avg_coordinates.csv')
# (383, '383_mds_avg_coordinates.csv')
# (388, '388_mds_avg_coordinates.csv')
# (389, '389_mds_avg_coordinates.csv')
# (390, '390_mds_avg_coordinates.csv')
# (392, '392_mds_avg_coordinates.csv')
# (396, '396_mds_avg_coordinates.csv')
# (397, '397_mds_avg_coordinates.csv')
# (401, '401_mds_avg_coordinates.csv')
# (67, '67_mds_avg_coordinates.csv')
# (407, '407_mds_avg_coordinates.csv')
# (416, '416_mds_avg_coordinates.csv')
# (420, '420_mds_avg_coordinates.csv')
# (426, '426_mds_avg_coordinates.csv')
# (430, '430_mds_avg_coordinates.csv')
# (433, '433_mds_avg_coordinates.csv')
# (439, '439_mds_avg_coordinates.csv')
# (445, '445_mds_avg_coordinates.csv')
# (447, '447_mds_avg_coordinates.csv')
# (450, '450_mds_avg_coordinates.csv')
# (75, '75_mds_avg_coordinates.csv')
# (545, '545_mds_avg_coordinates.csv')
# (464, '464_mds_avg_coordinates.csv')
# (466, '466_mds_avg_coordinates.csv')
# (479, '479_mds_avg_coordinates.csv')
# (480, '480_mds_avg_coordinates.csv')
# (516, '516_mds_avg_coordinates.csv')
# (488, '488_mds_avg_coordinates.csv')
# (489, '489_mds_avg_coordinates.csv')
# (492, '492_mds_avg_coordinates.csv')
# (493, '493_mds_avg_coordinates.csv')
# (494, '494_mds_avg_coordinates.csv')
# (495, '495_mds_avg_coordinates.csv')
# (499, '499_mds_avg_coordinates.csv')
# (501, '501_mds_avg_coordinates.csv')
# (502, '502_mds_avg_coordinates.csv')
# (507, '507_mds_avg_coordinates.csv')

# %%
norm = plt.Normalize()
norm.autoscale(sorted(masterfile['Year'].values))

cmap_red = plt.get_cmap('gist_rainbow')

for i, f in coordinate_files.items():
    coords = pd.read_csv('{0}/{1}'.format(dir_handle, f), index_col=0)
    coords_joined = coords.join(masterfile)
    fig = plt.figure(i, figsize=(12, 12))
    for group, data in coords_joined.groupby('Year'):
        plt.scatter(data['x'], data['y'], color=cmap_red(norm(group)), label=group)
    plt.title('Subgraph {0} MDS by Year'.format(i))
    plt.legend()
    plt.savefig('mds_coordinates/{0}_mds_by_year.pdf'.format(i))
    plt.close()

# %%
norm.autoscale(sorted(masterfile['Year'].values))

# %%
for group, data in masterfile.groupby('Year'):
    print(group, cmap_red(norm(group)))
# Out:
# (1980, (0.0, 0.0, 0.0, 1.0))
# (1981, (0.25622745098039218, 0.0, 0.29279215686274512, 1.0))
# (1982, (0.47845294117647058, 0.0, 0.54507058823529408, 1.0))
# (1983, (0.51501764705882347, 0.0, 0.58169019607843131, 1.0))
# (1984, (0.34507647058823532, 0.0, 0.62354117647058815, 1.0))
# (1985, (0.052284313725490472, 0.0, 0.66016078431372538, 1.0))
# (1986, (0.0, 0.0, 0.77258235294117639, 1.0))
# (1987, (0.0, 0.036603921568627448, 0.86670000000000003, 1.0))
# (1988, (0.0, 0.3294352941176471, 0.86670000000000003, 1.0))
# (1989, (0.0, 0.50067843137254897, 0.86670000000000003, 1.0))
# (1990, (0.0, 0.5843176470588235, 0.86670000000000003, 1.0))
# (1991, (0.0, 0.62877254901960777, 0.78042549019607865, 1.0))
# (1992, (0.0, 0.66669999999999996, 0.65885294117647075, 1.0))
# (1993, (0.0, 0.66669999999999996, 0.58561372549019608, 1.0))
# (1994, (0.0, 0.6510058823529411, 0.40781764705882351, 1.0))
# (1995, (0.0, 0.61438627450980388, 0.11502549019607844, 1.0))
# (1996, (0.0, 0.65488823529411766, 0.0, 1.0))
# (1997, (0.0, 0.73853137254901957, 0.0, 1.0))
# (1998, (0.0, 0.81177058823529413, 0.0, 1.0))
# (1999, (0.0, 0.89545098039215687, 0.0, 1.0))
# (2000, (0.0, 0.96863529411764704, 0.0, 1.0))
# (2001, (0.28756862745098039, 1.0, 0.0, 1.0))
# (2002, (0.6901647058823529, 1.0, 0.0, 1.0))
# (2003, (0.84702549019607842, 0.96207254901960781, 0.0, 1.0))
# (2004, (0.94114705882352923, 0.91761764705882387, 0.0, 1.0))
# (2005, (0.98299803921568629, 0.83397843137254901, 0.0, 1.0))
# (2006, (1.0, 0.74117647058823533, 0.0, 1.0))
# (2007, (1.0, 0.61568627450980395, 0.0, 1.0))
# (2008, (1.0, 0.31764705882352939, 0.0, 1.0))
# (2009, (0.98693137254901964, 0.0, 0.0, 1.0))
# (2010, (0.91374705882352947, 0.0, 0.0, 1.0))
# (2011, (0.84839019607843136, 0.0, 0.0, 1.0))
# (2012, (0.81177058823529413, 0.0, 0.0, 1.0))
# (2013, (0.80000000000000004, 0.36078431372549025, 0.36078431372549025, 1.0))
# (2014, (0.80000000000000004, 0.80000000000000004, 0.80000000000000004, 1.0))
