# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import math
import statsmodels.api as sm 

from itertools import combinations, product, permutations
from __future__ import division
from collections import Counter
from scipy.stats.mstats import mquantiles
from scipy.stats import norm, expon, poisson, binom
from scipy.misc import comb
from IPython.display import Math
from networkx.readwrite import json_graph 
from geopy.geocoders import GeoNames
from geopy.geocoders import GoogleV3

# %matplotlib inline

# %%
def golden_figsize(height):
    """
    Assuming height dimension is the shorter one, the width should be:
    (1 + 5**0.5)/2
    
    This function thus returns the (width, height) tuple which is
    computed to be in a golden ratio.
    """
    width = height * (1 + 5**0.5) / 2
    return (width, height)

# %%
G = nx.read_gpickle('20141103 All IRD Final Graph.pkl')

# %%
geocoder = GoogleV3(timeout=5)

# %%
G.nodes()[15]
# Out:
# 'A/Texas/44301765/2009'

# %%
# Nichola has coded them as wild/domestic and avian/mammalian. I will add these into the graph. 

# Load the data
df = pd.read_csv('Country-Species_to_be_Coded_by_Nichola.csv', index_col=0)

# Make it into a dicitonary where each entry is (country, species):habitat/setting
ecotype_map = dict()

for row, data in df.iterrows():
    country = data['Country']
    species = data['Species']
    ecotype = data['Habitat/setting']

    ecotype_map[(country, species)] = ecotype

    
def get_country_location_pairs(G):
    search_terms = set()
    node_search_terms = dict()
    for n, d in G.nodes(data=True):
        country = d['country']
        specific_region = n.split('/')[-3]
        
        cleaned_country = country.replace('_', ' ')
        
        if specific_region != cleaned_country:
            search_term = '{0}_{1}'.format(cleaned_country, specific_region)
    
        else:
            search_term = cleaned_country
        
        search_terms.add(search_term)
        node_search_terms[n] = search_term.replace('_', ' ')
    return search_terms, node_search_terms

countries_to_search, node_search_terms = get_country_location_pairs(G)
countries_to_search
node_search_terms
# Out:
# {'A/mallard/Interior Alaska/6MP0160AR1/2006': 'USA Interior Alaska',
#  'A/swine/Hong Kong/NS970/2012': 'Hong Kong',
#  'A/New York/132/2002': 'USA New York',
#  'A/guinea fowl/New Jersey/7290-19/1994': 'USA New Jersey',
#  'A/California/VRDL88/2009': 'USA California',
#  'A/tufted duck/PT/13771/2006': 'Portugal PT',
#  'A/Boston/YGA_00093/2012': 'USA Boston',
#  'A/village chicken/Kyaing Tong/2433/2007': 'Myanmar Kyaing Tong',
#  'A/HaNoi/Q163/2007': 'Viet Nam HaNoi',
#  'A/baikal teal/Korea/Donglim3/2014': 'South Korea Korea',
#  'A/northern pintail/Interior Alaska/9BM6248R0/2009': 'USA Interior Alaska',
#  'A/greater white-fronted goose/California/44358-089/2007': 'USA California',
#  'A/Duck/Nanchang/2-0485/2000': 'China Nanchang',
#  'A/Houston/1H/2009': 'USA Houston',
#  'A/Texas/44301765/2009': 'USA Texas',
#  'A/Russia/61/2009': 'Russia',
#  'A/swine/Minnesota/SG1236/2005': 'USA Minnesota',
#  'A/mallard/Wisconsin/986/1982': 'USA Wisconsin',
#  'A/California/NHRC0008/2005': 'USA California',
#  'A/mallard/Ohio/99/1989': 'USA Ohio',
#  'A/mallard/Sweden/80114/2008': 'Sweden',
#  'A/Canterbury/05/2001': 'New Zealand Canterbury',
#  'A/Canterbury/05/2002': 'New Zealand Canterbury',
#  'A/Malaysia/2143035/2009': 'Malaysia',
#  'A/Boston/YGA_00035/2013': 'USA Boston',
#  'A/Boston/DOA2-144/2013': 'USA Boston',
#  'A/Tennessee/F2048A/2011': 'USA Tennessee',
#  'A/mallard/Sweden/68583/2007': 'Sweden',
#  'A/Florida/UR07-0102/2008': 'USA Florida',
#  'A/England/547/2003': 'United Kingdom England',
#  'A/Pennsylvania/02/2011': 'USA Pennsylvania',
#  'A/Peru/PER359/2012': 'Peru',
#  'A/duck/Jiangxi/3286/2009': 'China Jiangxi',
#  'A/chicken/Bhutan/248015/2010': 'Bhutan',
#  'A/ruddy turnstone/New Jersey/AI09-727/2009': 'USA New Jersey',
#  'A/New York/366/2004': 'USA New York',
#  'A/swine/Ohio/09SW100/2009': 'USA Ohio',
#  'A/England/431/2009': 'United Kingdom England',
#  'A/England/05140206/2010': 'United Kingdom England',
#  'A/Boston/110/2009': 'USA Boston',
#  'A/duck/Hunan/S3047/2009': 'China Hunan',
#  'A/blue-winged teal/North Dakota/Sg-00740/2008': 'USA North Dakota',
#  'A/South Carolina/WRSP520/2009': 'USA South Carolina',
#  'A/Taiwan/8542/2009': 'Taiwan',
#  'A/black-billed magpie/Guangxi/31/2005': 'China Guangxi',
#  'A/Peru/PER018/2012': 'Peru',
#  'A/equine/California/103/1982': 'USA California',
#  'A/New York/6537/2009': 'USA New York',
#  'A/TayNguyen/TN405/2005': 'Viet Nam TayNguyen',
#  'A/Texas/45122036/2009': 'USA Texas',
#  'A/ruddy turnstone/Delaware Bay/82/1994': 'USA Delaware Bay',
#  'A/ruddy turnstone/NJ/1605/2001': 'USA NJ',
#  'A/Boston/DOA2-102/2012': 'USA Boston',
#  'A/Western Australia/3/2000': 'Australia Western Australia',
#  'A/shorebird/Delaware Bay/382/2008': 'USA Delaware Bay',
#  'A/chicken/Guangxi/LS/2013': 'China Guangxi',
#  'A/Bangkok/INS482/2010': 'Thailand Bangkok',
#  'A/California/VRDL228/2009': 'USA California',
#  'A/wood duck/Wisconsin/11OS2912/2011': 'USA Wisconsin',
#  'A/chicken/Chiba/1/2011': 'Japan Chiba',
#  'A/bufflehead/Wisconsin/10OS3204/2010': 'USA Wisconsin',
#  'A/Bethesda/SP506/2009': 'USA Bethesda',
#  'A/Khon Kaen/INS457/2010': 'Thailand Khon Kaen',
#  'A/Boston/YGA_00022/2013': 'USA Boston',
#  'A/Hong Kong/HKU3/2004': 'Hong Kong',
#  'A/Canterbury/303/2004': 'New Zealand Canterbury',
#  'A/mink/South Dakota/A01279427/2012': 'USA South Dakota',
#  'A/American green-winged teal/Ohio/13OS2106/2013': 'USA Ohio',
#  'A/Nicaragua/6966_06/2013': 'Nicaragua',
#  'A/California/VRDL286/2009': 'USA California',
#  'A/bean goose/Tyva/10/2009': 'Russia Tyva',
#  'A/Boston/YGA_01106/2012': 'USA Boston',
#  'A/Nicaragua/AGA2-27/2011': 'Nicaragua',
#  'A/Helsinki/942/2012': 'Finland Helsinki',
#  'A/northern shoveler/Alaska/7MP1669B/2007': 'USA Alaska',
#  'A/mallard/Interior Alaska/10BM09561R0/2010': 'USA Interior Alaska',
#  'A/mallard/California/2867/2012': 'USA California',
#  'A/England/05060444/2010': 'United Kingdom England',
#  'A/Boston/YGA_00096/2013': 'USA Boston',
#  'A/England/03380426/2010': 'United Kingdom England',
#  'A/ruddy turnstone/Delaware Bay/123/2007': 'USA Delaware Bay',
#  'A/swine/Texas/A01104004/2011': 'USA Texas',
#  'A/swine/Jiangsu/zg17/2011': 'China Jiangsu',
#  'A/Hong Kong/HKU61/2005': 'Hong Kong',
#  'A/Texas/45101424/2009': 'USA Texas',
#  'A/mallard/Wisconsin/222/1982': 'USA Wisconsin',
#  'A/Nicaragua/AGA2-41/2011': 'Nicaragua',
#  'A/Texas/UR06-0359/2007': 'USA Texas',
#  'A/goose/Tripura/103596/2008': 'India Tripura',
#  'A/swine/Guangxi/2897/2011': 'China Guangxi',
#  'A/New York/116/2002': 'USA New York',
#  'A/Managua/4064.01/2009': 'Nicaragua Managua',
#  'A/mallard/California/2521P/2011': 'USA California',
#  'A/HaNoi/ARI172/2003': 'Viet Nam HaNoi',
#  'A/knot/DE/2552/1987': 'USA DE',
#  'A/blue-winged teal/Wisconsin/134/1980': 'USA Wisconsin',
#  'A/Viet Nam/11032010/2009': 'Viet Nam',
#  'A/swine/Langefoerden/IDT14189/2011': 'Germany Langefoerden',
#  'A/New York/281/2001': 'USA New York',
#  'A/South Australia/36/2000': 'Australia South Australia',
#  'A/New York/WC-LVD-14-051/2014': 'USA New York',
#  'A/Peru/PER169/2010': 'Peru',
#  'A/Singapore/GP4369/2010': 'Singapore',
#  'A/Athens/INS398/2010': 'Greece Athens',
#  'A/swine/North Carolina/SG1477/2005': 'USA North Carolina',
#  'A/Taiwan/2649/2011': 'Taiwan',
#  'A/Cygnus olor/Caspian Sea/2006': 'Russia Cygnus olor',
#  'A/Mexico City/WRAIR3579N/2010': 'Mexico Mexico City',
#  'A/Taiwan/167/2009': 'Taiwan',
#  'A/Moscow/IIV-33/2010': 'Russia Moscow',
#  'A/mallard/Ohio/10OS1354/2010': 'USA Ohio',
#  'A/Peru/PER363/2012': 'Peru',
#  'A/American wigeon/California/HKWF371/2007': 'USA California',
#  'A/Chile/87/2010': 'Chile',
#  'A/Boston/127/2009': 'USA Boston',
#  'A/Managua/34/2007': 'Nicaragua Managua',
#  'A/shorebird/Delaware Bay/43/1995': 'USA Delaware Bay',
#  'A/Nicaragua/6369_04/2013': 'Nicaragua',
#  'A/Hong Kong/HKU35/2004': 'Hong Kong',
#  'A/Texas/27/2012': 'USA Texas',
#  'A/Warsaw/INS148/2009': 'Poland Warsaw',
#  'A/Houston/JMM_147/2013': 'USA Houston',
#  'A/mallard/Netherlands/13/2001': 'Netherlands',
#  'A/New York/4434/2009': 'USA New York',
#  'A/shorebird/Delaware Bay/11/1995': 'USA Delaware Bay',
#  'A/California/VRDL296/2009': 'USA California',
#  'A/swine/Guangdong/2670/2010': 'China Guangdong',
#  'A/Texas/UR06-0176/2007': 'USA Texas',
#  'A/pintail/Alaska/279/2005': 'USA Alaska',
#  'A/Munich/INS363/2009': 'Germany Munich',
#  'A/mallard/Alberta/289/2009': 'Canada Alberta',
#  'A/shorebird/Delaware/350/2006': 'USA Delaware',
#  'A/Queensland/56/2005': 'Australia Queensland',
#  'A/New York/770/1993': 'USA New York',
#  'A/Hong Kong/1/1997': 'Hong Kong',
#  'A/Oklahoma/UR06-0063/2007': 'USA Oklahoma',
#  'A/chicken/Guangdong/S1311/2010': 'China Guangdong',
#  'A/swine/Jiangsu/zg12/2011': 'China Jiangsu',
#  'A/shorebird/Delaware Bay/289/2005': 'USA Delaware Bay',
#  'A/Boston/YGA_01091/2012': 'USA Boston',
#  'A/laughing gull/New Jersey/AI09-271/2009': 'USA New Jersey',
#  'A/Athens/INS123/2009': 'Greece Athens',
#  'A/African Stonechat/Vietnam/8/2009': 'Viet Nam Vietnam',
#  'A/Wisconsin/629-D02455/2009': 'USA Wisconsin',
#  'A/Wisconsin/629-D00908/2009': 'USA Wisconsin',
#  'A/duck/Fujian/3193/2005': 'China Fujian',
#  'A/swine/Guangdong/2419/2010': 'China Guangdong',
#  'A/northern pintail/Interior Alaska/9BM8109R0/2009': 'USA Interior Alaska',
#  'A/ruddy turnstone/Delaware Bay/176/1994': 'USA Delaware Bay',
#  'A/Boston/YGA_01158/2013': 'USA Boston',
#  'A/duck/Anhui/1/06': 'China Anhui',
#  'A/mallard/Illinois/4124/2009': 'USA Illinois',
#  'A/northern shoveler/Mississippi/11OS5875/2011': 'USA Mississippi',
#  'A/chicken/Kuwait/KISR3/2007': 'Kuwait',
#  'A/American green-winged teal/Interior Alaska/10BM05439R0/2010': 'USA Interior Alaska',
#  'A/New York/1074/2007': 'USA New York',
#  'A/gadwall/California/44287-543/2007': 'USA California',
#  'A/duck/Taiwan/4360/2013': 'Taiwan',
#  'A/mallard/Minnesota/Sg-00059/2007': 'USA Minnesota',
#  'A/Kentucky/UR06-0258/2007': 'USA Kentucky',
#  'A/swine/Hong Kong/NS549/2012': 'Hong Kong',
#  'A/Terrassa/INS173/2009': 'Spain Terrassa',
#  'A/Thailand/CU68/2006': 'Thailand',
#  'A/Managua/1909.02/2009': 'Nicaragua Managua',
#  'A/California/VRDL357/2009': 'USA California',
#  'A/England/246/2009': 'United Kingdom England',
#  'A/chicken/Nigeria/957-20/2006': 'Nigeria',
#  'A/mallard/Wisconsin/2712/2009': 'USA Wisconsin',
#  'A/mallard/Nova Scotia/02286/2007': 'Canada Nova Scotia',
#  'A/northern pintail/California/2548/2010': 'USA California',
#  'A/ruddy turnstone/Delaware Bay/2830/1987': 'USA Delaware Bay',
#  'A/duck/Fujian/7119/2007': 'China Fujian',
#  'A/Canterbury/36/2000': 'New Zealand Canterbury',
#  'A/Wisconsin/629-D02299/2009': 'USA Wisconsin',
#  'A/ruddy turnstone/Delaware Bay/271/1995': 'USA Delaware Bay',
#  'A/swine/Guangxi/3212/2011': 'China Guangxi',
#  'A/mallard/Interior Alaska/9BM2750R0/2009': 'USA Interior Alaska',
#  'A/mallard/Alberta/11/91': 'Canada Alberta',
#  'A/England/220/2009': 'United Kingdom England',
#  'A/blue-winged teal/Iowa/10OS2624/2010': 'USA Iowa',
#  'A/San Salvador/WRAIR3537T/2010': 'El Salvador San Salvador',
#  'A/New York/387/2004': 'USA New York',
#  'A/Chicago/YGA_04065/2012': 'USA Chicago',
#  'A/Phillipines/2/1982': 'Philippines Phillipines',
#  'A/mallard/Sweden/1417/2002': 'Sweden',
#  'A/American black duck/New Brunswick/03398/2009': 'Canada New Brunswick',
#  'A/northern shoveler/California/HKWF392sm/2007': 'USA California',
#  'A/blue-winged teal/Ohio/1858/2006': 'USA Ohio',
#  'A/Wisconsin/629-D02367/2009': 'USA Wisconsin',
#  'A/New York/333/1999': 'USA New York',
#  'A/northern shoveler/California/3628/2011': 'USA California',
#  'A/Qatar/AF02/2008': 'Qatar',
#  'A/Athens/INS559/2011': 'Greece Athens',
#  'A/swine/Oklahoma/SG1349/2010': 'USA Oklahoma',
#  'A/environment/Bangladesh/19336/2013': 'Bangladesh',
#  'A/ruddy turnstone/Delaware Bay/189/1994': 'USA Delaware Bay',
#  'A/swine/Guangxi/3843/2011': 'China Guangxi',
#  'A/Sydney/DD3-05/2010': 'Australia Sydney',
#  'A/New York/3196/2009': 'USA New York',
#  'A/Hong Kong/HKU32/2004': 'Hong Kong',
#  'A/mallard/Maryland/231/2001': 'USA Maryland',
#  'A/northern shoveler/Hong Kong/MPL961/2011': 'Hong Kong',
#  'A/swine/Hong Kong/2857/2011': 'Hong Kong',
#  'A/Kentucky/UR06-0046/2007': 'USA Kentucky',
#  'A/Malaysia/1912346/2007': 'Malaysia',
#  'A/swine/Ohio/09SW98/2009': 'USA Ohio',
#  'A/shorebird/Delaware/22/06': 'USA Delaware',
#  'A/Santa Cruz/111/2012': 'Bolivia Santa Cruz',
#  'A/chicken/Bangladesh/15079/2012': 'Bangladesh',
#  'A/Wisconsin/629-D01909/2009': 'USA Wisconsin',
#  'A/duck/Fujian/6841/2007': 'China Fujian',
#  'A/lesser scaup/Alberta/206/1995': 'Canada Alberta',
#  'A/ruddy turnstone/New Jersey/1321416/2005': 'USA New Jersey',
#  'A/Netherlands/2143/2009': 'Netherlands',
#  'A/mallard/Sweden/3151/2003': 'Sweden',
#  'A/Sydney/DD3-59/2011': 'Australia Sydney',
#  'A/Athens/INS421/2010': 'Greece Athens',
#  'A/swine/Indiana/A00968322/2010': 'USA Indiana',
#  'A/mallard/Illinois/10OS3599/2010': 'USA Illinois',
#  'A/mallard/California/2555V/2011': 'USA California',
#  'A/Copenhagen/INS96/2009': 'Denmark Copenhagen',
#  'A/black duck/Western Australia/4954/1983': 'Australia Western Australia',
#  'A/Boston/YGA_00043/2013': 'USA Boston',
#  'A/Boston/YGA_01006/2012': 'USA Boston',
#  'A/swine/Indiana/13TOSU1052/2013': 'USA Indiana',
#  'A/northern pintail/Interior Alaska/6MP0814/2006': 'USA Interior Alaska',
#  'A/Wisconsin/629-D00859/2009': 'USA Wisconsin',
#  'A/muscovy duck/Vietnam/LBM398/2013': 'Viet Nam Vietnam',
#  'A/mallard/Wisconsin/920/1982': 'USA Wisconsin',
#  'A/Peru/PER308/2010': 'Peru',
#  'A/New York/6630/2009': 'USA New York',
#  'A/mallard/Sweden/80190/2008': 'Sweden',
#  'A/swine/Michigan/A01203498/2012': 'USA Michigan',
#  'A/Northern Ireland/04380108/2010': 'United Kingdom Northern Ireland',
#  'A/Illinois/UR06-0030/2007': 'USA Illinois',
#  'A/ThaiBinh/TB289/2008': 'Viet Nam ThaiBinh',
#  'A/mallard/Sweden/2823/2003': 'Sweden',
#  'A/Santa Clara/YGA_03024/2013': 'USA Santa Clara',
#  'A/swine/England/17787/2000': 'United Kingdom England',
#  'A/New York/95/2002': 'USA New York',
#  'A/environment/California/7871/2008': 'USA California',
#  'A/Myanmar/JP90/2009': 'Myanmar',
#  'A/environment/Delaware/234/2005': 'USA Delaware',
#  'A/American green-winged teal/Ohio/13OS2097/2013': 'USA Ohio',
#  'A/Managua/3244.02/2010': 'Nicaragua Managua',
#  'A/duck/Fujian/4125/2005': 'China Fujian',
#  'A/chicken/Oita/8/2004': 'Japan Oita',
#  'A/New York/WC-LVD-13-030/2013': 'USA New York',
#  'A/Boston/YGA_02017/2012': 'USA Boston',
#  'A/Nicaragua/7828_01/2013': 'Nicaragua',
#  'A/Maryland/07/2011': 'USA Maryland',
#  'A/mallard/Minnesota/AI07-3136/2007': 'USA Minnesota',
#  'A/mallard/Sweden/1665/2002': 'Sweden',
#  'A/swine/Hong Kong/NS3815/2010': 'Hong Kong',
#  'A/mallard/Interior Alaska/10BM04626R0/2010': 'USA Interior Alaska',
#  'A/Helsinki/39/2013': 'Finland Helsinki',
#  'A/swine/North Carolina/A01364596/2013': 'USA North Carolina',
#  'A/Nicaragua/AGA2-53/2011': 'Nicaragua',
#  'A/mallard/Sweden/5803/2005': 'Sweden',
#  'A/New York/240/1998': 'USA New York',
#  'A/Peru/PER295/2010': 'Peru',
#  'A/Baikal teal/Korea/H66/2014': 'South Korea Korea',
#  'A/mallard/Sweden/1621/2002': 'Sweden',
#  'A/swine/MB/54/2009': 'Canada MB',
#  'A/Nicaragua/AGA2-05/2012': 'Nicaragua',
#  'A/Georgia/04/2010': 'USA Georgia',
#  'A/swine/Minnesota/A01301908/2012': 'USA Minnesota',
#  'A/Wisconsin/629-D01414/2009': 'USA Wisconsin',
#  'A/chicken/Israel/853/2005': 'Israel',
#  'A/HaNoi/Q177/2006': 'Viet Nam HaNoi',
#  'A/Peru/PER017/2011': 'Peru',
#  'A/northern shoveler/Mississippi/10OS4526/2010': 'USA Mississippi',
#  'A/Houston/3OS/2009': 'USA Houston',
#  'A/Peru/PER061/2011': 'Peru',
#  'A/duck/Guangdong/23/2004': 'China Guangdong',
#  'A/blue-winged teal/Canada/3240/2011': 'Canada',
#  'A/duck/Hunan/177/2005': 'China Hunan',
#  'A/Wisconsin/629-D00636/2009': 'USA Wisconsin',
#  'A/swine/Henan/Y1/2009': 'China Henan',
#  'A/mallard/Alberta/237/2003': 'Canada Alberta',
#  'A/New York/18/2003': 'USA New York',
#  'A/duck/Shantou/1586/2001': 'China Shantou',
#  'A/swine/Hong Kong/3276/2011': 'Hong Kong',
#  'A/mallard/Ohio/83/1986': 'USA Ohio',
#  'A/Athens/INS329/2009': 'Greece Athens',
#  'A/Australia/28/2009': 'Australia',
#  'A/Lyon/1373/1991': 'France Lyon',
#  'A/Boston/637/2009': 'USA Boston',
#  'A/Managua/5953.01/2009': 'Nicaragua Managua',
#  'A/Nizhnii Novgorod/CRIE-BLM/2011': 'Russia Nizhnii Novgorod',
#  'A/swine/England/483/2006': 'United Kingdom England',
#  'A/ruddy turnstone/Delaware Bay/87/1994': 'USA Delaware Bay',
#  'A/swine/Illinois/A00857134/2011': 'USA Illinois',
#  'A/Khon Kaen/INS453/2010': 'Thailand Khon Kaen',
#  'A/swine/Korea/CY02-07/2012': 'South Korea Korea',
#  'A/Wisconsin/629-D01847/2009': 'USA Wisconsin',
#  'A/chicken/Moscow/2/2007': 'Russia Moscow',
#  'A/bufflehead/Wisconsin/11OS3570/2011': 'USA Wisconsin',
#  'A/swine/North Carolina/SG1479/2005': 'USA North Carolina',
#  'A/mallard/Iowa/10OS2692/2010': 'USA Iowa',
#  'A/Swine/Fujian/F1/2001': 'China Fujian',
#  'A/mallard/California/942V/2013': 'USA California',
#  'A/New York/1116/2008': 'USA New York',
#  'A/Santa Clara/YGA_03046/2013': 'USA Santa Clara',
#  'A/pintail duck/ALB/169/1980': 'Canada ALB',
#  'A/duck/Zhejiang/0611-8/2011': 'China Zhejiang',
#  'A/Brussels/INS71/2009': 'Belgium Brussels',
#  'A/Boston/92/2008': 'USA Boston',
#  'A/Boston/92/2009': 'USA Boston',
#  'A/Ohio/UR06-0443/2007': 'USA Ohio',
#  'A/equine/Heilongjiang/SS1/2013': 'China Heilongjiang',
#  'A/chicken/Miyazaki/12/2011': 'Japan Miyazaki',
#  'A/swine/Iowa/13H098/2013': 'USA Iowa',
#  'A/chicken/Egypt/S5018D/2012': 'Egypt',
#  'A/mallard/California/3314/2012': 'USA California',
#  'A/England/518/2003': 'United Kingdom England',
#  'A/duck/Hunan/S11893/2012': 'China Hunan',
#  'A/Managua/5801.02/2010': 'Nicaragua Managua',
#  'A/duck/Fujian/5728/2008': 'China Fujian',
#  'A/Hubei/1/2010': 'China Hubei',
#  'A/black scoter/Maine/276/2011': 'USA Maine',
#  'A/ruddy turnstone/Delaware Bay/96/2002': 'USA Delaware Bay',
#  'A/Boston/YGA_01079/2012': 'USA Boston',
#  'A/New York/WC-LVD-13-019/2013': 'USA New York',
#  'A/New York/534/1998': 'USA New York',
#  'A/Wisconsin/629-S0220/2009': 'USA Wisconsin',
#  'A/New York/163/1999': 'USA New York',
#  'A/swine/Banten/UT6008/2007': 'Indonesia Banten',
#  'A/shorebird/Delaware Bay/211/2000': 'USA Delaware Bay',
#  'A/California/VRDL170/2009': 'USA California',
#  'A/Texas/JMM_50/2012': 'USA Texas',
#  'A/Managua/1984.02/2009': 'Nicaragua Managua',
#  'A/swine/Iowa/A01202640/2011': 'USA Iowa',
#  'A/India/P1112874/2011': 'India',
#  'A/swine/Freren/IDT13837-1/2011': 'Germany Freren',
#  'A/mallard/Alberta/130/2007': 'Canada Alberta',
#  'A/Thailand/CU-B4148/2010': 'Thailand',
#  'A/northern pintail/California/469993/2006': 'USA California',
#  'A/Mississippi/UR06-0242/2007': 'USA Mississippi',
#  'A/blue-winged teal/Texas/AI09-6182/2009': 'USA Texas',
#  'A/Queensland/60/2005': 'Australia Queensland',
#  'A/California/VRDL277/2009': 'USA California',
#  'A/mallard/Alberta/235/1999': 'Canada Alberta',
#  'A/northern pintail/Interior Alaska/9BM10987R0/2009': 'USA Interior Alaska',
#  'A/New York/1160/2009': 'USA New York',
#  'A/swine/Iowa/SG1290/2007': 'USA Iowa',
#  'A/ruddy turnstone/Delaware Bay/155/1995': 'USA Delaware Bay',
#  'A/Vermont/UR06-0470/2007': 'USA Vermont',
#  'A/New York/302/2001': 'USA New York',
#  'A/redhead/Ohio/13OS0507/2013': 'USA Ohio',
#  'A/Wisconsin/629-D01469/2009': 'USA Wisconsin',
#  'A/environment/Maryland/267/2006': 'USA Maryland',
#  'A/laughing gull/Delaware Bay/2623/1987': 'USA Delaware Bay',
#  'A/Boston/DOA2-104/2012': 'USA Boston',
#  'A/American black duck/Prince Edward Island/02661/2007': 'Canada Prince Edward Island',
#  'A/swine/Ohio/10SW122/2010': 'USA Ohio',
#  'A/environment/Delaware/245/2005': 'USA Delaware',
#  'A/New York/434/2000': 'USA New York',
#  'A/New York/6939/2009': 'USA New York',
#  'A/Texas/JMM_1/2012': 'USA Texas',
#  'A/Queensland/24/2002': 'Australia Queensland',
#  'A/Florida/UR06-0265/2007': 'USA Florida',
#  'A/mallard/Minnesota/Sg-01042/2008': 'USA Minnesota',
#  'A/District of Columbia/INS18/2009': 'USA District of Columbia',
#  'A/duck/Egypt/M2583C/2010': 'Egypt',
#  'A/northern pintail/Interior Alaska/9BM7254R0/2009': 'USA Interior Alaska',
#  'A/Wroclaw/INS437/2009': 'Poland Wroclaw',
#  'A/Nicaragua/AGA2-23/2011': 'Nicaragua',
#  'A/swine/Kansas/10-91088/2010': 'USA Kansas',
#  'A/American green-winged teal/Mississippi/12OS191/2012': 'USA Mississippi',
#  'A/Aarhus/INS610/2011': 'Denmark Aarhus',
#  'A/New York/402/2001': 'USA New York',
#  'A/chicken/Hubei/489/2004': 'China Hubei',
#  'A/duck/Angthong/NIAH8246/2004': 'Thailand Angthong',
#  'A/New York/4576/2009': 'USA New York',
#  'A/Singapore/GP2257/2010': 'Singapore',
#  'A/Boston/YGA_01017/2012': 'USA Boston',
#  'A/mallard/Alberta/279/2006': 'Canada Alberta',
#  'A/Scotland/52/2003': 'United Kingdom Scotland',
#  'A/mallard/Huadong/Y/2003': 'China Huadong',
#  'A/mallard/California/6517/2008': 'USA California',
#  'A/mallard/Interior Alaska/10BM11420R0/2010': 'USA Interior Alaska',
#  'A/Thailand/CU379/2008': 'Thailand',
#  'A/chicken/Zhejiang/329/2011': 'China Zhejiang',
#  'A/Peru/PER384/2012': 'Peru',
#  'A/New York/803/1993': 'USA New York',
#  'A/American black duck/New Brunswick/02659/2007': 'Canada New Brunswick',
#  'A/TayNguyen/TN343/2005': 'Viet Nam TayNguyen',
#  'A/domestic duck/Germany/R2048/2007': 'Germany',
#  'A/Memphis/5/2003': 'USA Memphis',
#  'A/Wisconsin/629-S0435/2009': 'USA Wisconsin',
#  'A/duck/Fujian/S4081/2008': 'China Fujian',
#  'A/LongAn/HCM665/2006': 'Viet Nam LongAn',
#  'A/green-winged teal/Nova Scotia/00354/2010': 'Canada Nova Scotia',
#  'A/Mexico/24027/2009': 'Mexico',
#  'A/chicken/Israel/330/2008': 'Israel',
#  'A/swine/Iowa/24297/1991': 'USA Iowa',
#  'A/open-billed stork/Nakhonsawan/BBD1621J/05': 'Thailand Nakhonsawan',
#  'A/swine/Ohio/09SW63/2009': 'USA Ohio',
#  'A/Houston/JMM_160/2013': 'USA Houston',
#  'A/mallard/California/6469/2008': 'USA California',
#  'A/New York/383/2004': 'USA New York',
#  'A/Nicaragua/AGA2-72/2012': 'Nicaragua',
#  'A/mallard/Interior Alaska/9BM1964/2009': 'USA Interior Alaska',
#  'A/blue-winged teal/New Brunswick/00775/2010': 'Canada New Brunswick',
#  'A/swine/Hong Kong/1290/1993': 'Hong Kong',
#  'A/Peru/PER289/2011': 'Peru',
#  'A/American black duck/New Brunswick/00484/2010': 'Canada New Brunswick',
#  'A/chicken/Qalubia/CAI19/2008': 'Egypt Qalubia',
#  'A/swine/Illinois/A01328923/2012': 'USA Illinois',
#  'A/Houston/JMM_157/2013': 'USA Houston',
#  'A/American black duck/Nova Scotia/00086/2010': 'Canada Nova Scotia',
#  'A/swine/Mexico/Ver29/2010': 'Mexico',
#  'A/Kentucky/UR07-0085/2008': 'USA Kentucky',
#  'A/Athens/INS327/2009': 'Greece Athens',
#  'A/mallard/Interior Alaska/9BM10537R0/2009': 'USA Interior Alaska',
#  'A/Peru/PER036/2011': 'Peru',
#  'A/California/VRDL391/2009': 'USA California',
#  'A/New York/1154/2008': 'USA New York',
#  'A/Bangkok/INS581/2010': 'Thailand Bangkok',
#  'A/mallard/Minnesota/182772/1998': 'USA Minnesota',
#  'A/Boston/62/2009': 'USA Boston',
#  'A/Boston/DOA2-155/2012': 'USA Boston',
#  'A/New York/1059/2007': 'USA New York',
#  'A/swine/Ohio/09SW1490M/2009': 'USA Ohio',
#  'A/mallard/Minnesota/AI08-3881/2008': 'USA Minnesota',
#  'A/Pensacola/INS212/2009': 'USA Pensacola',
#  'A/Boston/DOA55/2011': 'USA Boston',
#  'A/Boston/DOA2-194/2013': 'USA Boston',
#  'A/Bethesda/SP508/2009': 'USA Bethesda',
#  'A/New South Wales/15/1999': 'Australia New South Wales',
#  'A/Virginia/UR06-0021/2007': 'USA Virginia',
#  'A/Memphis/47/1983': 'USA Memphis',
#  'A/Bronx/INS3_674/2012': 'USA Bronx',
#  'A/shorebird/Delaware/472/2007': 'USA Delaware',
#  'A/Peru/PER055/2011': 'Peru',
#  'A/Boston/YGA_01059/2012': 'USA Boston',
#  'A/chicken/Shanghai/A/2010': 'China Shanghai',
#  'A/Waikato/54/2003': 'New Zealand Waikato',
#  'A/mallard/Interior Alaska/10BM10324R0/2010': 'USA Interior Alaska',
#  'A/Texas/JMS356/2009': 'USA Texas',
#  'A/North Fitzroy/INS464/2010': 'Australia North Fitzroy',
#  'A/common goldeneye/Mongolia/12/2006': 'Mongolia',
#  'A/shorebird/Delaware Bay/4/2002': 'USA Delaware Bay',
#  'A/Singapore/GP4523/2010': 'Singapore',
#  'A/mallard/Sweden/1981/2003': 'Sweden',
#  'A/Peru/PER361/2010': 'Peru',
#  'A/Chicago/YGA_04092/2012': 'USA Chicago',
#  'A/environment/Hunan/6-69/2008': 'China Hunan',
#  'A/San Diego/INS16/2009': 'USA San Diego',
#  'A/New York/3470/2009': 'USA New York',
#  'A/mallard/Alberta/590/2010': 'Canada Alberta',
#  'A/swine/Hong Kong/4046/2011': 'Hong Kong',
#  'A/greylag goose/Iceland/0921/2011': 'Iceland',
#  'A/chicken/Taiwan/683/2012': 'Taiwan',
#  'A/swine/Manitoba/01799/2007': 'Canada Manitoba',
#  'A/Western Australia/1/2000': 'Australia Western Australia',
#  'A/Chicago/YGA_04150/2013': 'USA Chicago',
#  'A/England/766/2009': 'United Kingdom England',
#  'A/little grebe/Thailand/Phichit-01/2004': 'Thailand',
#  'A/swine/Chachoengsao/NIAH107037-28/2011': 'Thailand Chachoengsao',
#  'A/blue-winged teal/Iowa/13OS2368/2013': 'USA Iowa',
#  'A/New York/3743/2009': 'USA New York',
#  'A/swine/Hong Kong/1780/2008': 'Hong Kong',
#  'A/mallard/Washington/44338-034/2007': 'USA Washington',
#  'A/shorebird/Delaware Bay/296/2008': 'USA Delaware Bay',
#  'A/Memphis/14/1983': 'USA Memphis',
#  'A/Bangkok/INS492/2010': 'Thailand Bangkok',
#  'A/Maryland/03/2011': 'USA Maryland',
#  'A/Chicago/YGA_04114/2012': 'USA Chicago',
#  'A/California/UR06-0463/2007': 'USA California',
#  'A/Singapore/KK100/2010': 'Singapore',
#  'A/pintail/Alberta/84/2000': 'Canada Alberta',
#  'A/Managua/5259.02/2010': 'Nicaragua Managua',
#  'A/mallard/California/8518/2008': 'USA California',
#  'A/Pensacola/INS107/2009': 'USA Pensacola',
#  'A/Nymc X-157-A/St.Petersburg/8/2006)_RX': '-N/A- St.Petersburg',
#  'A/Frankfurt/INS305/2009': 'Germany Frankfurt',
#  'A/swine/Iowa/13C095/2013': 'USA Iowa',
#  'A/Bangkok/INS583/2010': 'Thailand Bangkok',
#  'A/New Mexico/06/2009': 'USA New Mexico',
#  'A/northern pintail/Interior Alaska/9BM8273R0/2009': 'USA Interior Alaska',
#  'A/California/VRDL27/2009': 'USA California',
#  'A/chicken/Germany/R3294/2007': 'Germany',
#  'A/New York/6257/2009': 'USA New York',
#  'A/swine/Guangxi/2253/2011': 'China Guangxi',
#  'A/swine/Iowa/A01244302/2012': 'USA Iowa',
#  'A/swine/Hong Kong/4902/2011': 'Hong Kong',
#  'A/mallard/California/3153/2012': 'USA California',
#  'A/wild duck/Shantou/488/2002': 'China Shantou',
#  'A/Toronto/C2781/2009': 'Canada Toronto',
#  'A/New York/1108/2008': 'USA New York',
#  'A/North Fitzroy/INS476/2010': 'Australia North Fitzroy',
#  'A/duck/Jiangsu/4/2010': 'China Jiangsu',
#  'A/wild duck/Shantou/5769/2004': 'China Shantou',
#  'A/Jiangxi/IPB13/2013': 'China Jiangxi',
#  'A/mallard/California/1356/2010': 'USA California',
#  'A/American black duck/New Brunswick/00614/2010': 'Canada New Brunswick',
#  'A/mallard/Wisconsin/944/1982': 'USA Wisconsin',
#  'A/swine/Hong Kong/NS972/2012': 'Hong Kong',
#  'A/swine/Miyazaki/1/2006': 'Japan Miyazaki',
#  'A/Texas/43132503/2009': 'USA Texas',
#  'A/mallard/Netherlands/22/2007': 'Netherlands',
#  'A/northern pintail/Interior Alaska/9BM4347R0/2009': 'USA Interior Alaska',
#  'A/equine/Santa Fe/1/1985': 'USA Santa Fe',
#  'A/waterfowl/Hong Kong/378.5/2001': 'Hong Kong',
#  'A/Chicago/YGA_04015/2012': 'USA Chicago',
#  'A/swine/Korea/A18/2011': 'South Korea Korea',
#  'A/mallard/MD/199/2003': 'USA MD',
#  'A/chicken/Israel/953/2007': 'Israel',
#  'A/mallard/California/3471/2012': 'USA California',
#  'A/Finland/43/2014': 'Finland',
#  'A/mallard/Sweden/4258/2004': 'Sweden',
#  'A/duck/Interior Alaska/7MP1598/2007': 'USA Interior Alaska',
#  'A/duck/Vietnam/942B/2004': 'Viet Nam Vietnam',
#  'A/California/VRDL241/2009': 'USA California',
#  'A/turkey/Israel/884/2005': 'Israel',
#  'A/New York/515/1997': 'USA New York',
#  'A/Boston/YGA_01125/2013': 'USA Boston',
#  'A/northern pintail/Interior Alaska/9BM7108R2/2009': 'USA Interior Alaska',
#  'A/swine/Indiana/13TOSU4336/2013': 'USA Indiana',
#  'A/California/VRDL6/2010': 'USA California',
#  'A/Managua/655.02/2009': 'Nicaragua Managua',
#  'A/chicken/New York/88291-10/2005': 'USA New York',
#  'A/New York/WC-LVD-14-062/2014': 'USA New York',
#  'A/Chicago/YGA_04119/2012': 'USA Chicago',
#  'A/Texas/JMM_22/2012': 'USA Texas',
#  'A/Berlin/INS361/2009': 'Germany Berlin',
#  'A/Taiwan/6078/2009': 'Taiwan',
#  'A/swine/Indiana/13TOSU1142/2013': 'USA Indiana',
#  'A/California/VRDL239/2009': 'USA California',
#  'A/Santa Clara/YGA_03022/2013': 'USA Santa Clara',
#  'A/ruddy turnstone/Delaware Bay/197/2002': 'USA Delaware Bay',
#  'A/Helsinki/759M/2014': 'Finland Helsinki',
#  'A/mallard/Ohio/13OS1982/2013': 'USA Ohio',
#  'A/New York/274/2002': 'USA New York',
#  'A/swine/MB/10422/2009': 'Canada MB',
#  'A/swine/North Carolina/SG1334/2009': 'USA North Carolina',
#  'A/swine/Hong Kong/NS728/2002': 'Hong Kong',
#  'A/Boston/YGA_00066/2013': 'USA Boston',
#  'A/New York/165/2000': 'USA New York',
#  'A/swine/Finnistere/800/2004': 'France Finnistere',
#  'A/American green-winged teal/Ohio/13OS2056/2013': 'USA Ohio',
#  'A/environment/Shanghai/S1438/2013': 'China Shanghai',
#  'A/Canterbury/63/2000': 'New Zealand Canterbury',
#  'A/Canterbury/63/2001': 'New Zealand Canterbury',
#  'A/mallard/Sweden/6134/2005': 'Sweden',
#  'A/Tennessee/F2031A/2011': 'USA Tennessee',
#  'A/Quito/WRAIR0617N/2009': 'Ecuador Quito',
#  'A/Helsinki/828/2013': 'Finland Helsinki',
#  'A/mallard/Sweden/5/2005': 'Sweden',
#  'A/Texas/JMS393/2009': 'USA Texas',
#  'A/Malaysia/10360/1996': 'Malaysia',
#  'A/Managua/5664.02/2010': 'Nicaragua Managua',
#  'A/Springfield/INS3_652/2011': 'USA Springfield',
#  'A/Sydney/DD3-28/2010': 'Australia Sydney',
#  'A/mallard/Sweden/3715/2004': 'Sweden',
#  'A/mallard/Nova Scotia/02335/2007': 'Canada Nova Scotia',
#  'A/quail/Yogjakarta/UT1075/2004': 'Indonesia Yogjakarta',
#  'A/Wisconsin/629-S0293/2009': 'USA Wisconsin',
#  'A/California/VRDL10/2010': 'USA California',
#  'A/Texas/42163295/2009': 'USA Texas',
#  'A/Minnesota/11/2010': 'USA Minnesota',
#  'A/Peru/PER260/2012': 'Peru',
#  'A/mallard/Interior Alaska/10CH00035R0/2010': 'USA Interior Alaska',
#  'A/duck/Fujian/5643/2005': 'China Fujian',
#  'A/Canada/591/2004': 'Canada',
#  'A/Helsinki/870/2013': 'Finland Helsinki',
#  'A/Athens/INS355/2009': 'Greece Athens',
#  'A/Wisconsin/629-D02063/2009': 'USA Wisconsin',
#  'A/Hue/H354/2008': 'Viet Nam Hue',
#  'A/New York/289/1998': 'USA New York',
#  'A/ruddy turnstone/NJ/823/2001': 'USA NJ',
#  'A/Pensacola/INS213/2009': 'USA Pensacola',
#  'A/Tennessee/UR06-0379/2007': 'USA Tennessee',
#  'A/Auckland/591/2000': 'New Zealand Auckland',
#  'A/Tennessee/05/2009': 'USA Tennessee',
#  'A/Peru/PER104/2010': 'Peru',
#  'A/swine/Hong Kong/1286/1993': 'Hong Kong',
#  'A/England/XFL00364/2009': 'United Kingdom England',
#  'A/mallard/Missouri/466554-14/2007': 'USA Missouri',
#  'A/Copenhagen/INS98/2009': 'Denmark Copenhagen',
#  'A/American wigeon/Iowa/463993/2006': 'USA Iowa',
#  'A/mallard/Sweden/68621/2007': 'Sweden',
#  'A/American black duck/New Brunswick/19497/2006': 'Canada New Brunswick',
#  'A/redhead duck/Alberta/357/1983': 'Canada Alberta',
#  'A/swine/Hong Kong/3044/2011': 'Hong Kong',
#  'A/chicken/Hong Kong/JV17/2012': 'Hong Kong',
#  'A/Bochum/INS375/2009': 'Germany Bochum',
#  'A/pintail duck/ALB/623/1985': 'Canada ALB',
#  'A/duck/Fujian/7574/2006': 'China Fujian',
#  'A/equine/Kyonggi/SA1/2011': 'South Korea Kyonggi',
#  'A/environment/Maryland/1189/2006': 'USA Maryland',
#  'A/wild duck/Korea/PSC30-20/2010': 'South Korea Korea',
#  'A/Peru/PER154/2010': 'Peru',
#  'A/mallard/Alberta/720/1984': 'Canada Alberta',
#  'A/Houston/1OS/2009': 'USA Houston',
#  'A/Canada-SK/RV1797/2009': 'Canada Canada-SK',
#  'A/New York/372/2004': 'USA New York',
#  'A/duck/Laos/P0127/2007': 'Laos',
#  'A/Moscow/IIV-45/2012': 'Russia Moscow',
#  'A/ruddy turnstone/New Jersey/AI00-1385/2000': 'USA New Jersey',
#  'A/swine/Binh Duong/03_10/2010': 'Viet Nam Binh Duong',
#  'A/guinea fowl/New York/22067-10/2005': 'USA New York',
#  'A/mallard/Alaska/ND0006301/2013': 'USA Alaska',
#  'A/chicken/Hunan/8/2008': 'China Hunan',
#  'A/Chile/31/2009': 'Chile',
#  'A/mallard/California/2743/2012': 'USA California',
#  'A/California/VRDL257/2009': 'USA California',
#  'A/Singapore/GP496/2011': 'Singapore',
#  'A/Boston/YGA_00014/2012': 'USA Boston',
#  'A/mallard/California/3083/2012': 'USA California',
#  'A/duck/Guangdong/wy19/2008': 'China Guangdong',
#  'A/swine/Hong Kong/4816/2011': 'Hong Kong',
#  'A/mallard/Washington/44256-527/2006': 'USA Washington',
#  'A/ruddy turnstone/Delaware/650635/2002': 'USA Delaware',
#  'A/Chicago/YGA_04095/2012': 'USA Chicago',
#  'A/shorebird/Delaware Bay/78/2004': 'USA Delaware Bay',
#  'A/wild duck/Shantou/3155/2003': 'China Shantou',
#  'A/Nicaragua/5674_05/2010': 'Nicaragua',
#  'A/Wisconsin/629-D01773/2009': 'USA Wisconsin',
#  'A/Tennessee/UR06-0076/2007': 'USA Tennessee',
#  'A/American black duck/New Brunswick/02396/2007': 'Canada New Brunswick',
#  'A/Canterbury/59/2002': 'New Zealand Canterbury',
#  'A/swine/Illinois/A01244402/2012': 'USA Illinois',
#  'A/mallard/Jiangxi/8341/2004': 'China Jiangxi',
#  'A/Peru/WRAIR1296P/2007': 'Peru',
#  'A/swine/Norway/02_11342/2009': 'Norway',
#  'A/New York/3211/2009': 'USA New York',
#  'A/Russia/01/2009': 'Russia',
#  'A/Malaysia/2086505/2009': 'Malaysia',
#  'A/Bangkok/INS498/2010': 'Thailand Bangkok',
#  'A/environment/Cambodia/C425D/2011': 'Cambodia',
#  'A/mallard/Maryland/1135/2005': 'USA Maryland',
#  'A/New York/WC-LVD-14-030/2014': 'USA New York',
#  'A/New York/771/1993': 'USA New York',
#  'A/ruddy turnstone/Delaware/828213/2001': 'USA Delaware',
#  'A/Boston/13/2009': 'USA Boston',
#  'A/mallard/Sweden/2213/2003': 'Sweden',
#  'A/swine/Guangdong/603/2010': 'China Guangdong',
#  'A/Peru/PER156/2012': 'Peru',
#  'A/New York/517/1998': 'USA New York',
#  'A/shorebird/Delaware Bay/246/2003': 'USA Delaware Bay',
#  'A/HaNoi/BM949/2003': 'Viet Nam HaNoi',
#  'A/Nevada/12/2012': 'USA Nevada',
#  'A/chicken/INDIA/NIV33491/06': 'India INDIA',
#  'A/California/VRDL273/2009': 'USA California',
#  'A/New York/496/2003': 'USA New York',
#  'A/Illinois/UR06-0436/2007': 'USA Illinois',
#  'A/American green-winged teal/Interior Alaska/9BM6428R0/2009': 'USA Interior Alaska',
#  'A/guinea fowl/Massachusetts/14075-3/2013': 'USA Massachusetts',
#  'A/pintail/Ohio/351/1987': 'USA Ohio',
#  'A/Managua/5115.01/2009': 'Nicaragua Managua',
#  'A/chicken/Italy/22A/1998': 'Italy',
#  'A/parrot/Guangdong/C99/2005': 'China Guangdong',
#  'A/Canterbury/392/2003': 'New Zealand Canterbury',
#  'A/American green-winged teal/Interior Alaska/10BM06728R0/2010': 'USA Interior Alaska',
#  'A/mallard/Alberta/270/1986': 'Canada Alberta',
#  'A/mallard/Alberta/68/2004': 'Canada Alberta',
#  'A/swine/North Carolina/01469/2007': 'USA North Carolina',
#  'A/mallard/California/1523/2010': 'USA California',
#  'A/duck/Fujian/4224/2007': 'China Fujian',
#  'A/Memphis/3/1996': 'USA Memphis',
#  'A/ruddy turnstone/DE/510/1988': 'USA DE',
#  'A/duck/Zhejiang/D13/2013': 'China Zhejiang',
#  'A/chicken/Huadong/4/2008': 'China Huadong',
#  'A/Texas/JMS361/2009': 'USA Texas',
#  'A/HoChiMinh/HCM526/2006': 'Viet Nam HoChiMinh',
#  'A/pintail/ALB/179/1993': 'Canada ALB',
#  'A/Houston/JMM_99/2012': 'USA Houston',
#  'A/Nicaragua/AGA2-106/2012': 'Nicaragua',
#  'A/Managua/2155.01/2009': 'Nicaragua Managua',
#  'A/northern pintail/Interior Alaska/10BM04704R0/2010': 'USA Interior Alaska',
#  'A/mallard/Sweden/5944/2005': 'Sweden',
#  'A/mallard/Interior Alaska/7MP1094/2007': 'USA Interior Alaska',
#  'A/unknown/Alberta/126/2007': 'Canada Alberta',
#  'A/Waikato/108/2003': 'New Zealand Waikato',
#  'A/Athens/INS551/2011': 'Greece Athens',
#  'A/Illinois/NHRC0002/2011': 'USA Illinois',
#  'A/Texas/UR06-0174/2007': 'USA Texas',
#  'A/swine/Shandong/01/2009': 'China Shandong',
#  'A/mallard/California/2540P/2011': 'USA California',
#  'A/swine/Ohio/11SW170/2011': 'USA Ohio',
#  'A/England/917/2003': 'United Kingdom England',
#  'A/duck/Fujian/5784/2007': 'China Fujian',
#  'A/mallard/Wisconsin/598/1983': 'USA Wisconsin',
#  'A/goose/Egypt/M2794A/2011': 'Egypt',
#  'A/bird/Guangxi/83/2005': 'China Guangxi',
#  'A/New York/761/1993': 'USA New York',
#  'A/mallard/Sweden/57/2002': 'Sweden',
#  'A/duck/Guangxi/2736/2006': 'China Guangxi',
#  'A/Malaysia/1788397/2007': 'Malaysia',
#  'A/Georgia/NHRC0001/2004': 'USA Georgia',
#  'A/mallard/Interior Alaska/10BM06909R0/2010': 'USA Interior Alaska',
#  'A/Peru/PER175/2012': 'Peru',
#  'A/shoveler/ALB/114/1985': 'Canada ALB',
#  'A/mallard/Wisconsin/11OS3422/2011': 'USA Wisconsin',
#  'A/Georgia/NHRC0001/2003': 'USA Georgia',
#  'A/swine/Korea/CY01-06/2012': 'South Korea Korea',
#  'A/swine/Arkansas/SG1378/2011': 'USA Arkansas',
#  'A/mallard/Interior Alaska/9BM10393R0/2009': 'USA Interior Alaska',
#  'A/Dayton/INS3_634/2011': 'USA Dayton',
#  'A/Chicago/YGA_04035/2012': 'USA Chicago',
#  'A/greater white-fronted goose/California/44358-076/2007': 'USA California',
#  'A/northern shoveler/Oregon/44336-179/2007': 'USA Oregon',
#  'A/Canterbury/18/2004': 'New Zealand Canterbury',
#  'A/Canterbury/18/2002': 'New Zealand Canterbury',
#  'A/mallard/Wisconsin/1391/1983': 'USA Wisconsin',
#  'A/mallard/Oregon/461067-2/2006': 'USA Oregon',
#  'A/swine/Oklahoma/SG1460/2004': 'USA Oklahoma',
#  'A/Michigan/UR06-0015/2006': 'USA Michigan',
#  'A/Paris/467/1991': 'France Paris',
#  'A/mallard/Altai/1208/2007': 'Russia Altai',
#  'A/mallard/Wisconsin/2256/1984': 'USA Wisconsin',
#  'A/Malaysia/12974/1999': 'Malaysia',
#  'A/Wellington/55/2004': 'New Zealand Wellington',
#  'A/Brownsville/39H/2009': 'USA Brownsville',
#  'A/Argentina/7980/2009': 'Argentina',
#  'A/Texas/45010998/2009': 'USA Texas',
#  'A/swine/Iowa/H03US3/2003': 'USA Iowa',
#  'A/England/H093780041/2009': 'United Kingdom England',
#  'A/mallard/California/3381/2012': 'USA California',
#  'A/Texas/42102708/2009': 'USA Texas',
#  'A/Russia/14/2009': 'Russia',
#  'A/swine/Texas/03042/2010': 'USA Texas',
#  'A/Netherlands/1/1995': 'Netherlands',
#  'A/yellow-legged gull/Republic of Georgia/2/2013': 'Georgia Republic of Georgia',
#  'A/yellow-legged gull/Republic of Georgia/2/2012': 'Georgia Republic of Georgia',
#  'A/New York/3904/2009': 'USA New York',
#  'A/mallard/Sweden/68504/2007': 'Sweden',
#  'A/Boston/678/2009': 'USA Boston',
#  'A/Singapore/GP999/2010': 'Singapore',
#  'A/yellow-headed Amazon/California/500658/2007': 'USA California',
#  'A/mallard/British Columbia/07826/2005': 'Canada British Columbia',
#  'A/New York/133/2002': 'USA New York',
#  'A/Singapore/19/1993': 'Singapore',
#  'A/California/VRDL237/2009': 'USA California',
#  'A/American black duck/New Brunswick/02490/2007': 'Canada New Brunswick',
#  'A/Sydney/DD3-07/2010': 'Australia Sydney',
#  'A/northern shoveler/Interior Alaska/4/2007': 'USA Interior Alaska',
#  'A/duck/Guangdong/GD01/2014': 'China Guangdong',
#  'A/mallard/MN/259/1999': 'USA MN',
#  'A/ruddy turnstone/New Jersey/348/1989': 'USA New Jersey',
#  'A/Managua/112.01/2007': 'Nicaragua Managua',
#  'A/Singapore/GP3104/2009': 'Singapore',
#  'A/mallard/Interior Alaska/9BM1962/2009': 'USA Interior Alaska',
#  'A/Peru/PER178/2010': 'Peru',
#  'A/Boston/YGA_01049/2012': 'USA Boston',
#  'A/HoChiMinh/HCM554/2006': 'Viet Nam HoChiMinh',
#  'A/swine/Nebraska/A01301493/2012': 'USA Nebraska',
#  'A/Western Australia/76/2005': 'Australia Western Australia',
#  'A/swine/Ohio/09SW1478E/2009': 'USA Ohio',
#  'A/New York/4777/2009': 'USA New York',
#  'A/swine/Hong Kong/814/2010': 'Hong Kong',
#  'A/Bonn/INS278/2009': 'Germany Bonn',
#  'A/swine/Iowa/13C097/2013': 'USA Iowa',
#  'A/environment/New York/29047-1/2006': 'USA New York',
#  'A/Australia/39/2009': 'Australia',
#  'A/Waikato/120/2003': 'New Zealand Waikato',
#  'A/blue-winged teal/ALB/293/1994': 'Canada ALB',
#  'A/mallard/California/6524/2008': 'USA California',
#  'A/Houston/JMM_141/2013': 'USA Houston',
#  'A/duck/Shantou/3324/2005': 'China Shantou',
#  'A/swine/Kentucky/12TOSU1052/2012': 'USA Kentucky',
#  'A/swine/Illinois/A00857129/2011': 'USA Illinois',
#  'A/mallard/Interior Alaska/9BM2254/2009': 'USA Interior Alaska',
#  'A/chicken/Viet Nam/TN-025/2004': 'Viet Nam',
#  'A/DaNang/DN431/2008': 'Viet Nam DaNang',
#  'A/chicken/West Bengal/155505/2009': 'India West Bengal',
#  'A/New York/706/1993': 'USA New York',
#  'A/mallard/New Jersey/ND0007132/2013': 'USA New Jersey',
#  'A/HaNoi/N71/2007': 'Viet Nam HaNoi',
#  'A/swine/Indiana/13TOSU4284/2013': 'USA Indiana',
#  'A/HungYen/HY028/2004': 'Viet Nam HungYen',
#  'A/Helsinki/613/2013': 'Finland Helsinki',
#  'A/Alabama/WRAIR1242P/2009': 'USA Alabama',
#  'A/Managua/5221.03/2009': 'Nicaragua Managua',
#  'A/duck/Jiangxi/7348/2007': 'China Jiangxi',
#  'A/Houston/JMM_70/2012': 'USA Houston',
#  'A/swine/Colorado/SG1322/2009': 'USA Colorado',
#  'A/duck/Egypt/M2583A/2010': 'Egypt',
#  'A/Muscovy duck/New York/11646-4/2005': 'USA New York',
#  'A/Managua/1422.03/2010': 'Nicaragua Managua',
#  'A/Hong Kong/1870/2008': 'Hong Kong',
#  'A/Boston/DOA63/2011': 'USA Boston',
#  'A/Boston/78/2008': 'USA Boston',
#  'A/Netherlands/124/2001': 'Netherlands',
#  'A/mallard/California/1399/2013': 'USA California',
#  'A/mallard/California/5149/2009': 'USA California',
#  'A/Mexico City/025/2009': 'Mexico Mexico City',
#  'A/duck/Shanghai/C164/2009': 'China Shanghai',
#  'A/shorebird/Delaware/172/2006': 'USA Delaware',
#  'A/muscovy duck/Vietnam/LBM687/2014': 'Viet Nam Vietnam',
#  'A/Khon Kaen/INS451/2010': 'Thailand Khon Kaen',
#  'A/swine/Ohio/10SW207/2010': 'USA Ohio',
#  'A/New York/511/1997': 'USA New York',
#  'A/Athens/INS322/2009': 'Greece Athens',
#  'A/Moscow/IIV04/2009': 'Russia Moscow',
#  'A/blue-winged teal/Louisiana/AI09-5234/2009': 'USA Louisiana',
#  'A/wild duck/SH38-51/2010': 'South Korea wild duck',
#  'A/northern pintail/Interior Alaska/7MP0345BR2/2007': 'USA Interior Alaska',
#  'A/Boston/YGA_01191/2013': 'USA Boston',
#  'A/Boston/DOA2-163/2013': 'USA Boston',
#  'A/Texas/UR06-0309/2007': 'USA Texas',
#  'A/Texas/45093670/2009': 'USA Texas',
#  'A/Boston/DOA2-226/2013': 'USA Boston',
#  'A/ruddy turnstone/Delaware Bay/220/1995': 'USA Delaware Bay',
#  'A/New York/WC-LVD-14-025/2014': 'USA New York',
#  'A/blue-winged teal/ALB/569/1985': 'Canada ALB',
#  'A/turkey/Italy/3185/1999': 'Italy',
#  'A/mallard/PT/27972-B139/2007': 'Portugal PT',
#  'A/swine/Ohio/09SW1483E/2009': 'USA Ohio',
#  'A/mallard/California/1438/2010': 'USA California',
#  'A/American green-winged teal/Wisconsin/11OS3580/2011': 'USA Wisconsin',
#  'A/duck/Fujian/1878/2006': 'China Fujian',
#  'A/swine/Oklahoma/011506/2007': 'USA Oklahoma',
#  'A/Nanchang/16/1996': 'China Nanchang',
#  'A/Houston/JMM_97/2012': 'USA Houston',
#  'A/Finland/214/2012': 'Finland',
#  'A/mallard/Interior Alaska/10BM10787R0/2010': 'USA Interior Alaska',
#  'A/Singapore/GP413/2010': 'Singapore',
#  'A/mallard/California/20385-004/2007': 'USA California',
#  'A/redhead/Ohio/13OS0428/2013': 'USA Ohio',
#  'A/HaNoi/TX322/2007': 'Viet Nam HaNoi',
#  'A/ruddy turnstone/New Jersey/1148668/2004': 'USA New Jersey',
#  'A/black-headed gull/Iceland/1298/2011': 'Iceland',
#  'A/England/593/2003': 'United Kingdom England',
#  'A/New York/1157/2008': 'USA New York',
#  'A/chicken/Hong Kong/JV231W/2012': 'Hong Kong',
#  'A/Singapore/GP479/2011': 'Singapore',
#  'A/mallard/Alberta/6/1994': 'Canada Alberta',
#  'A/Oregon/UR06-0179/2007': 'USA Oregon',
#  'A/New York/487/2003': 'USA New York',
#  'A/New York/45/2003': 'USA New York',
#  'A/California/NHRC0003/2003': 'USA California',
#  'A/Oregon/UR06-0291/2007': 'USA Oregon',
#  'A/northern pintail/Interior Alaska/7MP0509/2007': 'USA Interior Alaska',
#  'A/mallard/Wisconsin/408/1983': 'USA Wisconsin',
#  'A/shorebird/Delaware Bay/293/2008': 'USA Delaware Bay',
#  'A/mallard/Sweden/81/2003': 'Sweden',
#  'A/ruddy turnstone/Delaware/293/2006': 'USA Delaware',
#  'A/swine/Saitama/21/2004': 'Japan Saitama',
#  'A/mallard/Wisconsin/867/1982': 'USA Wisconsin',
#  'A/California/VRDL393/2009': 'USA California',
#  'A/Managua/1077.04/2009': 'Nicaragua Managua',
#  'A/duck/Eastern China/16/2010': 'China Eastern China',
#  'A/TayNguyen/TN152/2003': 'Viet Nam TayNguyen',
#  'A/DaNang/DN364/2008': 'Viet Nam DaNang',
#  'A/Argentina/9705/2009': 'Argentina',
#  'A/New York/WC-LVD-13-027/2013': 'USA New York',
#  'A/Tennessee/F2041/2011': 'USA Tennessee',
#  'A/equine/Liaoning/9/2008': 'China Liaoning',
#  'A/Guinea fowl/New York/11646-3/2005': 'USA New York',
#  'A/blue-winged teal/Ohio/12OS2295/2012': 'USA Ohio',
#  'A/avian/Delaware Bay/226/2006': 'USA Delaware Bay',
#  'A/New York/774/1993': 'USA New York',
#  'A/New York/4728/2009': 'USA New York',
#  'A/blue-winged teal/Canada/3286/2011': 'Canada',
#  'A/equine/Xinjiang/2/2007': 'China Xinjiang',
#  'A/mallard/Ohio/1695/2009': 'USA Ohio',
#  'A/swine/Ohio/09SW93/2009': 'USA Ohio',
#  'A/New York/431/2000': 'USA New York',
#  'A/swine/Minnesota/07002083/2007': 'USA Minnesota',
#  'A/Managua/1167.03/2010': 'Nicaragua Managua',
#  'A/Texas/JMM_47/2012': 'USA Texas',
#  'A/mallard/New Brunswick/04482/2007': 'Canada New Brunswick',
#  'A/American green-winged teal/Interior Alaska/9BM8129R0/2009': 'USA Interior Alaska',
#  'A/New York/3181/2009': 'USA New York',
#  'A/England/798/2009': 'United Kingdom England',
#  'A/Waikato/19/2000': 'New Zealand Waikato',
#  'A/ruddy turnstone/New Jersey/AI09-1251/2009': 'USA New Jersey',
#  'A/duck/Zhejiang/2244/2011': 'China Zhejiang',
#  'A/mallard/Sweden/68538/2007': 'Sweden',
#  'A/New York/1152/2008': 'USA New York',
#  'A/condor/Guangdong/139/2003': 'China Guangdong',
#  'A/England/XFL00481/2009': 'United Kingdom England',
#  'A/New South Wales/25/2000': 'Australia New South Wales',
#  'A/Kentucky/UR06-0372/2007': 'USA Kentucky',
#  'A/England/593/2006': 'United Kingdom England',
#  'A/mallard/New Zealand/1615-17/2004': 'New Zealand',
#  'A/Chile/34/2010': 'Chile',
#  'A/mallard/Ohio/11OS2224/2011': 'USA Ohio',
#  'A/Canada-SK/RV1788/2009': 'Canada Canada-SK',
#  'A/blue-winged teal/Guatemala/CIP049-09/2010': 'Guatemala',
#  'A/northern pintail/Interior Alaska/9BM6094R0/2009': 'USA Interior Alaska',
#  'A/Shengzhen/227/1995': 'China Shengzhen',
#  'A/Alabama/02/2009': 'USA Alabama',
#  'A/duck/Wisconsin/2626/1985': 'USA Wisconsin',
#  'A/Australia/73/2009': 'Australia',
#  'A/New York/3297/2009': 'USA New York',
#  'A/gadwall/Mississippi/11OS6085/2011': 'USA Mississippi',
#  'A/blue-winged teal/Wisconsin/281/1982': 'USA Wisconsin',
#  'A/Chile/64/2010': 'Chile',
#  'A/Oregon/UR06-0200/2007': 'USA Oregon',
#  'A/Western Australia/40/2003': 'Australia Western Australia',
#  'A/California/VRDL22/2009': 'USA California',
#  'A/mink/Wisconsin/31512-7/2012': 'USA Wisconsin',
#  'A/American green-winged teal/Illinois/3054/2009': 'USA Illinois',
#  'A/whiskered tern/Egypt/04/2004': 'Egypt',
#  'A/chicken/Zhejiang/HJ/2007': 'China Zhejiang',
#  'A/mallard duck/ALB/506/1983': 'Canada ALB',
#  'A/duck/Cambodia/143W4M4/2013': 'Cambodia',
#  'A/Hong Kong/HKU21/2004': 'Hong Kong',
#  'A/Boston/657/2009': 'USA Boston',
#  'A/mallard duck/ALB/635/1983': 'Canada ALB',
#  'A/Scotland/61/2003': 'United Kingdom Scotland',
#  'A/California/VRDL244/2009': 'USA California',
#  'A/California/VRDL336/2009': 'USA California',
#  'A/Pennsylvania/PIT12/2008': 'USA Pennsylvania',
#  'A/Malaysia/2156486/2009': 'Malaysia',
#  'A/Nicaragua/7304_02/2013': 'Nicaragua',
#  'A/Boston/12/2007': 'USA Boston',
#  'A/open-billed stork/Nakhonsawan/BBA2611M/05': 'Thailand Nakhonsawan',
#  'A/DaNang/DN365/2008': 'Viet Nam DaNang',
#  'A/chicken/Guangxi/6/2000': 'China Guangxi',
#  'A/swine/Indiana/13TOSU1159/2013': 'USA Indiana',
#  'A/Boston/YGA_01041/2012': 'USA Boston',
#  'A/ring-necked duck/New Brunswick/03400/2009': 'Canada New Brunswick',
#  'A/Mexico/24015/2009': 'Mexico',
#  'A/swine/Hong Kong/NS3032/2011': 'Hong Kong',
#  'A/Mexico/24043/2009': 'Mexico',
#  'A/DaNang/DN453/2008': 'Viet Nam DaNang',
#  'A/swine/Indiana/A01203521/2012': 'USA Indiana',
#  'A/Northern shoveler/NC/6412-052/2005': 'USA NC',
#  'A/Boston/691/2009': 'USA Boston',
#  'A/Tomsk/06/2009': 'Russia Tomsk',
#  'A/northern pintail/Interior Alaska/10BM12221R0/2010': 'USA Interior Alaska',
#  'A/northern pintail/Interior Alaska/9BM4410R1/2009': 'USA Interior Alaska',
#  'A/New York/359/2005': 'USA New York',
#  'A/American black duck/Nova Scotia/00090/2010': 'Canada Nova Scotia',
#  'A/mallard/Interior Alaska/10BM06905R0/2010': 'USA Interior Alaska',
#  'A/Santiago/p2d2/2012': 'Chile Santiago',
#  'A/Chicago/YGA_04128/2013': 'USA Chicago',
#  'A/mallard/Alberta/549/1986': 'Canada Alberta',
#  'A/New York/3519/2009': 'USA New York',
#  'A/Nicaragua/AGA2-68/2011': 'Nicaragua',
#  'A/Boston/17/2009': 'USA Boston',
#  'A/Mexico City/002/2009': 'Mexico Mexico City',
#  'A/HaNoi/BM061/2007': 'Viet Nam HaNoi',
#  'A/Singapore/TT150/2010': 'Singapore',
#  'A/South Carolina/10/2010': 'USA South Carolina',
#  'A/green-winged teal/California/96/2012': 'USA California',
#  'A/Boston/DOA2-107/2012': 'USA Boston',
#  'A/Illinois/03/2011': 'USA Illinois',
#  'A/New York/236/2004': 'USA New York',
#  'A/New York/7236/2009': 'USA New York',
#  'A/swine/Hong Kong/8376/2001': 'Hong Kong',
#  'A/New York/WC-LVD-13-013/2013': 'USA New York',
#  'A/Scotland/91800799/2009': 'United Kingdom Scotland',
#  'A/parakeet/Chiba/1/97': 'Japan Chiba',
#  'A/mallard/Jiangxi/8264/2004': 'China Jiangxi',
#  'A/mallard/Wisconsin/13OS2767/2013': 'USA Wisconsin',
#  'A/Kentucky/UR06-0062/2007': 'USA Kentucky',
#  'A/swine/Colorado/02875/2009': 'USA Colorado',
#  'A/Netherlands/3/1992': 'Netherlands',
#  'A/Australia/37/2009': 'Australia',
#  'A/New York/381/2004': 'USA New York',
#  'A/New York/7036/2009': 'USA New York',
#  'A/mallard/Wisconsin/11OS3192/2011': 'USA Wisconsin',
#  'A/Managua/5590.02/2009': 'Nicaragua Managua',
#  'A/New York/08-1326/2008': 'USA New York',
#  'A/Canada-ON/RV1529/2009': 'Canada Canada-ON',
#  'A/Canterbury/48/2002': 'New Zealand Canterbury',
#  'A/Queensland/29/2002': 'Australia Queensland',
#  'A/GSC_chicken_B/British Columbia/04': 'Canada GSC chicken B',
#  'A/Texas/45061755/2009': 'USA Texas',
#  'A/Canterbury/01/2001': 'New Zealand Canterbury',
#  'A/Canterbury/01/2002': 'New Zealand Canterbury',
#  'A/Athens/INS416/2010': 'Greece Athens',
#  'A/Canterbury/01/2005': 'New Zealand Canterbury',
#  'A/Wisconsin/629-D01055/2009': 'USA Wisconsin',
#  'A/swine/Guangdong/06/2009': 'China Guangdong',
#  'A/Boston/YGA_01028/2012': 'USA Boston',
#  'A/chicken/Hong Kong/FY6W/2012': 'Hong Kong',
#  'A/New York/225/2003': 'USA New York',
#  'A/New York/499/2004': 'USA New York',
#  'A/green-winged teal/Prince Edward Island/00840/2010': 'Canada Prince Edward Island',
#  'A/American green-winged teal/Illinois/10OS3329/2010': 'USA Illinois',
#  'A/mallard/San Jiang/275/2007': 'China San Jiang',
#  'A/Western Australia/77/2005': 'Australia Western Australia',
#  'A/duck/Guangxi/S4111/2010': 'China Guangxi',
#  'A/Boston/DOA49/2011': 'USA Boston',
#  'A/broiler duck/Korea/H49/2014': 'South Korea Korea',
#  'A/Managua/4009.02/2010': 'Nicaragua Managua',
#  'A/swine/Hubei/04/2009': 'China Hubei',
#  'A/swine/Indiana/13TOSU5095/2013': 'USA Indiana',
#  'A/chicken/Ningxia/4/99': 'China Ningxia',
#  'A/Houston/JMM_110/2013': 'USA Houston',
#  'A/mallard/Washington/44338-011/2007': 'USA Washington',
#  'A/Canterbury/65/2000': 'New Zealand Canterbury',
#  'A/Canterbury/65/2001': 'New Zealand Canterbury',
#  'A/Japanese Quail/Vietnam/4/2009': 'Viet Nam Vietnam',
#  'A/New York/1043/2006': 'USA New York',
#  'A/duck/Zhejiang/0611-24/2011': 'China Zhejiang',
#  'A/Singapore/ON1747/2009': 'Singapore',
#  'A/Kentucky/UR06-0071/2007': 'USA Kentucky',
#  'A/Memphis/12/1986': 'USA Memphis',
#  'A/duck/Eastern China/54/2002': 'China Eastern China',
#  'A/Singapore/NHRC0008/2003': 'Singapore',
#  'A/Memphis/12/1983': 'USA Memphis',
#  ...}

# %%
# Find a GPS coordinate for each
geodata = []
for search_term in countries_to_search:
    new_search_term = search_term.replace('_', ' ')
    loc = geocoder.geocode(new_search_term)
    if loc is None:
        loc = geocoder.geocode(cleaned_country)
    lat = loc.latitude
    lon = loc.longitude
    data = (search_term, u'{0}'.format(loc), lon, lat)
    geodata.append(data)
    print(data)
# Out:
# ('Canada', u'Canada', -106.346771, 56.130366)
# ('Australia_New South Wales', u'New South Wales, Australia', 151.2052868, -33.864174)
# ('France_Reunion', u'R\xe9union, 29680 Roscoff, France', -3.994667999999999, 48.702056)
# ('USA_Florida', u'Florida, USA', -81.5157535, 27.6648274)
# ('USA_Santa Clara', u'Santa Clara, CA, USA', -121.9552356, 37.3541079)
# ('Peru_Piura', u'Piura, Peru', -80.633333, -5.2)
# ('Indonesia_Banten', u'Banten, Republic of Indonesia', 106.0640179, -6.4058172)
# ('South Korea_KU', u'National Assembly of South Korea, Uisadang-daero, Yeoeuido-dong, Yeongdeungpo-gu, Seoul, South Korea', 126.9191163, 37.5318933)
# ('China_Guangzhou', u'Guangzhou, Guangdong, China', 113.264385, 23.12911)
# ('USA_Minneapolis', u'Minneapolis, MN, USA', -93.2650108, 44.977753)
# ('Viet Nam_TayNguyen', u'T\xe2y Nguy\xean, \u0110\u0103k Ha, \u0110\u1eafk Glong, \u0110\u0103k N\xf4ng, Vietnam', 107.7850886, 12.083802)
# ('Sweden_Umea', u'Ume\xe5, Sweden', 20.2630354, 63.8258471)
# ('USA_South Dakota', u'South Dakota, USA', -99.9018131, 43.9695148)
# ('China_Xinjiang', u'Xinjiang, China', 87.627704, 43.793026)
# ('Estonia_Tallinn', u'Tallinn, Estonia', 24.7535746, 59.43696079999999)
# ('USA_Cambridge', u'Cambridge, MA, USA', -71.10973349999999, 42.3736158)
# ("Cote dIvoire_Cote d'Ivoire", u"C\xf4te d'Ivoire", -5.547079999999999, 7.539988999999999)
# ('United Kingdom_Brighton', u'Brighton, The City of Brighton and Hove, UK', -0.137163, 50.82253000000001)
# ('New Zealand_South Canterbury', u'Canterbury, New Zealand', 171.1637245, -43.7542275)
# ('China_Fuzhou', u'Fuzhou, Fujian, China', 119.296494, 26.074508)
# ('Germany_Sachsen-Anhalt', u'Saxony-Anhalt, Germany', 11.6922735, 51.9502649)
# ('Peru_Trujillo', u'Trujillo, Peru', -79.0215336, -8.1090524)
# ('Japan_Chiba-C', u'Chiba, Chiba Prefecture, Japan', 140.1062907, 35.6072668)
# ('Japan_Chiba', u'Chiba, Chiba Prefecture, Japan', 140.1062907, 35.6072668)
# ('China_Xuyi', u"Xuyi, Huai'an, Jiangsu, China", 118.544361, 33.011971)
# ('Russia_Karasuk', u'Karasuk, Novosibirsk Oblast, Russia', 78.05, 53.716667)
# ('Viet Nam_Hanoi', u'Hanoi, Ho\xe0n Ki\u1ebfm, Hanoi, Vietnam', 105.8341598, 21.0277644)
# ('Russia_IIV-Anadyr', u'Anadyr, Chukotka Autonomous Okrug, Russia, 689000', 177.516667, 64.733333)
# ('South Korea_Kyonggi', u'Gyeonggi-do, South Korea', 127.5183, 37.41379999999999)
# ('Russia_Barnaul', u'Barnaul, Altai Krai, Russia', 83.76978319999999, 53.3547792)
# ('China_Nanjing', u'Nanjing, Jiangsu, China', 118.796877, 32.060255)
# ('Canada_Prince Edward Island', u'Prince Edward Island, Canada', -63.41681359999999, 46.510712)
# ('China_Lengshuitan', u'Lengshuitan, Yongzhou, Hunan, China', 111.592143, 26.461077)
# ('USA_San Antonio', u'San Antonio, TX, USA', -98.49362819999999, 29.4241219)
# ('Germany_Nordkirchen', u'Nordkirchen, Germany', 7.5222188, 51.73851939999999)
# ('Russia_Cheboksary', u'Cheboksary, Chuvashia Republic, Russia', 47.23333299999999, 56.15)
# ('Germany_Potsdam', u'Potsdam, Germany', 13.0644729, 52.3905689)
# ('Germany_Wagun', u'Wagun, 17159 Dargun, Germany', 12.8190403, 53.869026)
# ('Australia_Westmead', u'Westmead NSW 2145, Australia', 150.9872768, -33.8076889)
# ('Russia_Tver', u'Tver, Tver Oblast, Russia', 35.9175965, 56.85872140000001)
# ('New Zealand_Auckland', u'Auckland, New Zealand', 174.7633315, -36.8484597)
# ('Georgia_Republic of Georgia', u'Tbilisi Airport (TBS), Tbilisi, Georgia', 44.9568187, 41.6697036)
# ('Russia_Ulan Ude', u'Ulan-Ude, Buryatia, Russia', 107.607338, 51.8238785)
# ('Mexico_Queretaro', u'Santiago de Quer\xe9taro, Quer\xe9taro, Mexico', -100.3898881, 20.5887932)
# ('Germany_Garrel', u'Garrel, Germany', 8.0255988, 52.95310850000001)
# ('Thailand_Saraburi', u'Saraburi, Thailand', 100.9101421, 14.5289154)
# ('Norway', u'Norway', 8.468945999999999, 60.47202399999999)
# ('Thailand_NaraThiwat', u'Narathiwat, Thailand', 101.8253143, 6.4254607)
# ('USA_North Dakota', u'North Dakota, USA', -101.0020119, 47.5514926)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6fae9dc6b334> in <module>()
#       5     loc = geocoder.geocode(new_search_term)
#       6     if loc is None:
# ----> 7         loc = geocoder.geocode(cleaned_country)
#       8     lat = loc.latitude
#       9     lon = loc.longitude
#
# NameError: name 'cleaned_country' is not defined

# %%
geodf = pd.DataFrame(geodata)
geodf.columns = ['Search Term', "Returned Location", 'Longitude', 'Latitude']
geodf.to_csv('Country Geocoding.csv', encoding='utf-8')

# %%
# ecotype_map
# Add the ecotype into each node.
for n, d in G.nodes(data=True):
    country = d['country']
    species = d['host_species']
    if '/' in species:
        species = species.split('/')[0]
    if 'null' in species:
        species = 'Unknown'
        
        
    cleaned_country = country.replace('_', ' ')
    specific_region = n.split('/')[-3]
    if specific_region != cleaned_country:
        search_term = '{0} {1}'.format(cleaned_country, specific_region)
    else:
        search_term = cleaned_country
    print(search_term)
    location = geocoder.geocode(search_term)
    print('  ' + str(location))
    if location is None:
        location = geocoder.geocode(cleaned_country)
    lat = location.latitude
    lon = location.longitude
    
    

    
    G.node[n]['ecotype'] = ecotype_map[(country, species)]
    G.node[n]['latitude'] = lat
    G.node[n]['longitude'] = lon

# %%
# Identify the reassortants.

# Add reassortant status for each node.
for n, d in G.nodes(data=True):
    in_edge_types = set([d['edge_type'] for sc, sk, d in G.in_edges(n, data=True)])
    if 'reassortant' in in_edge_types:
        G.node[n]['reassortant'] = True
    elif 'full_complement' in in_edge_types:
        G.node[n]['reassortant'] = False
    else:
        G.node[n]['reassortant'] = False
        
def is_reassortant(G, node):
    return G.node[node]['reassortant']

reassortant_viruses = []
for n, d in G.nodes(data=True):
    if is_reassortant(G, n):
        reassortant_viruses.append(n)
        
print(len(reassortant_viruses))

# %%
reassortant_hosts = []
for virus in reassortant_viruses:
    reassortant_hosts.append(G.node[virus]['host_species'])
    
plt.pie(Counter(reassortant_hosts).values(), labels=Counter(reassortant_hosts).keys())
plt.axes().set_aspect('equal')
plt.show()

# %%
condensed_reassortant_hosts = []
for host in reassortant_hosts:
    if '/' in host:
        host = host.split('/')[1]
        if host == 'null':
            host = 'Unknown'
        condensed_reassortant_hosts.append(host)
    else:
        if host == 'null':
            host = 'Unknown'
        condensed_reassortant_hosts.append(host)

# %%
def get_host_group(G, node):
    host = G.node[node]['host_species']
    if 'Human' in host or 'human' in host:
        host = 'Human'
    elif 'Avian' in host or 'avian' in host:
        host = 'Avian'
    elif 'Unknown' in host or 'unknown' in host:
        host = 'Unknown'
    elif 'null' in host or 'Null' in host:
        host = 'Unknown'
    elif 'Swine' in host or 'swine' in host:
        host = 'Swine'
    else:
        host = 'Mammal'
        
    return host

def correct_host_group_ecotype(G, node):
    host = get_host_group(G.node[node]['host_species'])
    
    if host == 'Avian':
        if G.node[node]['ecotype'] == 'Domestic':
            host = 'Avian Domestic'
        else:
            host = 'Avian Wild'
            
    return host

# %%
# Get total representation of viruses
all_hosts = []
for n, d in G.nodes(data=True):
    all_hosts.append(correct_host_group_ecotype(G, n))

# %%
def counter_proportions(counter):
    total = sum(counter.values())
    
    proportions = dict()
    for key, value in counter.items():
        proportions[key] = float(value)/float(total)
        
    return proportions

def categorical_counter_xlabels(counter):
    idxs = dict()
    
    for i, key in enumerate(counter.keys()):
        idxs[key] = i
        
    return idxs

# %%
# all_hosts

# %%
# Plot the proportion of hosts for reassortant viruses
counts = Counter(condensed_reassortant_hosts)
props = counter_proportions(counts)
# xpos = categorical_counter_xlabels(counts)

reassortant_proportions = pd.DataFrame(props.values(), index=props.keys()).sort(0, ascending=False)
reassortant_proportions.columns = ['Reassortant Viruses']

counts = Counter(all_hosts)
props = counter_proportions(counts)
all_proportions = pd.DataFrame(props.values(), index=props.keys()).sort(0, ascending=False)
all_proportions.columns = ['All Viruses']

joined_proportions = all_proportions.join(reassortant_proportions)
joined_proportions.plot(kind='bar', grid=False, figsize=golden_figsize(2), color=['green', 'blue'])

# Plotting parameters.
ax = plt.gca()
# plt.xlabel('Host Species')
ax.set_ylabel('Proportion', fontsize=7)
ax.set_title("Proportion of Viruses' Host Species", fontsize=9)
plt.ylim(0, 1)
plt.legend(fontsize=7)
xlabels = ax.get_xticklabels()
plt.setp(xlabels, rotation=0, ha='center', fontsize=7) 
ylabels = ax.get_yticklabels()
plt.setp(ylabels, fontsize=7)

ax.annotate('d.', xy=(0,1), ha='left', va='top', xycoords='figure fraction')

plt.subplots_adjust(bottom=0.2, right=0.95, left=0.15)
plt.savefig('Proportion of Reassortant Viruses Host Species.pdf')

# %%
# Perform host species permutation test to assess what the distribution of reassortant viruses would be under null.

host_shuffledG = G.copy()

proportions = []

for i in range(1000):
    reassortant_species = dict()
    from random import shuffle
    hosts = [get_host_group(G, n) for n in G.nodes()]
    shuffle(hosts)

    # Add in condensed host
    for i, n in enumerate(host_shuffledG.nodes()):
        host_shuffledG.node[n]['host_group'] = hosts[i]

    for n, d in host_shuffledG.nodes(data=True):
        if is_reassortant(G, n):
            if d['host_group'] not in reassortant_species.keys():
                reassortant_species[d['host_group']] = 1
            else:
                reassortant_species[d['host_group']] += 1
                
    proportions.append(reassortant_species)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3dff8bc73822> in <module>()
#       8     reassortant_species = dict()
#       9     from random import shuffle
# ---> 10     hosts = [get_host_group(G, n) for n in G.nodes()]
#      11     shuffle(hosts)
#      12
#
# NameError: name 'get_host_group' is not defined

# %%
pd.DataFrame(proportions)

# %%
# Create a detailed version of the counter, which includes the exact species represented.
detailed_hosts = []
for virus in reassortant_viruses:
    host = G.node[virus]['host_species']
    if '/' in host:
        host = host.split('/')[0]
    if 'null' in host:
        host = 'Unknown'
    detailed_hosts.append(host)

counts = Counter(detailed_hosts)
props = counter_proportions(counts)
xpos = categorical_counter_xlabels(counts)

pd.DataFrame(props.values(), index=props.keys()).sort(0, ascending=False).plot(kind='bar', figsize=(16,5), grid=False, legend=False, color='green')
fig = plt.gcf()
fig.set_size_inches(20,5) 
plt.xlabel('Host Species')
plt.ylabel('Proportion')
plt.title("Proportion of Reassortant Viruses' Host Species")
plt.savefig('Proportion of Reassortant Viruses Host Species (Detailed).pdf', bbox_inches='tight')

# %%
# Create a detailed version of the counter, which includes the exact AVIAN only species represented.
detailed_avians = []
for virus in reassortant_viruses:
    host = G.node[virus]['host_species']
    if 'Avian' in host or 'avian' in host:
        if '/' in host:
            host = host.split('/')[0]
        detailed_avians.append(host)

counts = Counter(detailed_avians)
props = counter_proportions(counts)
xpos = categorical_counter_xlabels(counts)

pd.DataFrame(props.values(), index=props.keys()).sort(0, ascending=False).plot(kind='bar', figsize=(16,5), grid=False, legend=False, color='green')
fig = plt.gcf()
fig.set_size_inches(16,5) 
plt.xlabel('Host Species')
plt.ylabel('Proportion')
plt.title("Proportion of Reassortant Viruses' Avian Host Species")
plt.savefig('Proportion of Reassortant Viruses Host Species (Avian Only).pdf', bbox_inches='tight')

# %% [markdown]
# # Sampling Size Biases Subtype Connectivity?
#
# Does sampling size for a particular subtype bias the subtype's connectivity with other subtypes via reassortment?

# %%
subtype_counts = Counter()
for n, d in G.nodes(data=True):
    subtype = d['subtype']
    subtype_counts[subtype] += 1
    
subtype_counts
# Out:
# Counter({'H1N1': 5565, 'H3N2': 4349, 'H5N1': 794, 'H3N8': 714, 'H4N6': 680, 'H1N2': 446, 'H9N2': 357, 'H6N2': 300, 'H10N7': 291, 'H5N2': 259, 'H7N3': 223, 'H11N9': 223, 'H6N1': 188, 'H7N2': 179, 'H2N3': 152, 'H6N6': 141, 'H6N8': 117, 'H4N8': 95, 'H3N6': 90, 'H7N9': 84, 'H7N7': 83, 'H4N2': 67, 'H12N5': 67, 'H11N2': 66, 'H8N4': 65, 'Mixed': 51, 'H7N1': 46, 'H5N8': 43, 'H5N5': 36, 'H5N3': 35, 'H2N2': 34, 'H1N9': 34, 'H10N1': 32, 'H3N1': 32, 'H6N5': 29, 'H2N9': 28, 'H10N3': 26, 'H2N1': 26, 'H1N3': 26, 'H10N4': 24, 'H16N3': 24, 'H11N1': 23, 'H7N6': 20, 'H4N9': 20, 'H2N7': 19, 'H2N5': 18, 'H10N8': 16, 'H11N3': 15, 'H10N6': 14, 'H10N9': 13, 'H6N3': 13, 'H7N4': 13, 'H13N6': 13, 'H3N3': 12, 'H11N8': 11, 'H2N8': 10, 'H4N3': 10, 'H1N8': 10, 'H9N5': 10, 'H13N8': 10, 'H10N5': 9, 'H3N5': 9, 'H9N1': 9, 'H9N9': 9, 'H10N2': 8, 'H4N1': 8, 'H7N8': 8, 'H5N9': 7, 'H1N7': 7, 'H5N7': 6, 'H3N9': 6, 'H6N4': 6, 'H4N5': 5, 'H6N9': 5, 'H11N6': 5, 'H12N4': 5, 'H13N9': 5, 'H4N7': 4, 'H6N7': 4, 'H1N6': 4, 'H1N4': 4, 'H9N7': 4, 'H12N8': 4, 'H11N7': 3, 'H3N7': 3, 'H5N6': 3, 'H12N7': 3, 'H13N2': 3, 'H8N1': 2, 'H9N8': 2, 'H5N4': 2, 'H1N5': 2, 'H9N3': 2, 'H9N6': 2, 'H12N3': 2, 'H14N6': 2, 'H14N2': 2, 'H2N4': 1, 'H2N6': 1, 'H8N8': 1, 'H8N2': 1, 'H12N9': 1, 'H4N4': 1, 'H7N5': 1, 'H12N6': 1, 'H12N2': 1, 'H12N1': 1, 'H15N9': 1, 'H15N4': 1})

# %%
centralities = pd.read_csv('Subtype Reassortment Centralities.csv', index_col=0)
centralities = dict(zip(centralities['Subtype'], centralities['Degree Centrality']))

# %%
def ols_fit_predict(xs, ys):

    est = sm.OLS(ys, xs) 
    est = est.fit()
    print(est.summary())

    # Create the best line of fit data for plotting
    x_prime = np.linspace(min(xs), max(xs), 100)[:,np.newaxis]
    x_prime = sm.add_constant(x_prime)
    y_hat = est.predict(x_prime[:,1]) 
    
    rsquared = '{0:.2f}'.format(est.rsquared)
    
    return x_prime, y_hat, rsquared

# %%
# Plot params
titlefs = 9 #title fontsize
axisfs = 7 #axis fontsize
figsize = (2.5, 2.5) #figure size in inches

# %%
# Code to make scatterplot of subtype_counts vs centrality
xs = [] # centralities
ys = [] # counts in the dataset

for subtype, count in subtype_counts.items():
    xs.append(centralities[subtype])
    ys.append(count)
    
# Perform OLS regression
x_prime, y_hat, rsquared = ols_fit_predict(xs, ys)

# Plot the scatterplot and OLS
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111)
ax.scatter(xs, ys, color='blue')
ax.plot(x_prime[:,1],y_hat, 'r')

ax.annotate(r'$r^2: {0}$'.format(rsquared), xy=(0.5, 0.3), xycoords='axes fraction', ha='left', va='center', fontsize=9)
ax.annotate(r'b.', xy=(0,1), xycoords='figure fraction', va='top')

# Plot parameters
ax.set_xlabel('Connectivity', fontsize=axisfs)
ax.set_ylabel('Number of Isolates \n Represented (x1000)', fontsize=axisfs)
ax.set_yticklabels(np.arange(-1, 7, 1))
ax.set_xticks(np.arange(0, 0.9, 0.2))
ax.set_title('Sampling Effort', fontsize=titlefs)
plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.85)
plt.savefig('Subtype Representation vs. Subtype Connectivity.pdf')

# Save the data as a CSV file
csv_data = pd.DataFrame(xs, ys).reset_index()
csv_data.columns = ['Degree Centrality', 'Num Samples']
csv_data.to_csv('Subtype Representation vs. Subtype Connectivity.csv')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.167
# Method:                 Least Squares   F-statistic:                     22.79
# Date:                Tue, 19 May 2015   Prob (F-statistic):           5.70e-06
# Time:                        21:48:56   Log-Likelihood:                -857.20
# No. Observations:                 109   AIC:                             1716.
# Df Residuals:                     108   BIC:                             1719.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1          1117.3135    234.026      4.774      0.000       653.434  1581.193
# ==============================================================================
# Omnibus:                      182.726   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11069.814
# Skew:                           6.803   Prob(JB):                         0.00
# Kurtosis:                      50.458   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Reassortment Host Range and Connectivity
#
# One of the hypotheses I have is that that the inter-subtype degree centrality is related to the host range of the virus. To do this, I will plot a scatterplot of # of hosts represented against the degree centrality, for each subtype, with the radius of the dot proportional to the square root of the number of isolates represented.

# %%
subtype_hosts = dict()
subtype_counts = Counter()
for n, d in G.nodes(data=True):
    subtype = d['subtype']
    host = d['host_species']
    if host == 'mixed':
        host = 'Mixed'
    if host == 'null':
        host = 'Unknown'
    
    if subtype not in subtype_hosts.keys():
        subtype_hosts[subtype] = set()
        
    subtype_counts[subtype] += 1
    subtype_hosts[subtype].add(host)

# %%
# Code to make bubble plot.
xs = []
ys = []
ss = []
dot_labels = []
subtypes = []

# Precisely specify the xs, ys, and sizes of the dots.
for subtype, host_set in subtype_hosts.items():
    subtypes.append(subtype)
    xs.append(centralities[subtype])
    ys.append(len(subtype_hosts[subtype]))
    ss.append(math.sqrt(subtype_counts[subtype]))
    if centralities[subtype] > 0.4 or len(subtype_hosts[subtype]) > 25:
        dot_labels.append(subtype)
    else:
        dot_labels.append('')

x_prime, y_hat, rsquared = ols_fit_predict(xs, ys)

# Plot scatterplot
fig = plt.figure(figsize=(2.5,2.5))
ax = fig.add_subplot(111)
ax.scatter(xs, ys, s=ss, color='blue')
ax.plot(x_prime[:,1], y_hat, 'r')

# Additional plotting parameters
ax.set_xlabel('Connectivity', fontsize=axisfs)
ax.set_ylabel('Num. Unique Hosts Represented', fontsize=axisfs)
ax.set_title('Host Range', fontsize=titlefs)
ax.annotate(r'$r^2: {0}$'.format(rsquared), xy=(0.2, 0.5), xycoords='axes fraction', fontsize=9)
ax.annotate(r'c.', xy=(0,1), xycoords='figure fraction', va='top', ha='left')
ax.set_yticks(np.arange(0, 61, 20))
ax.set_xticks(np.arange(0, 0.9, 0.2))


plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.85)
plt.savefig('Host Range vs. Degree Centrality.pdf')

# Finally, make a dataframe of the data to accompany the plot.
data = {'subtypes':subtypes,
        'centralities':xs,
        'num_unique_hosts':ys,
        'num_isolates':[i**2 for i in ss]}
pd.DataFrame(data).to_csv('Host Range vs. Degree Centrality.csv')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.806
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     449.7
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):           2.69e-40
# Time:                        18:07:38   Log-Likelihood:                -342.86
# No. Observations:                 109   AIC:                             687.7
# Df Residuals:                     108   BIC:                             690.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            44.3010      2.089     21.206      0.000        40.160    48.442
# ==============================================================================
# Omnibus:                      145.506   Durbin-Watson:                   2.079
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5848.500
# Skew:                           4.639   Prob(JB):                         0.00
# Kurtosis:                      37.665   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Reassortment Geographic Range and Connectivity
#
# Similar to the question above: Is there a relationship between the number of unique countries in which each subtype has been found?

# %%
subtype_countries = dict()
for n, d in G.nodes(data=True):
    subtype = d['subtype']
    country = d['country']
    
    if subtype not in subtype_countries.keys():
        subtype_countries[subtype] = set()
        
    subtype_countries[subtype].add(country)

# %%
# Code to make bubble plot.
xs = []
ys = []
ss = []
dot_labels = []
subtypes = []

for subtype, host_set in subtype_hosts.items():
    subtypes.append(subtype)
    xs.append(centralities[subtype])
    ys.append(len(subtype_countries[subtype]))
    ss.append(math.sqrt(subtype_counts[subtype])) # Ensure that radius proportional to sqrt of counts.
    if centralities[subtype] > 0.2 and len(subtype_countries[subtype]) > 10:
        dot_labels.append(subtype)
    else:
        dot_labels.append('')

x_prime, y_hat, rsquared = ols_fit_predict(xs, ys)

# Plot the scatterplot
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111)
ax.scatter(xs, ys, s=ss, color='blue')
ax.plot(x_prime[:,1], y_hat, 'r')

ax.set_xlabel('Subtype Degree Centrality', fontsize=axisfs)
ax.set_ylabel('Num. Unique Countries Represented', fontsize=axisfs)
ax.set_title('Geographic Dispersal', fontsize=titlefs)
# ax.text(-0.05, -6, 'Size of bubble proportional to number of isolates', ha='left')
ax.annotate(r'$r^2: {0}$'.format(rsquared), xy=(0.2, 0.4), xycoords='axes fraction', fontsize=9)
ax.set_yticks(np.arange(0, 61, 20))
ax.set_xticks(np.arange(0, 0.9, 0.2))
ax.annotate(r'd.', xy=(0,1), xycoords='figure fraction', va='top', ha='left')

plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.85)
plt.savefig('Geographic Dispersal vs. Degree Centrality.pdf')

# Finally, make a dataframe of the data to accompany the plot.
data = {'subtypes':subtypes,
        'centralities':xs,
        'num_unique_countries':ys,
        'num_isolates':[i**2 for i in ss]}
pd.DataFrame(data).to_csv('Geographic Dispersal vs. Degree Centrality.csv')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.553
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     133.6
# Date:                Wed, 18 Mar 2015   Prob (F-statistic):           1.35e-20
# Time:                        18:07:39   Log-Likelihood:                -350.43
# No. Observations:                 109   AIC:                             702.9
# Df Residuals:                     108   BIC:                             705.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            25.8812      2.239     11.558      0.000        21.442    30.320
# ==============================================================================
# Omnibus:                      139.276   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3473.146
# Skew:                           4.581   Prob(JB):                         0.00
# Kurtosis:                      29.092   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Summary
#
# The geographic dispersal and host range both have a correlation with the degree centrality score. I interpret this as such: The geographic dispersal and host range probably have an impact on the subtype's status as a "hub" subtype.
#
# Using OLS regression, I have found that the sampling size is poorly correlated with the subtype degree centrality, and should not be biasing the data, while host range is the most correlated with subtype connectivity, followed by geographic dispersal.
