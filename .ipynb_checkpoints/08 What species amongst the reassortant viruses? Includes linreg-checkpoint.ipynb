# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import math
import statsmodels.api as sm 

from itertools import combinations, product, permutations
from __future__ import division
from collections import Counter
from scipy.stats.mstats import mquantiles
from scipy.stats import norm, expon, poisson, binom
from scipy.misc import comb
from IPython.display import Math
from networkx.readwrite import json_graph 
from geopy.geocoders import GeoNames
from geopy.geocoders import GoogleV3

# %matplotlib inline

# %%
def golden_figsize(height):
    """
    Assuming height dimension is the shorter one, the width should be:
    (1 + 5**0.5)/2
    
    This function thus returns the (width, height) tuple which is
    computed to be in a golden ratio.
    """
    width = height * (1 + 5**0.5) / 2
    return (width, height)

# %%
G = nx.read_gpickle('20141103 All IRD Final Graph.pkl')

# %%
geocoder = GoogleV3(timeout=5)

# %%
G.nodes(data=True)[15]
# Out:
# ('A/Canada-AB/RV1532/2009',
#  {'collection_date': Timestamp('2009-01-01 00:00:00'),
#   'country': 'Canada',
#   'host_species': 'Human',
#   'state': 'Canada-AB',
#   'subtype': 'H1N1'})

# %%
# Get a set of 'country:host species' mappings:

country_host = set()
for n, d in G.nodes(data=True):
    country = d['country']
    host = d['host_species']
    country_host.add((country, host))
    
country_host_new = pd.DataFrame(list(country_host))

# %%
# Nichola has coded them as wild/domestic and avian/mammalian. I will add these into the graph. 

# Load the data
df = pd.read_csv('Country-Species_coded.csv', index_col=0)

# Make it into a dicitonary where each entry is (country, species):habitat/setting
ecotype_map = dict()

for row, data in df.iterrows():
    country = data['Country']
    species = data['Species']
    ecotype = data['Habitat/setting']

    ecotype_map[(country, species)] = ecotype

# %%
def get_country_location_pairs(G):
    search_terms = set()
    node_search_terms = dict()
    for n, d in G.nodes(data=True):
        country = d['country']
        specific_region = n.split('/')[-3]
        
        cleaned_country = country.replace('_', ' ')
        
        if specific_region != cleaned_country:
            search_term = '{0}_{1}'.format(cleaned_country, specific_region)
    
        else:
            search_term = cleaned_country
        
        search_terms.add(search_term)
        node_search_terms[n] = search_term.replace('_', ' ')
    return search_terms, node_search_terms

countries_to_search, node_search_terms = get_country_location_pairs(G)
countries_to_search
ecotype_map
# Out:
# {('-N/A-', 'Ferret'): 'Domestic',
#  ('-N/A-', 'Human'): 'Human',
#  ('Afghanistan', 'Chicken'): 'Domestic',
#  ('Afghanistan', 'Chicken/Avian'): 'Domestic',
#  ('Argentina', 'Horse'): 'Domestic',
#  ('Argentina', 'Human'): 'Human',
#  ('Argentina', 'Rosy-Billed Pochard'): 'Wild',
#  ('Argentina', 'Rosy-Billed Pochard/Avian'): 'Wild',
#  ('Australia', 'Avian'): 'Unknown',
#  ('Australia', 'Black Duck'): 'Wild',
#  ('Australia', 'Black Duck/Avian'): 'Wild',
#  ('Australia', 'Chicken'): 'Domestic',
#  ('Australia', 'Chicken/Avian'): 'Domestic',
#  ('Australia', 'Duck'): 'Wild',
#  ('Australia', 'Duck/Avian'): 'Wild',
#  ('Australia', 'Emu'): 'Wild',
#  ('Australia', 'Emu/Avian'): 'Wild',
#  ('Australia', 'Human'): 'Human',
#  ('Australia', 'Red-Necked Stint'): 'Wild',
#  ('Australia', 'Red-Necked Stint/Avian'): 'Wild',
#  ('Australia', 'Sharp-Tailed Sandpiper'): 'Wild',
#  ('Australia', 'Sharp-Tailed Sandpiper/Avian'): 'Wild',
#  ('Australia', 'Sooty Tern'): 'Wild',
#  ('Australia', 'Sooty Tern/Avian'): 'Wild',
#  ('Australia', 'Starling'): 'Wild',
#  ('Australia', 'Starling/Avian'): 'Wild',
#  ('Australia', 'Teal'): 'Wild',
#  ('Australia', 'Teal/Avian'): 'Wild',
#  ('Austria', 'Horse'): 'Domestic',
#  ('Austria', 'Human'): 'Human',
#  ('Bangladesh', 'Chicken'): 'Domestic',
#  ('Bangladesh', 'Chicken/Avian'): 'Domestic',
#  ('Bangladesh', 'Duck'): 'Domestic',
#  ('Bangladesh', 'Duck/Avian'): 'Domestic',
#  ('Bangladesh', 'Environment'): 'Unknown',
#  ('Bangladesh', 'Quail'): 'Domestic',
#  ('Bangladesh', 'Quail/Avian'): 'Domestic',
#  ('Belgium', 'Human'): 'Human',
#  ('Belgium', 'Mallard'): 'Wild',
#  ('Belgium', 'Mallard/Avian'): 'Wild',
#  ('Belgium', 'Swine'): 'Domestic',
#  ('Bhutan', 'Chicken'): 'Domestic',
#  ('Bhutan', 'Chicken/Avian'): 'Domestic',
#  ('Bolivia', 'Human'): 'Human',
#  ('Brazil', 'Human'): 'Human',
#  ('Brazil', 'Semipalmated Sandpiper'): 'Wild',
#  ('Brazil', 'Semipalmated Sandpiper/Avian'): 'Wild',
#  ('Brazil', 'Swine'): 'Domestic',
#  ('Cambodia', 'Chicken'): 'Domestic',
#  ('Cambodia', 'Chicken/Avian'): 'Domestic',
#  ('Cambodia', 'Duck'): 'Domestic',
#  ('Cambodia', 'Duck/Avian'): 'Domestic',
#  ('Cambodia', 'Environment'): 'Unknown',
#  ('Cambodia', 'Human'): 'Human',
#  ('Cambodia', 'Stork'): 'Wild',
#  ('Cambodia', 'Stork/Avian'): 'Wild',
#  ('Canada', 'American Black Duck'): 'Wild',
#  ('Canada', 'American Black Duck/Avian'): 'Wild',
#  ('Canada', 'American Wigeon'): 'Wild',
#  ('Canada', 'American Wigeon/Avian'): 'Wild',
#  ('Canada', 'Avian'): 'Unknown',
#  ('Canada', 'Black Scoter'): 'Wild',
#  ('Canada', 'Black Scoter/Avian'): 'Wild',
#  ('Canada', 'Blue-Winged Teal'): 'Wild',
#  ('Canada', 'Blue-Winged Teal/Avian'): 'Wild',
#  ('Canada', 'Bufflehead'): 'Wild',
#  ('Canada', 'Bufflehead/Avian'): 'Wild',
#  ('Canada', 'Canada Goose'): 'Wild',
#  ('Canada', 'Canada Goose/Avian'): 'Wild',
#  ('Canada', 'Chicken'): 'Domestic',
#  ('Canada', 'Chicken/Avian'): 'Domestic',
#  ('Canada', 'Common Coot'): 'Wild',
#  ('Canada', 'Common Coot/Avian'): 'Wild',
#  ('Canada', 'Duck'): 'Unknown',
#  ('Canada', 'Duck/Avian'): 'Wild',
#  ('Canada', 'Goose'): 'Wild',
#  ('Canada', 'Goose/Avian'): 'Wild',
#  ('Canada', 'Green-Winged Teal'): 'Wild',
#  ('Canada', 'Green-Winged Teal/Avian'): 'Wild',
#  ('Canada', 'Hooded Merganser'): 'Wild',
#  ('Canada', 'Hooded Merganser/Avian'): 'Wild',
#  ('Canada', 'Human'): 'Human',
#  ('Canada', 'Lesser Scaup'): 'Wild',
#  ('Canada', 'Lesser Scaup/Avian'): 'Wild',
#  ('Canada', 'Mallard'): 'Wild',
#  ('Canada', 'Mallard-Black Duck Hybrid'): 'Wild',
#  ('Canada', 'Mallard-Black Duck Hybrid/Avian'): 'Wild',
#  ('Canada', 'Mallard/Avian'): 'Wild',
#  ('Canada', 'Murre'): 'Wild',
#  ('Canada', 'Murre/Avian'): 'Wild',
#  ('Canada', 'Northern Pintail'): 'Wild',
#  ('Canada', 'Northern Pintail/Avian'): 'Wild',
#  ('Canada', 'Pintail'): 'Wild',
#  ('Canada', 'Pintail/Avian'): 'Wild',
#  ('Canada', 'Redhead'): 'Wild',
#  ('Canada', 'Redhead Duck'): 'Wild',
#  ('Canada', 'Redhead Duck/Avian'): 'Wild',
#  ('Canada', 'Redhead/Avian'): 'Wild',
#  ('Canada', 'Ruddy Turnstone'): 'Wild',
#  ('Canada', 'Ruddy Turnstone/Avian'): 'Wild',
#  ('Canada', 'Scaup'): 'Wild',
#  ('Canada', 'Scaup/Avian'): 'Wild',
#  ('Canada', 'Shoveler'): 'Wild',
#  ('Canada', 'Shoveler/Avian'): 'Wild',
#  ('Canada', 'Swan'): 'Wild',
#  ('Canada', 'Swan/Avian'): 'Wild',
#  ('Canada', 'Swine'): 'Domestic',
#  ('Canada', 'Turkey'): 'Domestic',
#  ('Canada', 'Turkey/Avian'): 'Domestic',
#  ('Canada', 'Unknown'): 'Unknown',
#  ('Canada', 'White-Rumped Sandpiper'): 'Wild',
#  ('Canada', 'White-Rumped Sandpiper/Avian'): 'Wild',
#  ('Canada', 'null'): 'Unknown',
#  ('Chile', 'Human'): 'Human',
#  ('China', 'Baikal Teal'): 'Wild',
#  ('China', 'Baikal Teal/Avian'): 'Wild',
#  ('China', 'Bar-Headed Goose'): 'Wild',
#  ('China', 'Bar-Headed Goose/Avian'): 'Wild',
#  ('China', 'Bird'): 'Unknown',
#  ('China', 'Bird/Avian'): 'Wild',
#  ('China', 'Black-Billed Magpie'): 'Wild',
#  ('China', 'Black-Billed Magpie/Avian'): 'Wild',
#  ('China', 'Brown-Headed Gull'): 'Wild',
#  ('China', 'Brown-Headed Gull/Avian'): 'Wild',
#  ('China', 'Canvasback'): 'Wild',
#  ('China', 'Canvasback/Avian'): 'Wild',
#  ('China', 'Chicken'): 'Domestic',
#  ('China', 'Chicken/Avian'): 'Domestic',
#  ('China', 'Condor'): 'Wild',
#  ('China', 'Condor/Avian'): 'Wild',
#  ('China', 'Dog'): 'Domestic',
#  ('China', 'Domestic Cat'): 'Domestic',
#  ('China', 'Duck'): 'Domestic',
#  ('China', 'Duck/Avian'): 'Domestic',
#  ('China', 'Egret'): 'Wild',
#  ('China', 'Egret/Avian'): 'Wild',
#  ('China', 'Environment'): 'Unknown',
#  ('China', 'Finch'): 'Wild',
#  ('China', 'Finch/Avian'): 'Wild',
#  ('China', 'Garganey'): 'Wild',
#  ('China', 'Garganey/Avian'): 'Wild',
#  ('China', 'Goose'): 'Domestic',
#  ('China', 'Goose/Avian'): 'Domestic',
#  ('China', 'Great Black-Headed Gull'): 'Wild',
#  ('China', 'Great Black-Headed Gull/Avian'): 'Wild',
#  ('China', 'Grebe'): 'Wild',
#  ('China', 'Grebe/Avian'): 'Wild',
#  ('China', 'Green-Winged Teal'): 'Wild',
#  ('China', 'Green-Winged Teal/Avian'): 'Wild',
#  ('China', 'Horse'): 'Domestic',
#  ('China', 'Human'): 'Human',
#  ('China', 'Large Cat'): 'Domestic',
#  ('China', 'Little Grebe'): 'Wild',
#  ('China', 'Little Grebe/Avian'): 'Wild',
#  ('China', 'Magpie'): 'Wild',
#  ('China', 'Magpie/Avian'): 'Wild',
#  ('China', 'Mallard'): 'Wild',
#  ('China', 'Mallard/Avian'): 'Wild',
#  ('China', 'Muscovy Duck'): 'Domestic',
#  ('China', 'Muscovy Duck/Avian'): 'Domestic',
#  ('China', 'Myna'): 'Wild',
#  ('China', 'Myna/Avian'): 'Wild',
#  ('China', 'Ostrich'): 'Wild',
#  ('China', 'Ostrich/Avian'): 'Wild',
#  ('China', 'Panda'): 'Wild',
#  ('China', 'Parrot'): 'Wild',
#  ('China', 'Parrot/Avian'): 'Wild',
#  ('China', 'Pigeon'): 'Wild',
#  ('China', 'Pigeon/Avian'): 'Wild',
#  ('China', 'Quail'): 'Domestic',
#  ('China', 'Quail/Avian'): 'Domestic',
#  ('China', 'Shrike'): 'Wild',
#  ('China', 'Shrike/Avian'): 'Wild',
#  ('China', 'Silky Chicken'): 'Domestic',
#  ('China', 'Silky Chicken/Avian'): 'Domestic',
#  ('China', 'Sparrow'): 'Wild',
#  ('China', 'Sparrow/Avian'): 'Wild',
#  ('China', 'Spot-Billed Duck'): 'Wild',
#  ('China', 'Spot-Billed Duck/Avian'): 'Domestic',
#  ('China', 'Swan'): 'Wild',
#  ('China', 'Swan/Avian'): 'Wild',
#  ('China', 'Swine'): 'Domestic',
#  ('China', 'Waterfowl'): 'Wild',
#  ('China', 'Waterfowl/Avian'): 'Wild',
#  ('China', 'Wild Chicken'): 'Domestic',
#  ('China', 'Wild Chicken/Avian'): 'Wild',
#  ('Colombia', 'Human'): 'Human',
#  ('Cote dIvoire', 'Chicken'): 'Domestic',
#  ('Cote dIvoire', 'Chicken/Avian'): 'Domestic',
#  ('Cote dIvoire', 'Duck'): 'Domestic',
#  ('Cote dIvoire', 'Duck/Avian'): 'Domestic',
#  ('Cote dIvoire', 'Turkey'): 'Domestic',
#  ('Cote dIvoire', 'Turkey/Avian'): 'Domestic',
#  ('Croatia', 'Mute Swan'): 'Wild',
#  ('Croatia', 'Mute Swan/Avian'): 'Wild',
#  ('Czech Republic', 'Human'): 'Human',
#  ('Czech Republic', 'Swine'): 'Domestic',
#  ('Denmark', 'Duck'): 'Unknown',
#  ('Denmark', 'Duck/Avian'): 'Wild',
#  ('Denmark', 'Human'): 'Human',
#  ('Denmark', 'Swine'): 'Domestic',
#  ('Dominican Republic', 'Human'): 'Human',
#  ('Ecuador', 'Human'): 'Human',
#  ('Egypt', 'Avian'): 'Unknown',
#  ('Egypt', 'Chicken'): 'Domestic',
#  ('Egypt', 'Chicken/Avian'): 'Domestic',
#  ('Egypt', 'Duck'): 'Domestic',
#  ('Egypt', 'Duck/Avian'): 'Domestic',
#  ('Egypt', 'Goose'): 'Domestic',
#  ('Egypt', 'Goose/Avian'): 'Domestic',
#  ('Egypt', 'Turkey'): 'Domestic',
#  ('Egypt', 'Turkey/Avian'): 'Domestic',
#  ('Egypt', 'Whiskered Tern'): 'Wild',
#  ('Egypt', 'Whiskered Tern/Avian'): 'Wild',
#  ('El Salvador', 'Human'): 'Human',
#  ('Estonia', 'Human'): 'Human',
#  ('Finland', 'Human'): 'Human',
#  ('France', 'Duck'): 'Domestic',
#  ('France', 'Duck/Avian'): 'Wild',
#  ('France', 'Human'): 'Human',
#  ('France', 'Mallard'): 'Wild',
#  ('France', 'Mallard/Avian'): 'Wild',
#  ('France', 'Muscovy Duck'): 'Domestic',
#  ('France', 'Muscovy Duck/Avian'): 'Domestic',
#  ('France', 'Swine'): 'Domestic',
#  ('France', 'Turkey'): 'Domestic',
#  ('France', 'Turkey/Avian'): 'Domestic',
#  ('Georgia', 'Black-Headed Gull'): 'Wild',
#  ('Georgia', 'Black-Headed Gull/Avian'): 'Wild',
#  ('Georgia', 'Duck'): 'Domestic',
#  ('Georgia', 'Duck/Avian'): 'Wild',
#  ('Georgia', 'Garganey'): 'Wild',
#  ('Georgia', 'Garganey/Avian'): 'Wild',
#  ('Georgia', 'Gull'): 'Wild',
#  ('Georgia', 'Gull/Avian'): 'Wild',
#  ('Georgia', 'Mallard'): 'Wild',
#  ('Georgia', 'Mallard/Avian'): 'Wild',
#  ('Georgia', 'Northern Shoveler'): 'Wild',
#  ('Georgia', 'Northern Shoveler/Avian'): 'Wild',
#  ('Georgia', 'Teal'): 'Wild',
#  ('Georgia', 'Teal/Avian'): 'Wild',
#  ('Germany', 'Chicken'): 'Domestic',
#  ('Germany', 'Chicken/Avian'): 'Domestic',
#  ('Germany', 'Duck'): 'Unknown',
#  ('Germany', 'Duck/Avian'): 'Wild',
#  ('Germany', 'Human'): 'Human',
#  ('Germany', 'Mallard'): 'Wild',
#  ('Germany', 'Mallard/Avian'): 'Wild',
#  ('Germany', 'Mute Swan'): 'Wild',
#  ('Germany', 'Mute Swan/Avian'): 'Wild',
#  ('Germany', 'Swan'): 'Wild',
#  ('Germany', 'Swan/Avian'): 'Wild',
#  ('Germany', 'Swine'): 'Domestic',
#  ('Germany', 'Weasel'): 'Domestic',
#  ('Greece', 'Human'): 'Human',
#  ('Guam', 'Human'): 'Human',
#  ('Guatemala', 'Blue-Winged Teal'): 'Wild',
#  ('Guatemala', 'Blue-Winged Teal/Avian'): 'Wild',
#  ('Guatemala', 'Chicken'): 'Domestic',
#  ('Guatemala', 'Chicken/Avian'): 'Domestic',
#  ('Hong Kong', 'Avian'): 'Unknown',
#  ('Hong Kong', 'Barn Swallow'): 'Wild',
#  ('Hong Kong', 'Barn Swallow/Avian'): 'Wild',
#  ('Hong Kong', 'Chicken'): 'Domestic',
#  ('Hong Kong', 'Chicken/Avian'): 'Domestic',
#  ('Hong Kong', 'Chukar'): 'Domestic',
#  ('Hong Kong', 'Chukar/Avian'): 'Wild',
#  ('Hong Kong', 'Duck'): 'Domestic',
#  ('Hong Kong', 'Duck/Avian'): 'Domestic',
#  ('Hong Kong', 'Egret'): 'Wild',
#  ('Hong Kong', 'Egret/Avian'): 'Wild',
#  ('Hong Kong', 'Environment'): 'Unknown',
#  ('Hong Kong', 'Eurasian Wigeon'): 'Wild',
#  ('Hong Kong', 'Eurasian Wigeon/Avian'): 'Wild',
#  ('Hong Kong', 'Grey Heron'): 'Wild',
#  ('Hong Kong', 'Grey Heron/Avian'): 'Wild',
#  ('Hong Kong', 'Guineafowl'): 'Domestic',
#  ('Hong Kong', 'Guineafowl/Avian'): 'Domestic',
#  ('Hong Kong', 'Heron'): 'Wild',
#  ('Hong Kong', 'Heron/Avian'): 'Wild',
#  ('Hong Kong', 'Human'): 'Human',
#  ('Hong Kong', 'Little Egret'): 'Wild',
#  ('Hong Kong', 'Little Egret/Avian'): 'Wild',
#  ('Hong Kong', 'Magpie Robin'): 'Wild',
#  ('Hong Kong', 'Magpie Robin/Avian'): 'Wild',
#  ('Hong Kong', 'Northern Pintail'): 'Wild',
#  ('Hong Kong', 'Northern Pintail/Avian'): 'Wild',
#  ('Hong Kong', 'Northern Shoveler'): 'Wild',
#  ('Hong Kong', 'Northern Shoveler/Avian'): 'Wild',
#  ('Hong Kong', 'Peregrine Falcon'): 'Wild',
#  ('Hong Kong', 'Peregrine Falcon/Avian'): 'Wild',
#  ('Hong Kong', 'Pheasant'): 'Domestic',
#  ('Hong Kong', 'Pheasant/Avian'): 'Wild',
#  ('Hong Kong', 'Pigeon'): 'Wild',
#  ('Hong Kong', 'Pigeon/Avian'): 'Wild',
#  ('Hong Kong', 'Quail'): 'Domestic',
#  ('Hong Kong', 'Quail/Avian'): 'Domestic',
#  ('Hong Kong', 'Silky Chicken'): 'Domestic',
#  ('Hong Kong', 'Silky Chicken/Avian'): 'Domestic',
#  ('Hong Kong', 'Swine'): 'Domestic',
#  ('Hong Kong', 'Teal'): 'Wild',
#  ('Hong Kong', 'Teal/Avian'): 'Wild',
#  ('Hong Kong', 'Waterfowl'): 'Wild',
#  ('Hong Kong', 'Waterfowl/Avian'): 'Wild',
#  ('Hungary', 'Goose'): 'Unknown',
#  ('Hungary', 'Goose/Avian'): 'Wild',
#  ('Hungary', 'Human'): 'Human',
#  ('Hungary', 'Mute Swan'): 'Wild',
#  ('Hungary', 'Mute Swan/Avian'): 'Wild',
#  ('Hungary', 'Swine'): 'Domestic',
#  ('Iceland', 'Black-Headed Gull'): 'Wild',
#  ('Iceland', 'Black-Headed Gull/Avian'): 'Wild',
#  ('Iceland', 'Glaucous Gull'): 'Wild',
#  ('Iceland', 'Glaucous Gull/Avian'): 'Wild',
#  ('Iceland', 'Goose'): 'Wild',
#  ('Iceland', 'Goose/Avian'): 'Wild',
#  ('Iceland', 'Gull'): 'Wild',
#  ('Iceland', 'Gull/Avian'): 'Wild',
#  ('Iceland', 'Herring Gull'): 'Wild',
#  ('Iceland', 'Herring Gull/Avian'): 'Wild',
#  ('Iceland', 'Iceland Gull'): 'Wild',
#  ('Iceland', 'Iceland Gull/Avian'): 'Wild',
#  ('Iceland', 'Mallard'): 'Wild',
#  ('Iceland', 'Mallard/Avian'): 'Wild',
#  ('Iceland', 'Pink-Footed Goose'): 'Wild',
#  ('Iceland', 'Pink-Footed Goose/Avian'): 'Wild',
#  ('India', 'Aquatic Bird'): 'Wild',
#  ('India', 'Aquatic Bird/Avian'): 'Wild',
#  ('India', 'Chicken'): 'Domestic',
#  ('India', 'Chicken/Avian'): 'Domestic',
#  ('India', 'Goose'): 'Domestic',
#  ('India', 'Goose/Avian'): 'Domestic',
#  ('India', 'Human'): 'Human',
#  ('Indonesia', 'Chicken'): 'Domestic',
#  ('Indonesia', 'Chicken/Avian'): 'Domestic',
#  ('Indonesia', 'Duck'): 'Domestic',
#  ('Indonesia', 'Duck/Avian'): 'Domestic',
#  ('Indonesia', 'Human'): 'Human',
#  ('Indonesia', 'Quail'): 'Domestic',
#  ('Indonesia', 'Quail/Avian'): 'Domestic',
#  ('Indonesia', 'Swine'): 'Domestic',
#  ('Iran', 'Chicken'): 'Domestic',
#  ('Iran', 'Chicken/Avian'): 'Domestic',
#  ('Iraq', 'Human'): 'Human',
#  ('Israel', 'Avian'): 'Domestic',
#  ('Israel', 'Chicken'): 'Domestic',
#  ('Israel', 'Chicken/Avian'): 'Domestic',
#  ('Israel', 'Turkey'): 'Domestic',
#  ('Israel', 'Turkey/Avian'): 'Domestic',
#  ('Italy', 'Chicken'): 'Domestic',
#  ('Italy', 'Chicken/Avian'): 'Domestic',
#  ('Italy', 'Duck'): 'Domestic',
#  ('Italy', 'Duck/Avian'): 'Wild',
#  ('Italy', 'Guineafowl'): 'Domestic',
#  ('Italy', 'Guineafowl/Avian'): 'Wild',
#  ('Italy', 'Horse'): 'Domestic',
#  ('Italy', 'Human'): 'Human',
#  ('Italy', 'Mallard'): 'Wild',
#  ('Italy', 'Mallard/Avian'): 'Wild',
#  ('Italy', 'Mute Swan'): 'Wild',
#  ('Italy', 'Mute Swan/Avian'): 'Wild',
#  ('Italy', 'Ostrich'): 'Wild',
#  ('Italy', 'Ostrich/Avian'): 'Wild',
#  ('Italy', 'Poultry'): 'Domestic',
#  ('Italy', 'Poultry/Avian'): 'Domestic',
#  ('Italy', 'Quail'): 'Domestic',
#  ('Italy', 'Quail/Avian'): 'Domestic',
#  ('Italy', 'Swine'): 'Domestic',
#  ('Italy', 'Teal'): 'Wild',
#  ('Italy', 'Teal/Avian'): 'Wild',
#  ('Italy', 'Turkey'): 'Domestic',
#  ('Italy', 'Turkey/Avian'): 'Domestic',
#  ('Japan', 'Avian'): 'Unknown',
#  ('Japan', 'Chicken'): 'Domestic',
#  ('Japan', 'Chicken/Avian'): 'Domestic',
#  ('Japan', 'Crane'): 'Wild',
#  ('Japan', 'Crane/Avian'): 'Wild',
#  ('Japan', 'Crow'): 'Wild',
#  ('Japan', 'Crow/Avian'): 'Wild',
#  ('Japan', 'Duck'): 'Unknown',
#  ('Japan', 'Duck/Avian'): 'Domestic',
#  ('Japan', 'Eagle'): 'Wild',
#  ('Japan', 'Eagle/Avian'): 'Wild',
#  ('Japan', 'Falcon'): 'Wild',
#  ('Japan', 'Falcon/Avian'): 'Wild',
#  ('Japan', 'Human'): 'Human',
#  ('Japan', 'Mallard'): 'Wild',
#  ('Japan', 'Mallard/Avian'): 'Wild',
#  ('Japan', 'Northern Pintail'): 'Wild',
#  ('Japan', 'Northern Pintail/Avian'): 'Wild',
#  ('Japan', 'Parakeet'): 'Wild',
#  ('Japan', 'Parakeet/Avian'): 'Wild',
#  ('Japan', 'Peregrine Falcon'): 'Wild',
#  ('Japan', 'Peregrine Falcon/Avian'): 'Wild',
#  ('Japan', 'Quail'): 'Domestic',
#  ('Japan', 'Quail/Avian'): 'Domestic',
#  ('Japan', 'Swan'): 'Wild',
#  ('Japan', 'Swan/Avian'): 'Wild',
#  ('Japan', 'Swine'): 'Domestic',
#  ('Japan', 'Tufted Duck'): 'Wild',
#  ('Japan', 'Tufted Duck/Avian'): 'Wild',
#  ('Japan', 'Tundra Swan'): 'Wild',
#  ('Japan', 'Tundra Swan/Avian'): 'Wild',
#  ('Japan', 'Whooper Swan'): 'Wild',
#  ('Japan', 'Whooper Swan/Avian'): 'Wild',
#  ('Kazakhstan', 'Human'): 'Human',
#  ('Kuwait', 'Chicken'): 'Domestic',
#  ('Kuwait', 'Chicken/Avian'): 'Domestic',
#  ('Kuwait', 'Human'): 'Human',
#  ('Kuwait', 'Saker Falcon'): 'Wild',
#  ('Kuwait', 'Saker Falcon/Avian'): 'Wild',
#  ('Kyrgyzstan', 'Human'): 'Human',
#  ('Laos', 'Chicken'): 'Domestic',
#  ('Laos', 'Chicken/Avian'): 'Domestic',
#  ('Laos', 'Duck'): 'Domestic',
#  ('Laos', 'Duck/Avian'): 'Domestic',
#  ('Laos', 'Environment'): 'Unknown',
#  ('Laos', 'Pigeon'): 'Wild',
#  ('Laos', 'Pigeon/Avian'): 'Wild',
#  ('Lebanon', 'Human'): 'Human',
#  ('Lebanon', 'Quail'): 'Domestic',
#  ('Lebanon', 'Quail/Avian'): 'Domestic',
#  ('Luxembourg', 'Human'): 'Human',
#  ('Malaysia', 'Duck'): 'Domestic',
#  ('Malaysia', 'Duck/Avian'): 'Domestic',
#  ('Malaysia', 'Human'): 'Human',
#  ('Mexico', 'Chicken'): 'Domestic',
#  ('Mexico', 'Chicken/Avian'): 'Domestic',
#  ('Mexico', 'Cinnamon Teal'): 'Wild',
#  ('Mexico', 'Cinnamon Teal/Avian'): 'Wild',
#  ('Mexico', 'Human'): 'Human',
#  ('Mexico', 'Swine'): 'Domestic',
#  ('Mongolia', 'Black-Headed Gull'): 'Wild',
#  ('Mongolia', 'Black-Headed Gull/Avian'): 'Wild',
#  ('Mongolia', 'Camel'): 'Domestic',
#  ('Mongolia', 'Common Goldeneye'): 'Wild',
#  ('Mongolia', 'Common Goldeneye/Avian'): 'Wild',
#  ('Mongolia', 'Duck'): 'Wild',
#  ('Mongolia', 'Duck/Avian'): 'Wild',
#  ('Mongolia', 'Herring Gull'): 'Wild',
#  ('Mongolia', 'Herring Gull/Avian'): 'Wild',
#  ('Mongolia', 'Human'): 'Human',
#  ('Mongolia', 'Red-Crested Pochard'): 'Wild',
#  ('Mongolia', 'Red-Crested Pochard/Avian'): 'Wild',
#  ('Mongolia', 'Whooper Swan'): 'Wild',
#  ('Mongolia', 'Whooper Swan/Avian'): 'Wild',
#  ('Myanmar', 'Chicken'): 'Domestic',
#  ('Myanmar', 'Chicken/Avian'): 'Domestic',
#  ('Myanmar', 'Human'): 'Human',
#  ('Myanmar', 'Quail'): 'Domestic',
#  ('Myanmar', 'Quail/Avian'): 'Domestic',
#  ('Nepal', 'Human'): 'Human',
#  ('Netherlands', 'Barnacle Goose'): 'Wild',
#  ('Netherlands', 'Barnacle Goose/Avian'): 'Wild',
#  ('Netherlands', "Bewick's Swan"): 'Wild',
#  ('Netherlands', "Bewick's Swan/Avian"): 'Wild',
#  ('Netherlands', 'Black-Headed Gull'): 'Wild',
#  ('Netherlands', 'Black-Headed Gull/Avian'): 'Wild',
#  ('Netherlands', 'Chicken'): 'Domestic',
#  ('Netherlands', 'Chicken/Avian'): 'Domestic',
#  ('Netherlands', 'Common Eider'): 'Wild',
#  ('Netherlands', 'Common Eider/Avian'): 'Wild',
#  ('Netherlands', 'Eurasian Wigeon'): 'Wild',
#  ('Netherlands', 'Eurasian Wigeon/Avian'): 'Wild',
#  ('Netherlands', 'Goose'): 'Unknown',
#  ('Netherlands', 'Goose/Avian'): 'Wild',
#  ('Netherlands', 'Herring Gull'): 'Wild',
#  ('Netherlands', 'Herring Gull/Avian'): 'Wild',
#  ('Netherlands', 'Human'): 'Human',
#  ('Netherlands', 'Mallard'): 'Wild',
#  ('Netherlands', 'Mallard/Avian'): 'Wild',
#  ('Netherlands', 'Mute Swan'): 'Wild',
#  ('Netherlands', 'Mute Swan/Avian'): 'Wild',
#  ('Netherlands', 'Northern Shoveler'): 'Wild',
#  ('Netherlands', 'Northern Shoveler/Avian'): 'Wild',
#  ('Netherlands', 'Pink-Footed Goose'): 'Wild',
#  ('Netherlands', 'Pink-Footed Goose/Avian'): 'Wild',
#  ('Netherlands', 'Ruddy Turnstone'): 'Wild',
#  ('Netherlands', 'Ruddy Turnstone/Avian'): 'Wild',
#  ('Netherlands', 'Shoveler'): 'Wild',
#  ('Netherlands', 'Shoveler/Avian'): 'Wild',
#  ('Netherlands', 'Swine'): 'Domestic',
#  ('Netherlands', 'Teal'): 'Wild',
#  ('Netherlands', 'Teal/Avian'): 'Wild',
#  ('New Caledonia', 'Human'): 'Human',
#  ('New Zealand', 'Human'): 'Human',
#  ('New Zealand', 'Mallard'): 'Wild',
#  ('New Zealand', 'Mallard/Avian'): 'Wild',
#  ('Nicaragua', 'Human'): 'Human',
#  ('Nigeria', 'Chicken'): 'Domestic',
#  ('Nigeria', 'Chicken/Avian'): 'Domestic',
#  ('Nigeria', 'Guineafowl'): 'Domestic',
#  ('Nigeria', 'Guineafowl/Avian'): 'Domestic',
#  ('Nigeria', 'Ostrich'): 'Domestic',
#  ('Nigeria', 'Ostrich/Avian'): 'Wild',
#  ('Norway', 'Human'): 'Human',
#  ('Norway', 'Swine'): 'Domestic',
#  ('Ontario', 'Swine'): 'Domestic',
#  ('Pakistan', 'Chicken'): 'Domestic',
#  ('Pakistan', 'Chicken/Avian'): 'Domestic',
#  ('Peru', 'Human'): 'Human',
#  ('Philippines', 'Human'): 'Human',
#  ('Poland', 'Chicken'): 'Domestic',
#  ('Poland', 'Chicken/Avian'): 'Domestic',
#  ('Poland', 'Human'): 'Human',
#  ('Poland', 'Swine'): 'Domestic',
#  ('Poland', 'Turkey'): 'Domestic',
#  ('Poland', 'Turkey/Avian'): 'Domestic',
#  ('Portugal', 'Mallard'): 'Wild',
#  ('Portugal', 'Mallard/Avian'): 'Wild',
#  ('Portugal', 'Tufted Duck'): 'Wild',
#  ('Portugal', 'Tufted Duck/Avian'): 'Wild',
#  ('Qatar', 'Human'): 'Human',
#  ('Romania', 'Horse'): 'Domestic',
#  ('Russia', 'Chicken'): 'Domestic',
#  ('Russia', 'Chicken/Avian'): 'Domestic',
#  ('Russia', 'Duck'): 'Domestic',
#  ('Russia', 'Duck/Avian'): 'Wild',
#  ('Russia', 'Gadwall'): 'Wild',
#  ('Russia', 'Gadwall/Avian'): 'Wild',
#  ('Russia', 'Garganey'): 'Wild',
#  ('Russia', 'Garganey/Avian'): 'Wild',
#  ('Russia', 'Goose'): 'Wild',
#  ('Russia', 'Goose/Avian'): 'Wild',
#  ('Russia', 'Great Crested Grebe'): 'Wild',
#  ('Russia', 'Great Crested Grebe/Avian'): 'Wild',
#  ('Russia', 'Grebe'): 'Wild',
#  ('Russia', 'Grebe/Avian'): 'Wild',
#  ('Russia', 'Gull'): 'Wild',
#  ('Russia', 'Gull/Avian'): 'Wild',
#  ('Russia', 'Human'): 'Human',
#  ('Russia', 'Mallard'): 'Wild',
#  ('Russia', 'Mallard/Avian'): 'Wild',
#  ('Russia', 'Muscovy Duck'): 'Domestic',
#  ('Russia', 'Muscovy Duck/Avian'): 'Domestic',
#  ('Russia', 'Mute Swan'): 'Wild',
#  ('Russia', 'Mute Swan/Avian'): 'Wild',
#  ('Russia', 'Pigeon'): 'Wild',
#  ('Russia', 'Pigeon/Avian'): 'Wild',
#  ('Russia', 'Rook'): 'Wild',
#  ('Russia', 'Rook/Avian'): 'Wild',
#  ('Russia', 'Starling'): 'Wild',
#  ('Russia', 'Starling/Avian'): 'Wild',
#  ('Russia', 'Teal'): 'Wild',
#  ('Russia', 'Teal/Avian'): 'Wild',
#  ('Russia', 'Turkey'): 'Domestic',
#  ('Russia', 'Turkey/Avian'): 'Domestic',
#  ('Russia', 'Unknown'): 'Unknown',
#  ('Russia', 'Whooper Swan'): 'Wild',
#  ('Russia', 'Whooper Swan/Avian'): 'Wild',
#  ('Russia', 'null'): 'Unknown',
#  ('Saudi Arabia', 'Avian'): 'Domestic',
#  ('Saudi Arabia', 'Falcon'): 'Wild',
#  ('Saudi Arabia', 'Falcon/Avian'): 'Wild',
#  ('Saudi Arabia', 'Turkey'): 'Domestic',
#  ('Saudi Arabia', 'Turkey/Avian'): 'Domestic',
#  ('Senegal', 'Human'): 'Human',
#  ('Singapore', 'Human'): 'Human',
#  ('Slovenia', 'Swan'): 'Wild',
#  ('Slovenia', 'Swan/Avian'): 'Wild',
#  ('South Africa', 'Horse'): 'Domestic',
#  ('South Africa', 'Human'): 'Human',
#  ('South Africa', 'Ostrich'): 'Wild',
#  ('South Africa', 'Ostrich/Avian'): 'Wild',
#  ('South Korea', 'Aquatic Bird'): 'Wild',
#  ('South Korea', 'Aquatic Bird/Avian'): 'Wild',
#  ('South Korea', 'Baikal Teal'): 'Wild',
#  ('South Korea', 'Baikal Teal/Avian'): 'Wild',
#  ('South Korea', 'Bird'): 'Unknown',
#  ('South Korea', 'Bird/Avian'): 'Wild',
#  ('South Korea', 'Chicken'): 'Domestic',
#  ('South Korea', 'Chicken/Avian'): 'Domestic',
#  ('South Korea', 'Common Coot'): 'Wild',
#  ('South Korea', 'Common Coot/Avian'): 'Wild',
#  ('South Korea', 'Dog'): 'Domestic',
#  ('South Korea', 'Domestic Cat'): 'Domestic',
#  ('South Korea', 'Duck'): 'Domestic',
#  ('South Korea', 'Duck/Avian'): 'Domestic',
#  ('South Korea', 'Environment'): 'Unknown',
#  ('South Korea', 'Eurasian Eagle-Owl'): 'Wild',
#  ('South Korea', 'Eurasian Eagle-Owl/Avian'): 'Wild',
#  ('South Korea', 'Goose'): 'Domestic',
#  ('South Korea', 'Goose/Avian'): 'Domestic',
#  ('South Korea', 'Horse'): 'Domestic',
#  ('South Korea', 'Human'): 'Human',
#  ('South Korea', 'Mallard'): 'Wild',
#  ('South Korea', 'Mallard/Avian'): 'Wild',
#  ('South Korea', 'Swine'): 'Domestic',
#  ('South Korea', 'Teal'): 'Wild',
#  ('South Korea', 'Teal/Avian'): 'Wild',
#  ('South Korea', 'Tundra Swan'): 'Wild',
#  ('South Korea', 'Tundra Swan/Avian'): 'Wild',
#  ('South Korea', 'Waterfowl'): 'Wild',
#  ('South Korea', 'Waterfowl/Avian'): 'Wild',
#  ('Spain', 'Human'): 'Human',
#  ('Spain', 'Swine'): 'Domestic',
#  ('Sudan', 'Chicken'): 'Domestic',
#  ('Sudan', 'Chicken/Avian'): 'Domestic',
#  ('Sweden', 'Black-Headed Gull'): 'Wild',
#  ('Sweden', 'Black-Headed Gull/Avian'): 'Wild',
#  ('Sweden', 'Dunlin'): 'Wild',
#  ('Sweden', 'Dunlin/Avian'): 'Wild',
#  ('Sweden', 'Eurasian Wigeon'): 'Wild',
#  ('Sweden', 'Eurasian Wigeon/Avian'): 'Wild',
#  ('Sweden', 'Human'): 'Human',
#  ('Sweden', 'Mallard'): 'Wild',
#  ('Sweden', 'Mallard/Avian'): 'Wild',
#  ('Sweden', 'Weasel'): 'Domestic',
#  ('Switzerland', 'Horse'): 'Domestic',
#  ('Switzerland', 'Human'): 'Human',
#  ('Taiwan', 'Chicken'): 'Domestic',
#  ('Taiwan', 'Chicken/Avian'): 'Domestic',
#  ('Taiwan', 'Duck'): 'Domestic ',
#  ('Taiwan', 'Duck/Avian'): 'Domestic',
#  ('Taiwan', 'Ferret'): 'Domestic',
#  ('Taiwan', 'Human'): 'Human',
#  ('Taiwan', 'Partridge'): 'Domestic ',
#  ('Taiwan', 'Partridge/Avian'): 'Wild',
#  ('Taiwan', 'Swine'): 'Domestic',
#  ('Thailand', 'Chicken'): 'Domestic',
#  ('Thailand', 'Chicken/Avian'): 'Domestic',
#  ('Thailand', 'Duck'): 'Domestic',
#  ('Thailand', 'Duck/Avian'): 'Domestic',
#  ('Thailand', 'Human'): 'Human',
#  ('Thailand', 'Little Grebe'): 'Wild',
#  ('Thailand', 'Little Grebe/Avian'): 'Wild',
#  ('Thailand', 'Openbill Stork'): 'Wild',
#  ('Thailand', 'Openbill Stork/Avian'): 'Wild',
#  ('Thailand', 'Pigeon'): 'Wild',
#  ('Thailand', 'Pigeon/Avian'): 'Wild',
#  ('Thailand', 'Quail'): 'Domestic',
#  ('Thailand', 'Quail/Avian'): 'Domestic',
#  ('Thailand', 'Swine'): 'Domestic',
#  ('Thailand', 'Tree Sparrow'): 'Wild',
#  ('Thailand', 'Tree Sparrow/Avian'): 'Wild',
#  ('Thailand', 'Unknown'): 'Unknown',
#  ('Turkey', 'Human'): 'Human',
#  ('USA', 'American Black Duck'): 'Wild',
#  ('USA', 'American Black Duck/Avian'): 'Wild',
#  ('USA', 'American Green-Winged Teal'): 'Wild',
#  ('USA', 'American Green-Winged Teal/Avian'): 'Wild',
#  ('USA', 'American Wigeon'): 'Wild',
#  ('USA', 'American Wigeon/Avian'): 'Wild',
#  ('USA', 'Avian'): 'Unknown',
#  ('USA', 'Bird'): 'Unknown',
#  ('USA', 'Bird/Avian'): 'Wild',
#  ('USA', 'Black Duck'): 'Wild',
#  ('USA', 'Black Duck/Avian'): 'Wild',
#  ('USA', 'Black Scoter'): 'Wild',
#  ('USA', 'Black Scoter/Avian'): 'Wild',
#  ('USA', 'Blue-Winged Teal'): 'Wild',
#  ('USA', 'Blue-Winged Teal/Avian'): 'Wild',
#  ('USA', 'Bufflehead'): 'Wild',
#  ('USA', 'Bufflehead/Avian'): 'Wild',
#  ('USA', 'Canada Goose'): 'Wild',
#  ('USA', 'Canada Goose/Avian'): 'Wild',
#  ('USA', 'Chicken'): 'Domestic',
#  ('USA', 'Chicken/Avian'): 'Domestic',
#  ('USA', 'Chukar'): 'Wild',
#  ('USA', 'Chukar/Avian'): 'Wild',
#  ('USA', 'Cinnamon Teal'): 'Wild',
#  ('USA', 'Cinnamon Teal/Avian'): 'Wild',
#  ('USA', 'Common Eider'): 'Wild',
#  ('USA', 'Common Eider/Avian'): 'Wild',
#  ('USA', 'Common Goldeneye'): 'Wild',
#  ('USA', 'Common Goldeneye/Avian'): 'Wild',
#  ('USA', 'Common Murre'): 'Wild',
#  ('USA', 'Common Murre/Avian'): 'Wild',
#  ('USA', 'Common Scoter'): 'Wild',
#  ('USA', 'Common Scoter/Avian'): 'Wild',
#  ('USA', 'Coot'): 'Wild',
#  ('USA', 'Coot/Avian'): 'Wild',
#  ('USA', 'Dove'): 'Wild',
#  ('USA', 'Dove/Avian'): 'Wild',
#  ('USA', 'Duck'): 'Unknown',
#  ('USA', 'Duck/Avian'): 'Wild',
#  ('USA', 'Emu'): 'Unknown',
#  ('USA', 'Emu/Avian'): 'Wild',
#  ('USA', 'Environment'): 'Unknown',
#  ('USA', 'Gadwall'): 'Wild',
#  ('USA', 'Gadwall/Avian'): 'Wild',
#  ('USA', 'Goose'): 'Wild',
#  ('USA', 'Goose/Avian'): 'Wild',
#  ('USA', 'Greater Scaup'): 'Wild',
#  ('USA', 'Greater Scaup/Avian'): 'Wild',
#  ('USA', 'Greater White-Fronted Goose'): 'Wild',
#  ('USA', 'Greater White-Fronted Goose/Avian'): 'Wild',
#  ('USA', 'Grebe'): 'Wild',
#  ('USA', 'Grebe/Avian'): 'Wild',
#  ('USA', 'Green-Winged Teal'): 'Wild',
#  ('USA', 'Green-Winged Teal/Avian'): 'Wild',
#  ('USA', 'Guineafowl'): 'Domestic',
#  ('USA', 'Guineafowl/Avian'): 'Wild',
#  ('USA', 'Gull'): 'Wild',
#  ('USA', 'Gull/Avian'): 'Wild',
#  ('USA', 'Herring Gull'): 'Wild',
#  ('USA', 'Herring Gull/Avian'): 'Wild',
#  ('USA', 'Horse'): 'Domestic',
#  ('USA', 'Human'): 'Human',
#  ('USA', 'Knot'): 'Wild',
#  ('USA', 'Knot/Avian'): 'Wild',
#  ('USA', 'Laughing Gull'): 'Wild',
#  ('USA', 'Laughing Gull/Avian'): 'Wild',
#  ('USA', 'Least Sandpiper'): 'Wild',
#  ('USA', 'Least Sandpiper/Avian'): 'Wild',
#  ('USA', 'Lesser Scaup'): 'Wild',
#  ('USA', 'Lesser Scaup/Avian'): 'Wild',
#  ('USA', 'Long-Tailed Duck'): 'Wild',
#  ('USA', 'Long-Tailed Duck/Avian'): 'Wild',
#  ('USA', 'Mallard'): 'Wild',
#  ('USA', 'Mallard/Avian'): 'Wild',
#  ('USA', 'Muscovy Duck'): 'Domestic',
#  ('USA', 'Muscovy Duck/Avian'): 'Wild',
#  ('USA', 'Mute Swan'): 'Wild',
#  ('USA', 'Mute Swan/Avian'): 'Wild',
#  ('USA', 'Northern Pintail'): 'Wild',
#  ('USA', 'Northern Pintail/Avian'): 'Wild',
#  ('USA', 'Northern Shoveler'): 'Wild',
#  ('USA', 'Northern Shoveler/Avian'): 'Wild',
#  ('USA', 'Parrot'): 'Wild',
#  ('USA', 'Parrot/Avian'): 'Wild',
#  ('USA', 'Pheasant'): 'Wild',
#  ('USA', 'Pheasant/Avian'): 'Wild',
#  ('USA', 'Pigeon'): 'Wild',
#  ('USA', 'Pigeon/Avian'): 'Wild',
#  ('USA', 'Pintail'): 'Wild',
#  ('USA', 'Pintail/Avian'): 'Wild',
#  ('USA', 'Quail'): 'Domestic',
#  ('USA', 'Quail/Avian'): 'Wild',
#  ('USA', 'Red Knot'): 'Wild',
#  ('USA', 'Red Knot/Avian'): 'Wild',
#  ('USA', 'Redhead'): 'Wild',
#  ('USA', 'Redhead/Avian'): 'Wild',
#  ('USA', 'Rhea'): 'Unknown',
#  ('USA', 'Rhea/Avian'): 'Wild',
#  ('USA', 'Ring-Necked Duck'): 'Wild',
#  ('USA', 'Ring-Necked Duck/Avian'): 'Wild',
#  ('USA', 'Ruddy Turnstone'): 'Wild',
#  ('USA', 'Ruddy Turnstone/Avian'): 'Wild',
#  ('USA', 'Sanderling'): 'Wild',
#  ('USA', 'Sanderling/Avian'): 'Wild',
#  ('USA', 'Semipalmated Sandpiper'): 'Wild',
#  ('USA', 'Semipalmated Sandpiper/Avian'): 'Wild',
#  ('USA', 'Shorebird'): 'Wild',
#  ('USA', 'Shorebird/Avian'): 'Wild',
#  ('USA', 'Snow Goose'): 'Wild',
#  ('USA', 'Snow Goose/Avian'): 'Wild',
#  ('USA', 'Softbill'): 'Wild',
#  ('USA', 'Softbill/Avian'): 'Wild',
#  ('USA', 'Swan'): 'Wild',
#  ('USA', 'Swan/Avian'): 'Wild',
#  ('USA', 'Swine'): 'Domestic',
#  ('USA', 'Teal'): 'Wild',
#  ('USA', 'Teal/Avian'): 'Wild',
#  ('USA', 'Tundra Swan'): 'Wild',
#  ('USA', 'Tundra Swan/Avian'): 'Wild',
#  ('USA', 'Turkey'): 'Domestic',
#  ('USA', 'Turkey/Avian'): 'Domestic',
#  ('USA', 'Unknown'): 'Unknown',
#  ('USA', 'Waterfowl'): 'Wild',
#  ('USA', 'Waterfowl/Avian'): 'Wild',
#  ('USA', 'Weasel'): 'Domestic',
#  ('USA', 'White-Winged Scoter'): 'Wild',
#  ('USA', 'White-Winged Scoter/Avian'): 'Wild',
#  ('USA', 'null'): 'Unknown',
#  ('Uganda', 'Human'): 'Human',
#  ('United Arab Emirates', 'Chicken'): 'Domestic',
#  ('United Arab Emirates', 'Chicken/Avian'): 'Domestic',
#  ('United Kingdom', 'Horse'): 'Domestic',
#  ('United Kingdom', 'Human'): 'Human',
#  ('United Kingdom', 'Swine'): 'Domestic',
#  ('Viet Nam', 'Aquatic Bird'): 'Wild',
#  ('Viet Nam', 'Aquatic Bird/Avian'): 'Wild',
#  ('Viet Nam', 'Babbler'): 'Wild',
#  ('Viet Nam', 'Babbler/Avian'): 'Wild',
#  ('Viet Nam', 'Chicken'): 'Domestic',
#  ('Viet Nam', 'Chicken/Avian'): 'Domestic',
#  ('Viet Nam', 'Dove'): 'Wild',
#  ('Viet Nam', 'Dove/Avian'): 'Wild',
#  ('Viet Nam', 'Duck'): 'Domestic',
#  ('Viet Nam', 'Duck/Avian'): 'Domestic',
#  ('Viet Nam', 'Environment'): 'Unknown',
#  ('Viet Nam', 'Flycatcher'): 'Wild',
#  ('Viet Nam', 'Flycatcher/Avian'): 'Wild',
#  ('Viet Nam', 'Goose'): 'Domestic',
#  ('Viet Nam', 'Goose/Avian'): 'Domestic',
#  ('Viet Nam', 'Human'): 'Human',
#  ('Viet Nam', 'Japanese Quail'): 'Domestic',
#  ('Viet Nam', 'Japanese Quail/Avian'): 'Domestic',
#  ('Viet Nam', 'Mallard'): 'Wild',
#  ('Viet Nam', 'Mallard/Avian'): 'Wild',
#  ('Viet Nam', 'Muscovy Duck'): 'Domestic',
#  ('Viet Nam', 'Muscovy Duck/Avian'): 'Domestic',
#  ('Viet Nam', 'Quail'): 'Domestic',
#  ('Viet Nam', 'Quail/Avian'): 'Domestic',
#  ('Viet Nam', 'Swine'): 'Domestic',
#  ('Zambia', 'Duck'): 'Wild',
#  ('Zambia', 'Duck/Avian'): 'Domestic',
#  ('Zambia', 'Pelican'): 'Wild',
#  ('Zambia', 'Pelican/Avian'): 'Wild'}

# %%
countries_to_search
# Out:
# {'-N/A-_Indonesia',
#  '-N/A-_St.Petersburg',
#  'Afghanistan',
#  'Argentina',
#  'Argentina_Cordoba',
#  'Australia',
#  'Australia_AUS',
#  'Australia_Brisbane',
#  'Australia_Bunbury',
#  'Australia_Cairns North',
#  'Australia_Canberra',
#  'Australia_Darlinghurst',
#  'Australia_Melbourne',
#  'Australia_New South Wales',
#  'Australia_North Fitzroy',
#  'Australia_Perth',
#  'Australia_Queensland',
#  'Australia_South Austalia',
#  'Australia_South Australia',
#  'Australia_Sydney',
#  'Australia_Tasmania',
#  'Australia_Victoria',
#  'Australia_Western Australia',
#  'Australia_Westmead',
#  'Australia_chicken',
#  'Australia_starling',
#  'Austria',
#  'Austria_Vienna',
#  'Bangladesh',
#  'Belgium',
#  'Belgium_Antwerp',
#  'Belgium_Brussels',
#  'Belgium_Gent',
#  'Belgium_Tessenderlo',
#  'Bhutan',
#  'Bolivia_Santa Cruz',
#  'Brazil',
#  'Cambodia',
#  'Canada',
#  'Canada_AB',
#  'Canada_ALB',
#  'Canada_Alberta',
#  'Canada_BC',
#  'Canada_British Columbia',
#  'Canada_Canada-AB',
#  'Canada_Canada-MB',
#  'Canada_Canada-NS',
#  'Canada_Canada-ON',
#  'Canada_Canada-PQ',
#  'Canada_Canada-QC',
#  'Canada_Canada-SK',
#  'Canada_GSC_chicken',
#  'Canada_GSC_chicken_B',
#  'Canada_MB',
#  'Canada_Manitoba',
#  'Canada_NB',
#  'Canada_New Brunswick',
#  'Canada_Nova Scotia',
#  'Canada_Nunavet',
#  'Canada_Ontario',
#  'Canada_Prince Edward Island',
#  'Canada_QC',
#  'Canada_Quebec',
#  'Canada_SK',
#  'Canada_Saskatchewan',
#  'Canada_Toronto',
#  'Canada_chicken',
#  'Chile',
#  'Chile_Santiago',
#  'China',
#  'China_Anhui',
#  'China_Beijing',
#  'China_Changchun',
#  'China_Changzhou',
#  'China_Chibi',
#  'China_Dongting',
#  'China_Eastern China',
#  'China_Fujian',
#  'China_Fuzhou',
#  'China_Gansu',
#  'China_Guangdong',
#  'China_Guangxi',
#  'China_Guangzhou',
#  'China_Guizhou',
#  'China_Hangzhou',
#  'China_Harbin',
#  'China_Hebei',
#  'China_Hei Longjiang',
#  'China_Heilongjiang',
#  'China_Henan',
#  'China_HuBei',
#  'China_HuNan',
#  'China_Huabei',
#  'China_Huadong',
#  'China_Hubei',
#  'China_Hunan',
#  'China_Inner Mongolia',
#  'China_Jangsu',
#  'China_Jiangsu',
#  'China_Jiangxi',
#  'China_Jilin',
#  'China_Kowloon',
#  'China_Lengshuitan',
#  'China_Liaoning',
#  'China_Nanchang',
#  'China_Nanjing',
#  'China_Ningxia',
#  'China_North China',
#  'China_Qinghai',
#  'China_Rizhao',
#  'China_San Jiang',
#  'China_SanJiang',
#  'China_Shaanxi',
#  'China_Shandong',
#  'China_Shanghai',
#  'China_Shantou',
#  'China_Shanxi',
#  'China_Shengzhen',
#  'China_Sheny',
#  'China_Shijiazhuang',
#  'China_Sichuan',
#  'China_Suzhou',
#  'China_Tianjin',
#  'China_Tibet',
#  'China_Wenzhou',
#  'China_Wuxi',
#  'China_Xianghai',
#  'China_Xinjiang',
#  'China_Xuyi',
#  'China_Xuzhou',
#  "China_Ya'an",
#  'China_Yangzhou',
#  'China_Yunnan',
#  'China_ZhaLong',
#  'China_Zhejiang',
#  'China_Zhejiang-Yiwu',
#  'China_Zhenjiang',
#  'China_Zhoushan',
#  'China_mallard',
#  'Colombia_Bogota',
#  'Colombia_Medellin',
#  "Cote dIvoire_Cote d'Ivoire",
#  'Cote dIvoire_Ivory Coast',
#  'Croatia',
#  'Czech Republic_Brno',
#  'Czech Republic_Ostrava',
#  'Denmark',
#  'Denmark_Aalborg',
#  'Denmark_Aarhus',
#  'Denmark_Copenhagen',
#  'Denmark_Hvidovre',
#  'Denmark_Odense',
#  'Dominican Republic_Santo Domingo',
#  'Ecuador_Quito',
#  'Egypt',
#  'Egypt_El Fayoum',
#  'Egypt_Giza',
#  'Egypt_Menofia',
#  'Egypt_Qalubia',
#  'Egypt_Sharkia',
#  'El Salvador_San Salvador',
#  'Estonia_Tallinn',
#  'Finland',
#  'Finland_Helsinki',
#  'France',
#  "France_Cotes d'Armor",
#  'France_Finnistere',
#  'France_Ille et Vilaine',
#  'France_Lyon',
#  'France_Marquenterre',
#  'France_Nice',
#  'France_OMS',
#  'France_Paris',
#  'France_Ploufragan',
#  'France_Reunion',
#  'France_StEtienne',
#  'Georgia',
#  'Georgia_Republic of Georgia',
#  'Germany',
#  'Germany_Albersloh',
#  'Germany_Altenberge',
#  'Germany_Althausen',
#  'Germany_Ankum-Stockum',
#  'Germany_Bavaria',
#  'Germany_Bayern',
#  'Germany_Berlin',
#  'Germany_Bochum',
#  'Germany_Bonn',
#  'Germany_Cloppenburg',
#  'Germany_Cologne',
#  'Germany_Doetlingen',
#  'Germany_Duelmen',
#  'Germany_Ebbinghof',
#  'Germany_Frankfurt',
#  'Germany_Freren',
#  'Germany_Garrel',
#  'Germany_Germany-BY',
#  'Germany_Greven',
#  'Germany_Hamburg',
#  'Germany_Heinersdorf',
#  'Germany_Heudorf-Messkirch',
#  'Germany_Jena',
#  'Germany_Langefoerden',
#  'Germany_Lohne',
#  'Germany_Moeglingen',
#  'Germany_Munich',
#  'Germany_Neumarkt',
#  'Germany_Niederwinden',
#  'Germany_Nordkirchen',
#  'Germany_Papenburg',
#  'Germany_Potsdam',
#  'Germany_Rugen',
#  'Germany_Sachsen-Anhalt',
#  'Germany_Saerbeck',
#  'Germany_Stralsund',
#  'Germany_Tornitz',
#  'Germany_Wagun',
#  'Germany_Warendorf',
#  'Germany_Wettringen',
#  'Germany_Wuerusreuth',
#  'Germany_Wurzburg',
#  'Greece_Athens',
#  'Guam',
#  'Guatemala',
#  'Hong Kong',
#  'Hong Kong_Jiangxi',
#  'Hungary',
#  'Hungary_Budapest',
#  'Iceland',
#  'India',
#  'India_INDIA',
#  'India_Rtng',
#  'India_Sikkim',
#  'India_Tripura',
#  'India_Vadu',
#  'India_West Bengal',
#  'Indonesia',
#  'Indonesia_Bali',
#  'Indonesia_Banten',
#  'Indonesia_Central Java',
#  'Indonesia_East Java',
#  'Indonesia_East Kalimantan',
#  'Indonesia_North Sumatra',
#  'Indonesia_South Kalimantan',
#  'Indonesia_Sulawesi Selatan',
#  'Indonesia_West Java',
#  'Indonesia_Yogjakarta',
#  'Iran',
#  'Iraq',
#  'Israel',
#  'Italy',
#  'Italy_Genoa',
#  'Italy_Pavia',
#  'Italy_Roma',
#  'Italy_Siena',
#  'Japan',
#  'Japan_Aichi',
#  'Japan_Akita',
#  'Japan_Amagasaki',
#  'Japan_Aomori',
#  'Japan_Chiba',
#  'Japan_Chiba-C',
#  'Japan_Fukuoka-C',
#  'Japan_Fukushima',
#  'Japan_Gifu-C',
#  'Japan_Gunma',
#  'Japan_Himeji',
#  'Japan_Hiroshima',
#  'Japan_Hokkaido',
#  'Japan_Hyogo',
#  'Japan_Ibaraki',
#  'Japan_Iwate',
#  'Japan_Kagoshima',
#  'Japan_Kanagawa',
#  'Japan_Kawasaki',
#  'Japan_Kobe',
#  'Japan_Kumamoto',
#  'Japan_Kyoto',
#  'Japan_Mie',
#  'Japan_Miyazaki',
#  'Japan_Nagasaki',
#  'Japan_Nara',
#  'Japan_Narita',
#  'Japan_Niigata',
#  'Japan_Oita',
#  'Japan_Okinawa',
#  'Japan_Osaka',
#  'Japan_Osaka-C',
#  'Japan_Saitama',
#  'Japan_Sakai',
#  'Japan_Sapporo',
#  'Japan_Sendai',
#  'Japan_Shiga',
#  'Japan_Shimane',
#  'Japan_Shizuoka',
#  'Japan_Shizuoka-C',
#  'Japan_Tochigi',
#  'Japan_Tokushima',
#  'Japan_Tokyo',
#  'Japan_Utsunomiya',
#  'Japan_Wakayama',
#  'Japan_Yamagata',
#  'Japan_Yamaguchi',
#  'Japan_Yokohama',
#  'Japan_kumamoto',
#  'Japan_swine',
#  'Kazakhstan_Almati',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Kyrgyzstan_Bishkek',
#  'Laos',
#  'Laos_Lao',
#  'Lebanon',
#  'Lebanon_Tennessee',
#  'Luxembourg',
#  'Malaysia',
#  'Mexico',
#  'Mexico_Chis',
#  'Mexico_Coahuila',
#  'Mexico_Durango',
#  'Mexico_Hidalgo',
#  'Mexico_Jalisco',
#  'Mexico_Merida',
#  'Mexico_Mexico City',
#  'Mexico_Mexico city',
#  'Mexico_Puebla',
#  'Mexico_Queretaro',
#  'Mexico_Veracruz',
#  'Mexico_Yucatan',
#  'Mongolia',
#  'Mongolia_Dundgobi',
#  'Mongolia_Ulaanbaatar',
#  'Mongolia_Ulgii',
#  'Myanmar',
#  'Myanmar_Hmawbi',
#  'Myanmar_Kyaing Tong',
#  'Myanmar_Pyigyitagon',
#  'Myanmar_Thanatpin',
#  'Nepal',
#  'Netherlands',
#  'Netherlands_Amsterdam',
#  'Netherlands_Bilthoven',
#  'Netherlands_Enschede',
#  'Netherlands_Nijmegen',
#  'Netherlands_Rotterdam',
#  'Netherlands_Tilburg',
#  'Netherlands_common eider',
#  'Netherlands_swine',
#  'New Caledonia',
#  'New Zealand',
#  'New Zealand_Ashburton',
#  'New Zealand_Auckland',
#  'New Zealand_Bay of Plenty',
#  'New Zealand_Canterbury',
#  'New Zealand_Christchurch',
#  'New Zealand_Dunedin',
#  'New Zealand_Otago',
#  'New Zealand_South Canterbury',
#  'New Zealand_Southland',
#  'New Zealand_Tairawhiti',
#  'New Zealand_Waikato',
#  'New Zealand_Wellington',
#  'New Zealand_West Coast',
#  'New Zealand_Whanganui',
#  'Nicaragua',
#  'Nicaragua_Managua',
#  'Nigeria',
#  'Nigeria_NIGERIA',
#  'Norway',
#  'Norway_Oslo',
#  'Ontario',
#  'Pakistan',
#  'Pakistan_Rawalpindi',
#  'Pakistan_Sihala',
#  'Peru',
#  'Peru_Lima',
#  'Peru_Piura',
#  'Peru_Pucallpa',
#  'Peru_Trujillo',
#  'Philippines',
#  'Philippines_Phillipines',
#  'Poland',
#  'Poland_Bieganow',
#  'Poland_Lutol',
#  'Poland_Warsaw',
#  'Poland_Wroclaw',
#  'Portugal',
#  'Portugal_PT',
#  'Qatar',
#  'Romania',
#  'Russia',
#  'Russia_Altai',
#  'Russia_Arkhangelsk',
#  'Russia_Astrakhan',
#  'Russia_Barnaul',
#  'Russia_Blagovechensk',
#  'Russia_Chany',
#  'Russia_Cheboksary',
#  'Russia_Chita',
#  'Russia_Cygnus olor',
#  'Russia_Domodedovo',
#  'Russia_Ekaterinburg',
#  'Russia_IIV-Anadyr',
#  'Russia_Irkutsk',
#  'Russia_Joshkar-Ola',
#  'Russia_Karasuk',
#  'Russia_Krasnodar',
#  'Russia_Krasnoozerskoe',
#  'Russia_Kurgan',
#  'Russia_Lipetsk',
#  'Russia_Magadan',
#  'Russia_Moscow',
#  'Russia_Nizhnii Novgorod',
#  'Russia_Novosibirsk',
#  'Russia_Omsk',
#  'Russia_Orenburg',
#  'Russia_Perm',
#  'Russia_Primorie',
#  'Russia_Primorje',
#  'Russia_Reshoty',
#  'Russia_Rostov',
#  'Russia_Rostov-on-Don',
#  'Russia_Russia_Krasnodar',
#  'Russia_Salekhard',
#  'Russia_Siberia',
#  'Russia_St. Petersburg',
#  'Russia_Suzdalka',
#  'Russia_Tomsk',
#  'Russia_Tula',
#  'Russia_Tver',
#  'Russia_Tyva',
#  'Russia_Ulan Ude',
#  'Russia_Vladimir',
#  'Russia_Vladivistok',
#  'Russia_Vladivostok',
#  'Russia_Volgograd',
#  'Russia_Yaroslavl',
#  'Saudi Arabia',
#  'Senegal_Dakar',
#  'Singapore',
#  'Slovenia',
#  'South Africa',
#  'South Africa_Johannesburg',
#  'South Korea',
#  'South Korea_KU',
#  'South Korea_Korea',
#  'South Korea_Kyonggi',
#  'South Korea_wild duck',
#  'Spain',
#  'Spain_Barcelona',
#  'Spain_Madrid',
#  'Spain_Oviedo',
#  'Spain_Terrassa',
#  'Sudan',
#  'Sweden',
#  'Sweden_Stockholm',
#  'Sweden_Umea',
#  'Switzerland',
#  'Switzerland_Geneva',
#  'Taiwan',
#  'Taiwan_Kingmen',
#  'Taiwan_TW',
#  'Taiwan_Taipei',
#  'Thailand',
#  'Thailand_A',
#  'Thailand_Angthong',
#  'Thailand_Bangkok',
#  'Thailand_Chachoengsao',
#  'Thailand_Chonburi',
#  'Thailand_Kalasin',
#  'Thailand_Khon Kaen',
#  'Thailand_Kohn Kaen',
#  'Thailand_Nakhon Pathom',
#  'Thailand_Nakhonsawan',
#  'Thailand_NaraThiwat',
#  'Thailand_Phathumthani',
#  'Thailand_Phichit',
#  'Thailand_Rachaburi',
#  'Thailand_Ratchaburi',
#  'Thailand_Saraburi',
#  'Thailand_Sukhothai',
#  'Thailand_Suphanburi',
#  'Thailand_Udon Thani',
#  'Thailand_Uthaithani',
#  'Thailand_swine',
#  'Turkey_Ankara',
#  'USA_Alabama',
#  'USA_Alaska',
#  'USA_Arizona',
#  'USA_Arkansas',
#  'USA_Atlanta',
#  'USA_Baylor',
#  'USA_Bethesda',
#  'USA_Boston',
#  'USA_Bronx',
#  'USA_Brooklyn',
#  'USA_Brownsville',
#  'USA_CA',
#  'USA_California',
#  'USA_Cambridge',
#  'USA_Cherry Point',
#  'USA_Chicago',
#  'USA_Colorado',
#  'USA_Connecticut',
#  'USA_Craven',
#  'USA_DE',
#  'USA_Dayton',
#  'USA_Delaware',
#  'USA_Delaware Bay',
#  'USA_District of Columbia',
#  'USA_Durham',
#  'USA_FL',
#  'USA_Florida',
#  'USA_Ft.Benning',
#  'USA_GA',
#  'USA_Gainesville',
#  'USA_Georgia',
#  'USA_Great Lakes',
#  'USA_Houston',
#  'USA_IA',
#  'USA_IN',
#  'USA_Idaho',
#  'USA_Illinois',
#  'USA_Indiana',
#  'USA_Interior Alaska',
#  'USA_Iowa',
#  'USA_Kansas',
#  'USA_Kentucky',
#  'USA_LA',
#  'USA_Los Angeles',
#  'USA_Louisiana',
#  'USA_MD',
#  'USA_MI',
#  'USA_MN',
#  'USA_MO',
#  'USA_Maine',
#  'USA_Maryland',
#  'USA_Massachusetts',
#  'USA_Memphis',
#  'USA_Michigan',
#  'USA_Minneapolis',
#  'USA_Minnesota',
#  'USA_Mississippi',
#  'USA_Missouri',
#  'USA_Montana',
#  'USA_NC',
#  'USA_NJ',
#  'USA_NY',
#  'USA_Nebraska',
#  'USA_Nevada',
#  'USA_New Bern',
#  'USA_New Jersey',
#  'USA_New Mexico',
#  'USA_New York',
#  'USA_Newark',
#  'USA_North Carolina',
#  'USA_North Dakota',
#  'USA_OH',
#  'USA_Ohio',
#  'USA_Oklahoma',
#  'USA_Oregon',
#  'USA_PA',
#  'USA_Pennsylvania',
#  'USA_Pensacola',
#  'USA_Rhode Island',
#  'USA_SD',
#  'USA_San Antonio',
#  'USA_San Diego',
#  'USA_Santa Clara',
#  'USA_Santa Fe',
#  'USA_Silver Spring',
#  'USA_South Carolina',
#  'USA_South Central Alaska',
#  'USA_South Dakota',
#  'USA_Southcentral Alaska',
#  'USA_Southeastern Alaska',
#  'USA_Springfield',
#  'USA_TX',
#  'USA_Tennessee',
#  'USA_Texas',
#  'USA_Utah',
#  'USA_VA',
#  'USA_Vermont',
#  'USA_Virginia',
#  'USA_Washington',
#  'USA_West Virginia',
#  'USA_Wisconsin',
#  'USA_Wyoming',
#  'USA_mallard.Maryland',
#  'USA_swine',
#  'Uganda',
#  'United Arab Emirates_Emirates',
#  'United Kingdom',
#  'United Kingdom_Brighton',
#  "United Kingdom_Christ's Hospital",
#  'United Kingdom_England',
#  'United Kingdom_Guildford',
#  'United Kingdom_Headington',
#  'United Kingdom_Northern Ireland',
#  'United Kingdom_Rook',
#  'United Kingdom_Scotland',
#  'United Kingdom_Sheffield',
#  'Viet Nam',
#  'Viet Nam_Bac Lieu',
#  'Viet Nam_BacGiang',
#  'Viet Nam_BacNinh',
#  'Viet Nam_Binh Doung',
#  'Viet Nam_Binh Duong',
#  'Viet Nam_Ca Mau',
#  'Viet Nam_Cao Bang',
#  'Viet Nam_DaNang',
#  'Viet Nam_Ha Nam',
#  'Viet Nam_Ha Tay',
#  'Viet Nam_HaNam',
#  'Viet Nam_HaNoi',
#  'Viet Nam_Hai Duong',
#  'Viet Nam_Hanoi',
#  'Viet Nam_Hau Giang',
#  'Viet Nam_HoChiMinh',
#  'Viet Nam_HoaBinh',
#  'Viet Nam_Hue',
#  'Viet Nam_HungYen',
#  'Viet Nam_KhanhHoa',
#  'Viet Nam_Lang Son',
#  'Viet Nam_LangSon',
#  'Viet Nam_Long An',
#  'Viet Nam_LongAn',
#  'Viet Nam_Nam Dinh',
#  'Viet Nam_NamDinh',
#  'Viet Nam_Ninh Binh',
#  'Viet Nam_Quang Ninh',
#  'Viet Nam_Soc Trang',
#  'Viet Nam_Son La',
#  'Viet Nam_TayNguyen',
#  'Viet Nam_TayNinh',
#  'Viet Nam_ThaiBinh',
#  'Viet Nam_Vietnam',
#  'Zambia'}

# %%
# Find a GPS coordinate for each
# geodata = []
# for search_term in countries_to_search:
#     new_search_term = search_term.replace('_', ' ')
#     loc = geocoder.geocode(new_search_term)
#     if loc is None:
#         loc = geocoder.geocode(new_search_term[0])
#     lat = loc.latitude
#     lon = loc.longitude
#     data = (search_term, u'{0}'.format(loc), lon, lat)
#     geodata.append(data)
#     print(data)

# %%
# geodf = pd.DataFrame(geodata)
# geodf.columns = ['Search Term', "Returned Location", 'Longitude', 'Latitude']
# geodf.to_csv('Country Geocoding.csv', encoding='utf-8')

# %%
# ecotype_map
# Add the ecotype into each node.
for n, d in G.nodes(data=True):
    country = d['country']
    species = d['host_species']
    if '/' in species:
        species = species.split('/')[0]
    if 'null' in species:
        species = 'Unknown'
        
        
#     cleaned_country = country.replace('_', ' ')
#     specific_region = n.split('/')[-3]
#     if specific_region != cleaned_country:
#         search_term = '{0} {1}'.format(cleaned_country, specific_region)
#     else:
#         search_term = cleaned_country
#     print(search_term)
#     location = geocoder.geocode(search_term)
#     print('  ' + str(location))
#     if location is None:
#         location = geocoder.geocode(cleaned_country)
#     lat = location.latitude
#     lon = location.longitude
    
    

    
    G.node[n]['ecotype'] = ecotype_map[(country, species)]
#     G.node[n]['latitude'] = lat
#     G.node[n]['longitude'] = lon

# %%
# Identify the reassortants.

# Add reassortant status for each node.
for n, d in G.nodes(data=True):
    in_edge_types = set([d['edge_type'] for sc, sk, d in G.in_edges(n, data=True)])
    if 'reassortant' in in_edge_types:
        G.node[n]['reassortant'] = True
    elif 'full_complement' in in_edge_types:
        G.node[n]['reassortant'] = False
    else:
        G.node[n]['reassortant'] = False
        
def is_reassortant(G, node):
    return G.node[node]['reassortant']

reassortant_viruses = []
for n, d in G.nodes(data=True):
    if is_reassortant(G, n):
        reassortant_viruses.append(n)
        
print(len(reassortant_viruses))
# Out:
# 2106

# %%
reassortant_hosts = []
for virus in reassortant_viruses:
    reassortant_hosts.append(G.node[virus]['host_species'])
    
plt.pie(Counter(reassortant_hosts).values(), labels=Counter(reassortant_hosts).keys())
plt.axes().set_aspect('equal')
plt.show()

# %%
# condensed_reassortant_hosts = []
# for host in reassortant_hosts:
#     if '/' in host:
#         host = host.split('/')[1]
#         if host == 'null':
#             host = 'Unknown'
#         condensed_reassortant_hosts.append(host)
#     else:
#         if host == 'null':
#             host = 'Unknown'
#         condensed_reassortant_hosts.append(host)

# %%
def get_host_group(G, node):
    host = G.node[node]['host_species']
    if 'Human' in host or 'human' in host:
        host = 'Hu'
    elif 'Avian' in host or 'avian' in host:
        host = 'Av'
    elif 'Unknown' in host or 'unknown' in host:
        host = 'Un'
    elif 'null' in host or 'Null' in host:
        host = 'Un'
    elif 'Swine' in host or 'swine' in host:
        host = 'Sw'
    else:
        host = 'Ma'
        
    return host

def correct_host_group_ecotype(G, node):
    host = get_host_group(G, node)
    
    if host == 'Av':
        if G.node[node]['ecotype'] == 'Domestic':
            host = 'Av-D'
        else:
            host = 'Av-W'
            
    return host

# %%
G.nodes(data=True)[0]
# Out:
# ('A/mallard/Interior Alaska/6MP0160AR1/2006',
#  {'collection_date': Timestamp('2006-08-12 00:00:00'),
#   'country': 'USA',
#   'ecotype': 'Wild',
#   'host_species': 'Mallard/Avian',
#   'reassortant': False,
#   'state': 'Interior Alaska',
#   'subtype': 'H3N8'})

# %%
# Get total representation of viruses
all_hosts = []
for n, d in G.nodes(data=True):
    all_hosts.append(correct_host_group_ecotype(G, n))
    
reassortant_hosts = []
for n, d in G.nodes(data=True):
    if d['reassortant'] == True:
        reassortant_hosts.append(correct_host_group_ecotype(G, n))

# %%
def counter_proportions(counter):
    total = sum(counter.values())
    
    proportions = dict()
    for key, value in counter.items():
        proportions[key] = float(value)/float(total)
        
    return proportions

def categorical_counter_xlabels(counter):
    idxs = dict()
    
    for i, key in enumerate(counter.keys()):
        idxs[key] = i
        
    return idxs

# %%
# all_hosts

# %%
# Plot the proportion of hosts for reassortant viruses
counts = Counter(reassortant_hosts)
props = counter_proportions(counts)
# xpos = categorical_counter_xlabels(counts)

reassortant_proportions = pd.DataFrame(props.values(), index=props.keys()).sort(0, ascending=False)
reassortant_proportions.columns = ['Reassortant Viruses']

counts = Counter(all_hosts)
props = counter_proportions(counts)
all_proportions = pd.DataFrame(props.values(), index=props.keys()).sort(0, ascending=False)
all_proportions.columns = ['All Viruses']

joined_proportions = all_proportions.join(reassortant_proportions)
joined_proportions.plot(kind='bar', grid=False, figsize=golden_figsize(2), color=['green', 'blue'])

# Plotting parameters.
ax = plt.gca()
# plt.xlabel('Host Species')
ax.set_ylabel('Proportion', fontsize=7)
ax.set_title("Proportion of Viruses' Host Species", fontsize=9)
plt.ylim(0, 1)
plt.legend(fontsize=7)
xlabels = ax.get_xticklabels()
plt.setp(xlabels, rotation=0, ha='center', fontsize=7) 
ylabels = ax.get_yticklabels()
plt.setp(ylabels, fontsize=7)

ax.annotate('d.', xy=(0,1), ha='left', va='top', xycoords='figure fraction')

plt.subplots_adjust(bottom=0.2, right=0.95, left=0.15)
plt.savefig('Proportion of Reassortant Viruses Host Species.pdf')

# %%
joined_proportions
# Out:
#       All Viruses  Reassortant Viruses
# Hu       0.503513             0.030864
# Av-W     0.274725             0.697531
# Sw       0.105687             0.077398
# Av-D     0.096319             0.169991
# Ma       0.018195             0.023267
# Un       0.001561             0.000950

# %%
# Perform host species permutation test to assess what the distribution of reassortant viruses would be under null.

host_shuffledG = G.copy()

proportions = []

for i in range(1000):
    reassortant_species = dict()
    from random import shuffle
    hosts = [get_host_group(G, n) for n in G.nodes()]
    shuffle(hosts)

    # Add in condensed host
    for i, n in enumerate(host_shuffledG.nodes()):
        host_shuffledG.node[n]['host_group'] = hosts[i]

    for n, d in host_shuffledG.nodes(data=True):
        if is_reassortant(G, n):
            if d['host_group'] not in reassortant_species.keys():
                reassortant_species[d['host_group']] = 1
            else:
                reassortant_species[d['host_group']] += 1
                
    proportions.append(reassortant_species)

# %%
pd.DataFrame(proportions)
# Out:
#       Av    Hu  Ma   Sw  Un
# 0    796  1039  40  227   4
# 1    744  1103  36  221   2
# 2    793  1044  44  220   5
# 3    776  1068  24  238 NaN
# 4    778  1089  47  189   3
# 5    750  1094  42  217   3
# 6    799  1049  35  221   2
# 7    741  1091  31  241   2
# 8    792  1035  40  237   2
# 9    788  1088  36  193   1
# 10   742  1092  33  236   3
# 11   784  1057  39  224   2
# 12   752  1078  47  227   2
# 13   801  1039  38  225   3
# 14   810  1017  39  236   4
# 15   772  1037  45  247   5
# 16   789  1072  38  205   2
# 17   819  1040  28  214   5
# 18   751  1082  44  225   4
# 19   790  1050  36  226   4
# 20   789  1042  43  229   3
# 21   781  1040  48  235   2
# 22   819  1055  33  197   2
# 23   784  1045  38  237   2
# 24   776  1041  31  255   3
# 25   751  1094  43  216   2
# 26   791  1034  33  245   3
# 27   790  1041  36  237   2
# 28   814  1045  34  210   3
# 29   795  1061  42  204   4
# ..   ...   ...  ..  ...  ..
# 970  758  1070  32  242   4
# 971  806  1039  31  225   5
# 972  793  1051  30  226   6
# 973  813  1038  29  223   3
# 974  739  1087  29  247   4
# 975  764  1071  34  236   1
# 976  805  1054  40  207 NaN
# 977  805  1044  37  218   2
# 978  766  1088  33  216   3
# 979  776  1075  32  221   2
# 980  793  1037  46  226   4
# 981  757  1093  35  219   2
# 982  752  1068  42  241   3
# 983  794  1049  45  215   3
# 984  767  1059  39  238   3
# 985  799  1033  37  233   4
# 986  720  1108  40  234   4
# 987  753  1085  35  231   2
# 988  747  1102  36  218   3
# 989  811  1015  41  236   3
# 990  797  1064  34  209   2
# 991  778  1070  40  216   2
# 992  755  1076  37  234   4
# 993  789  1010  42  261   4
# 994  838  1030  33  203   2
# 995  809  1045  39  207   6
# 996  767  1053  44  237   5
# 997  731  1098  53  219   5
# 998  802  1063  34  206   1
# 999  786  1067  35  213   5
#
# [1000 rows x 5 columns]

# %%
# Create a detailed version of the counter, which includes the exact species represented.
detailed_hosts = []
for virus in reassortant_viruses:
    host = G.node[virus]['host_species']
    if '/' in host:
        host = host.split('/')[0]
    if 'null' in host:
        host = 'Unknown'
    detailed_hosts.append(host)

counts = Counter(detailed_hosts)
props = counter_proportions(counts)
xpos = categorical_counter_xlabels(counts)

pd.DataFrame(props.values(), index=props.keys()).sort(0, ascending=False).plot(kind='bar', figsize=(16,5), grid=False, legend=False, color='green')
fig = plt.gcf()
fig.set_size_inches(20,5) 
plt.xlabel('Host Species')
plt.ylabel('Proportion')
plt.title("Proportion of Reassortant Viruses' Host Species")
plt.savefig('Proportion of Reassortant Viruses Host Species (Detailed).pdf', bbox_inches='tight')

# %%
# Create a detailed version of the counter, which includes the exact AVIAN only species represented.
detailed_avians = []
for virus in reassortant_viruses:
    host = G.node[virus]['host_species']
    if 'Avian' in host or 'avian' in host:
        if '/' in host:
            host = host.split('/')[0]
        detailed_avians.append(host)

counts = Counter(detailed_avians)
props = counter_proportions(counts)
xpos = categorical_counter_xlabels(counts)

pd.DataFrame(props.values(), index=props.keys()).sort(0, ascending=False).plot(kind='bar', figsize=(16,5), grid=False, legend=False, color='green')
fig = plt.gcf()
fig.set_size_inches(16,5) 
plt.xlabel('Host Species')
plt.ylabel('Proportion')
plt.title("Proportion of Reassortant Viruses' Avian Host Species")
plt.savefig('Proportion of Reassortant Viruses Host Species (Avian Only).pdf', bbox_inches='tight')

# %% [markdown]
# # Sampling Size Biases Subtype Connectivity?
#
# Does sampling size for a particular subtype bias the subtype's connectivity with other subtypes via reassortment?

# %%
subtype_counts = Counter()
for n, d in G.nodes(data=True):
    subtype = d['subtype']
    subtype_counts[subtype] += 1
    
subtype_counts
# Out:
# Counter({'H1N1': 5607, 'H3N2': 4350, 'H5N1': 794, 'H3N8': 718, 'H4N6': 680, 'H1N2': 448, 'H9N2': 358, 'H6N2': 300, 'H10N7': 292, 'H5N2': 259, 'H7N3': 223, 'H11N9': 223, 'H6N1': 189, 'H7N2': 180, 'H2N3': 154, 'H6N6': 141, 'H6N8': 117, 'H4N8': 99, 'H3N6': 90, 'H7N9': 84, 'H7N7': 83, 'H12N5': 68, 'H4N2': 67, 'H11N2': 66, 'H8N4': 65, 'Mixed': 51, 'H7N1': 46, 'H5N8': 43, 'H5N5': 36, 'H5N3': 35, 'H2N2': 34, 'H3N1': 34, 'H1N9': 34, 'H10N1': 32, 'H6N5': 29, 'H2N9': 28, 'H10N3': 26, 'H2N1': 26, 'H1N3': 26, 'H16N3': 25, 'H10N4': 24, 'H11N1': 23, 'H7N6': 20, 'H2N7': 20, 'H4N9': 20, 'H2N5': 18, 'H10N8': 16, 'H11N3': 15, 'H10N6': 14, 'H13N6': 14, 'H10N9': 13, 'H6N3': 13, 'H7N4': 13, 'H3N3': 12, 'H4N3': 11, 'H11N8': 11, 'H10N2': 10, 'H2N8': 10, 'H1N8': 10, 'H9N5': 10, 'H13N8': 10, 'H10N5': 9, 'H3N5': 9, 'H9N1': 9, 'H9N9': 9, 'H4N1': 8, 'H3N7': 8, 'H7N8': 8, 'H5N9': 7, 'H1N7': 7, 'H6N4': 6, 'H5N7': 6, 'H3N9': 6, 'H4N5': 5, 'H6N9': 5, 'H11N6': 5, 'H12N4': 5, 'H13N9': 5, 'H11N7': 4, 'H4N7': 4, 'H12N7': 4, 'H1N6': 4, 'H1N4': 4, 'H9N7': 4, 'H6N7': 4, 'H12N8': 4, 'H5N6': 3, 'H13N2': 3, 'H8N1': 2, 'H9N8': 2, 'H5N4': 2, 'H7N5': 2, 'H1N5': 2, 'H9N3': 2, 'H9N6': 2, 'H12N3': 2, 'H14N6': 2, 'H14N2': 2, 'H2N4': 1, 'H2N6': 1, 'H8N8': 1, 'H8N2': 1, 'H12N9': 1, 'H4N4': 1, 'H12N6': 1, 'H12N2': 1, 'H12N1': 1, 'H15N9': 1, 'H15N4': 1})

# %%
centralities = pd.read_csv('Subtype Reassortment Centralities.csv', index_col=0)
centralities = dict(zip(centralities['Subtype'], centralities['Degree Centrality']))

# %%
def ols_fit_predict(xs, ys):

    est = sm.OLS(ys, xs) 
    est = est.fit()
    print(est.summary())

    # Create the best line of fit data for plotting
    x_prime = np.linspace(min(xs), max(xs), 100)[:,np.newaxis]
    x_prime = sm.add_constant(x_prime)
    y_hat = est.predict(x_prime[:,1]) 
    
    rsquared = '{0:.2f}'.format(est.rsquared)
    
    return x_prime, y_hat, rsquared

# %%
# Plot params
titlefs = 9 #title fontsize
axisfs = 7 #axis fontsize
figsize = (2.5, 2.5) #figure size in inches

# %%
# Code to make scatterplot of subtype_counts vs centrality
xs = [] # centralities
ys = [] # counts in the dataset

for subtype, count in subtype_counts.items():
    xs.append(centralities[subtype])
    ys.append(count)
    
# Perform OLS regression
x_prime, y_hat, rsquared = ols_fit_predict(xs, ys)

# Plot the scatterplot and OLS
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111)
ax.scatter(xs, ys, color='blue')
ax.plot(x_prime[:,1],y_hat, 'r')

ax.annotate(r'$r^2: {0}$'.format(rsquared), xy=(0.5, 0.3), xycoords='axes fraction', ha='left', va='center', fontsize=9)
ax.annotate(r'b.', xy=(0,1), xycoords='figure fraction', va='top')

# Plot parameters
ax.set_xlabel('Connectivity', fontsize=axisfs)
ax.set_ylabel('Number of Isolates \n Represented (x1000)', fontsize=axisfs)
ax.set_yticklabels(np.arange(-1, 7, 1))
ax.set_xticks(np.arange(0, 0.9, 0.2))
ax.set_title('Sampling Effort', fontsize=titlefs)
plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.85)
plt.savefig('Subtype Representation vs. Subtype Connectivity.pdf')

# Save the data as a CSV file
csv_data = pd.DataFrame(xs, ys).reset_index()
csv_data.columns = ['Degree Centrality', 'Num Samples']
csv_data.to_csv('Subtype Representation vs. Subtype Connectivity.csv')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.167
# Method:                 Least Squares   F-statistic:                     22.80
# Date:                Wed, 27 May 2015   Prob (F-statistic):           5.69e-06
# Time:                        15:52:20   Log-Likelihood:                -857.71
# No. Observations:                 109   AIC:                             1717.
# Df Residuals:                     108   BIC:                             1720.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1          1073.5111    224.844      4.774      0.000       627.831  1519.191
# ==============================================================================
# Omnibus:                      182.919   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11128.215
# Skew:                           6.814   Prob(JB):                         0.00
# Kurtosis:                      50.587   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Reassortment Host Range and Connectivity
#
# One of the hypotheses I have is that that the inter-subtype degree centrality is related to the host range of the virus. To do this, I will plot a scatterplot of # of hosts represented against the degree centrality, for each subtype, with the radius of the dot proportional to the square root of the number of isolates represented.

# %%
subtype_hosts = dict()
subtype_counts = Counter()
for n, d in G.nodes(data=True):
    subtype = d['subtype']
    host = d['host_species']
    if host == 'mixed':
        host = 'Mixed'
    if host == 'null':
        host = 'Unknown'
    
    if subtype not in subtype_hosts.keys():
        subtype_hosts[subtype] = set()
        
    subtype_counts[subtype] += 1
    subtype_hosts[subtype].add(host)

# %%
# Code to make bubble plot.
xs = []
ys = []
ss = []
dot_labels = []
subtypes = []

# Precisely specify the xs, ys, and sizes of the dots.
for subtype, host_set in subtype_hosts.items():
    subtypes.append(subtype)
    xs.append(centralities[subtype])
    ys.append(len(subtype_hosts[subtype]))
    ss.append(math.sqrt(subtype_counts[subtype]))
    if centralities[subtype] > 0.4 or len(subtype_hosts[subtype]) > 25:
        dot_labels.append(subtype)
    else:
        dot_labels.append('')

x_prime, y_hat, rsquared = ols_fit_predict(xs, ys)

# Plot scatterplot
fig = plt.figure(figsize=(2.5,2.5))
ax = fig.add_subplot(111)
ax.scatter(xs, ys, s=ss, color='blue')
ax.plot(x_prime[:,1], y_hat, 'r')

# Additional plotting parameters
ax.set_xlabel('Connectivity', fontsize=axisfs)
ax.set_ylabel('Num. Unique Hosts Represented', fontsize=axisfs)
ax.set_title('Host Range', fontsize=titlefs)
ax.annotate(r'$r^2: {0}$'.format(rsquared), xy=(0.2, 0.5), xycoords='axes fraction', fontsize=9)
ax.annotate(r'c.', xy=(0,1), xycoords='figure fraction', va='top', ha='left')
ax.set_yticks(np.arange(0, 61, 20))
ax.set_xticks(np.arange(0, 0.9, 0.2))


plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.85)
plt.savefig('Host Range vs. Degree Centrality.pdf')

# Finally, make a dataframe of the data to accompany the plot.
data = {'subtypes':subtypes,
        'centralities':xs,
        'num_unique_hosts':ys,
        'num_isolates':[i**2 for i in ss]}
pd.DataFrame(data).to_csv('Host Range vs. Degree Centrality.csv')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     460.8
# Date:                Wed, 27 May 2015   Prob (F-statistic):           9.21e-41
# Time:                        15:52:21   Log-Likelihood:                -341.96
# No. Observations:                 109   AIC:                             685.9
# Df Residuals:                     108   BIC:                             688.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            42.5333      1.981     21.467      0.000        38.606    46.461
# ==============================================================================
# Omnibus:                      145.613   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5908.047
# Skew:                           4.639   Prob(JB):                         0.00
# Kurtosis:                      37.853   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/ericmjl/anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/backends/backend_pdf.py:2264: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   different = bool(ours != theirs)

# %% [markdown]
# # Reassortment Geographic Range and Connectivity
#
# Similar to the question above: Is there a relationship between the number of unique countries in which each subtype has been found?

# %%
subtype_countries = dict()
for n, d in G.nodes(data=True):
    subtype = d['subtype']
    country = d['country']
    
    if subtype not in subtype_countries.keys():
        subtype_countries[subtype] = set()
        
    subtype_countries[subtype].add(country)

# %%
# Code to make bubble plot.
xs = []
ys = []
ss = []
dot_labels = []
subtypes = []

for subtype, host_set in subtype_hosts.items():
    subtypes.append(subtype)
    xs.append(centralities[subtype])
    ys.append(len(subtype_countries[subtype]))
    ss.append(math.sqrt(subtype_counts[subtype])) # Ensure that radius proportional to sqrt of counts.
    if centralities[subtype] > 0.2 and len(subtype_countries[subtype]) > 10:
        dot_labels.append(subtype)
    else:
        dot_labels.append('')

x_prime, y_hat, rsquared = ols_fit_predict(xs, ys)

# Plot the scatterplot
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111)
ax.scatter(xs, ys, s=ss, color='blue')
ax.plot(x_prime[:,1], y_hat, 'r')

ax.set_xlabel('Connectivity', fontsize=axisfs)
ax.set_ylabel('Num. Unique Countries Represented', fontsize=axisfs)
ax.set_title('Geographic Dispersal', fontsize=titlefs)
# ax.text(-0.05, -6, 'Size of bubble proportional to number of isolates', ha='left')
ax.annotate(r'$r^2: {0}$'.format(rsquared), xy=(0.2, 0.4), xycoords='axes fraction', fontsize=9)
ax.set_yticks(np.arange(0, 61, 20))
ax.set_xticks(np.arange(0, 0.9, 0.2))
ax.annotate(r'd.', xy=(0,1), xycoords='figure fraction', va='top', ha='left')

plt.subplots_adjust(left=0.2, right=0.95, bottom=0.15, top=0.85)
plt.savefig('Geographic Dispersal vs. Degree Centrality.pdf')

# Finally, make a dataframe of the data to accompany the plot.
data = {'subtypes':subtypes,
        'centralities':xs,
        'num_unique_countries':ys,
        'num_isolates':[i**2 for i in ss]}
pd.DataFrame(data).to_csv('Geographic Dispersal vs. Degree Centrality.csv')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.553
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     133.4
# Date:                Wed, 27 May 2015   Prob (F-statistic):           1.41e-20
# Time:                        15:52:22   Log-Likelihood:                -352.19
# No. Observations:                 109   AIC:                             706.4
# Df Residuals:                     108   BIC:                             709.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            25.1350      2.176     11.549      0.000        20.821    29.449
# ==============================================================================
# Omnibus:                      142.267   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3836.585
# Skew:                           4.703   Prob(JB):                         0.00
# Kurtosis:                      30.500   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Summary
#
# The geographic dispersal and host range both have a correlation with the degree centrality score. I interpret this as such: The geographic dispersal and host range probably have an impact on the subtype's status as a "hub" subtype.
#
# Using OLS regression, I have found that the sampling size is poorly correlated with the subtype degree centrality, and should not be biasing the data, while host range is the most correlated with subtype connectivity, followed by geographic dispersal.
